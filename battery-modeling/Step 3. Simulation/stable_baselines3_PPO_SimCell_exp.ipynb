# %%
# Python 3.9. Anaconda recommended.
# -- Prerequisites install 
#%pip install ipykernel --user
#%pip install stable_baselines3 --user
#%pip install tensorboard --user
#%pip install torch --index-url https://download.pytorch.org/whl/cu117 --upgrade --force-reinstall --trusted-host pypi.org --trusted-host pytorch.org --trusted-host download.pytorch.org --no-cache --user

# %% [markdown]
# # STABLEBASELINES TESTBED

# %%
# Battery env 
import gymnasium as gym
import numpy as np
from typing import Optional, Union
import itertools

import sys
sys.path.append('../../battery-modeling/Step 3. Simulation')

import sys
sys.path.append('../../battery-modeling/Step 3. Simulation')

import SimCellPack as scp



#class BatteryEnv(gym.Env[np.ndarray, Union[int, np.ndarray]]):

class BatteryEnv(gym.Env):

   def __init__(self, numCells, simCycles, sampleFactor, render_mode: Optional[str] = None):
      super().__init__()

      self.env_id = "Battery v0.4"
      self.num_envs = 1

      self.numCells = numCells

      # Define cell model simualtor 
      self.cellModel = scp.SimCellPack(numCells = numCells, simCycles = simCycles, sampleFactor = sampleFactor)
   
      self.soc_threshold_upper = 0.85
      self.soc_threshold_lower = 0.15


      self.action_space = gym.spaces.Box(-1, 1, (self.numCells,), dtype=np.float32)       # current applied to cell1,cell2,cell3...
      self.observation_space = gym.spaces.Box(0, 1, (self.numCells,), dtype=np.float32)   # SOCs for cell1, cell2, cell3...


      self.episode_time = 0
      self.state = None
      



   def step(self, action):
      err_msg = f"{action!r} ({type(action)}) invalid"
      assert self.action_space.contains(action), err_msg
      assert self.state is not None, "Call reset before using step method."

      # Scale the action space between 0 and 1
      battery_current_values = get_converted_action(action)

      # Send the action as feedback to the cell model
      self.cellModel.sendSimFeedback(battery_current_values)

      # Flags for determining certain occurences
      terminated = False
      truncated = False

      #Apply action to state
      code, self.state = self.cellModel.getSimStep()

      #print("Step: state: " + str(self.state) + " code: " + str(code))

      # Cell simulation finished, terminate
      if code == 0.0:
         truncated = True

      # Compute reward and termination cases
      # Apply step reward. Continue running.
      reward = compute_ballancing_reward(self.state, action, False)

      # Return modified
      return np.array(self.state, dtype=np.float32), float(reward), terminated, truncated, {}

   def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None,):
   # Reset runs first before starting the simulation to get the initial states
        
      super().reset(seed=seed)

      # Stops and restarts the cell simulation
      self.cellModel.stopSim()
      self.cellModel.startSim()


      self.episode_time = 0

      # Get initial states from the cell model
      code, self.state = self.cellModel.getSimStep()

      #print("Reset state: " + str(self.state))

      return np.array(self.state, dtype=np.float32), {}



#CONVERT ACTION
   
def get_converted_action(action):
   current_values = []
   for current in action:
      shifted_value = ((current + 1.0))/2  #from [-1, 1] to [0, 1], to be reduced from SoC
      current_values.append(shifted_value)

   return current_values


# REWARD CALCULATION HELPERS 

def compute_closeness(socs):
   mean = 0
   for soc in socs:
      mean += soc
   mean = mean/len(socs)

   mean_diff = 0
   for  soc in socs:
      mean_diff += abs(mean - soc)

   mean_diff /= len(socs)

   min = np.array(socs).min()
   max = np.array(socs).max()
   abs_diff_min_max = max - min


   # alternative: (mean_diff_from_mean), or (mean_diff_from_mean*05 + abs_diff_min_max*0.5)
   return abs_diff_min_max

# Closeness function debug code
numbers = [0.02, 0.05, 0, 0.01, 0.1]
numbers = [0.8268956, 0.7947008, 0.8274856]
print(compute_closeness(numbers))
print(np.std(numbers, dtype=np.float32))  # standard deviation

# Get reward for a given step
def compute_ballancing_reward(socs, action, should_print):

   # ---- REWARD ALTERNATIVES ----

   # 1. Cost as distance between 2 numbers. Yang
   #reward = -pow(soc0 - soc1, 2)
      
   # 2. Cost as standard deviation
   # reward = -np.std(socs, dtype=np.float32)

   # ---- REWARD ALTERNATIVES ----




   # normalized_socs = []
   # for soc in socs:
   #    newsoc = (soc - min(socs)) / (max(socs) - min(socs))
   #    normalized_socs.append(newsoc)
   
   # SOCs are now between [0, 1]


   reward = 0

   if action[socs.index(min(socs))] != 0.0:
      reward -= 0.01

   # Give 0.2 for each pair of SOCs that are within 0.02 distance of eachother.
   for i in range(len(socs)):
      for j in range(i + 1, len(socs)):
         if (math.isclose(socs[i], socs[j], abs_tol=0.01)):
            reward += 0.01
   
   # Introduce closeness to the reward
   reward = reward - compute_closeness(socs)
             
   return reward
# Out:
# 0.03278480000000006
# 0.0153177325

# %% [markdown]
# # PLOTTING FUNCTIONS:

# %%
import matplotlib.pyplot as plt
from IPython import display



def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=1)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    # plt.show()

    display.clear_output(wait=True)
    display.display(plt.gcf())

# plot_results(log_dir)

# %%
import stable_baselines3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback


import os
import torch
import math
import numpy as np
from typing import Optional, Union




class PlotResultsCallback(BaseCallback):

    def __init__(self, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.log_dir = log_dir
        self.save_path = None

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        plot_results(self.log_dir)

        return True

# %% [markdown]
# # Initialize environment

# %%
# !pip install gymnasium[box2d]
import gymnasium as gym
from stable_baselines3.common.env_checker import check_env


# Create log dir
log_dir = "./tmp/gym/pponormtest/"
os.makedirs(log_dir, exist_ok=True)


# Create and wrap the environment
env = BatteryEnv(numCells = 3, simCycles = 15, sampleFactor = 15, render_mode = False)

#for i in range(0, 100):
#    check_env(env)


# Logs will be saved in log_dir/monitor.csv 
env = Monitor(env, log_dir) #monitor for raw environments

# %% [markdown]
# # Opt1: Initialize a new model

# %%
from stable_baselines3 import A2C, SAC, PPO, TD3


print("Is CUDA enabled?", torch.cuda.is_available())



model = PPO('MlpPolicy', env, verbose=1, device="cuda", tensorboard_log="./ppo15c50s_tensorboard_log/", n_steps=2048, batch_size=256)
# Out:
# Is CUDA enabled? True
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Opt 2: Load existing trained model from save file

# %%
from stable_baselines3 import A2C, SAC, PPO, TD3

model = PPO.load(env=env, path=os.path.join(log_dir+"best_model_ppo_15c50s/", "best_model"))
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Train model for X timesteps.

# %% [markdown]
# Initialize Callback, so it remembers the best model for plotting purposes.

# %%
callback = EvalCallback(env, log_path=log_dir, n_eval_episodes= 1, eval_freq=100000,
                            best_model_save_path=os.path.join(log_dir, "best_model_ppo_15c50s"))

# %% [markdown]
# Train!

# %%
from stable_baselines3.common import results_plotter
from stable_baselines3 import A2C, SAC, PPO, TD3


# callback = EvalCallback(env, log_path=log_dir, n_eval_episodes= 1, eval_freq= 15000,
#                             best_model_save_path=os.path.join(log_dir, "best_model_ppo_norm"),
#                             callback_on_new_best=PlotResultsCallback(log_dir=log_dir))

# callback = EvalCallback(env, log_path=log_dir, n_eval_episodes= 1, eval_freq= 15000,
#                             best_model_save_path=os.path.join(log_dir, "best_model_ppo_norm"))

# Eval callback, for plotting and seeing how the training is going, and saving best models. No effect on the results.

# model.learn(total_timesteps=int(10000000), callback=callback)

for i in range (0, 2):
    model.learn(total_timesteps=int(200000), callback=callback)



# Plot helper from the library
results_plotter.plot_results(
    [log_dir], 1e6, results_plotter.X_TIMESTEPS, "PPO - Env: Battery"
)

# only ballance during resting
# during resting SOC is more accurate in estimation
# its also dangerous to do it during working times

# use larger SOC cells more AND use smallest SOC less4


# with Power Electronics, the output voltage has been changed.

# do ballancing while it rests'

# Current industry battery info: Current, Voltage, Temperature


# !!!!!!!!!! You should know that PPO1 and TRPO update self.num_timesteps after each rollout (and not each step) because they rely on MPI.
# Out:
# Logging to ./ppo15c50s_tensorboard_log/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 205  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0034018722 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -2.28        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000195    |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.998        |
# |    value_loss           | 0.00809      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0033384822 |
# |    clip_fraction        | 0.00669      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0187       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0199       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.996        |
# |    value_loss           | 0.0373       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003921785 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0688      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000241    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00146    |
# |    std                  | 0.995       |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005812399 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0926      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000995    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00327    |
# |    std                  | 1           |
# |    value_loss           | 0.00886     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004841712 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00466     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00115    |
# |    std                  | 1           |
# |    value_loss           | 0.0243      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 7            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0032326607 |
# |    clip_fraction        | 0.00698      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000758    |
# |    std                  | 1.01         |
# |    value_loss           | 0.0915       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 8            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0046037645 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.173       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0399       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00345     |
# |    std                  | 1.01         |
# |    value_loss           | 0.38         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 9            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0041438136 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0425       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0012      |
# |    std                  | 1.01         |
# |    value_loss           | 0.846        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 10           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0027610243 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0647       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000657    |
# |    std                  | 1            |
# |    value_loss           | 1.77         |
# ------------------------------------------
#
#
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.16e+04      |
# |    ep_rew_mean          | -1.99e+03     |
# | time/                   |               |
# |    fps                  | 371           |
# |    iterations           | 11            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00029553394 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.27         |
# |    explained_variance   | 0.41          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0447        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000117      |
# |    std                  | 1             |
# |    value_loss           | 3.47          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16e+04     |
# |    ep_rew_mean          | -1.99e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 12           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0030784667 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.191       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00174     |
# |    std                  | 1            |
# |    value_loss           | 6.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16e+04     |
# |    ep_rew_mean          | -1.99e+03    |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 13           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0053702537 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0419       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00209     |
# |    std                  | 1            |
# |    value_loss           | 0.179        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16e+04     |
# |    ep_rew_mean          | -1.99e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 14           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0017019892 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0372       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00036     |
# |    std                  | 0.996        |
# |    value_loss           | 0.0799       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16e+04    |
# |    ep_rew_mean          | -1.99e+03   |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 15          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004930815 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0209      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00189    |
# |    std                  | 0.997       |
# |    value_loss           | 0.267       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.16e+04     |
# |    ep_rew_mean          | -1.99e+03    |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 16           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0010469379 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.009        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000323    |
# |    std                  | 0.997        |
# |    value_loss           | 0.625        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+04   |
# |    ep_rew_mean          | -1.99e+03  |
# | time/                   |            |
# |    fps                  | 393        |
# |    iterations           | 17         |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00230983 |
# |    clip_fraction        | 0.00083    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.0923     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000381  |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.000257  |
# |    std                  | 0.997      |
# |    value_loss           | 0.616      |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.16e+04      |
# |    ep_rew_mean          | -1.99e+03     |
# | time/                   |               |
# |    fps                  | 395           |
# |    iterations           | 18            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00065852015 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.25         |
# |    explained_variance   | 0.241         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00213       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000344     |
# |    std                  | 0.998         |
# |    value_loss           | 0.601         |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+04   |
# |    ep_rew_mean          | -1.99e+03  |
# | time/                   |            |
# |    fps                  | 398        |
# |    iterations           | 19         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00223487 |
# |    clip_fraction        | 0.000928   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | -0.753     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00108   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.000767  |
# |    std                  | 1          |
# |    value_loss           | 0.291      |
# ----------------------------------------
#
#
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.99e+04      |
# |    ep_rew_mean          | -2.67e+03     |
# | time/                   |               |
# |    fps                  | 382           |
# |    iterations           | 20            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00095954956 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.26         |
# |    explained_variance   | -0.346        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00513       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00029      |
# |    std                  | 1             |
# |    value_loss           | 0.204         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+04     |
# |    ep_rew_mean          | -2.67e+03    |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 21           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0007685195 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.045       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00032     |
# |    std                  | 0.997        |
# |    value_loss           | 4.57         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+04     |
# |    ep_rew_mean          | -2.67e+03    |
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 22           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 9.493693e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0663       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.125        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 8.95e-06     |
# |    std                  | 0.996        |
# |    value_loss           | 2.67         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+04     |
# |    ep_rew_mean          | -2.67e+03    |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 23           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0009900783 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.0524      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0245       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000376    |
# |    std                  | 0.996        |
# |    value_loss           | 0.59         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+04     |
# |    ep_rew_mean          | -2.67e+03    |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 24           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0047407094 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00296     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00233     |
# |    std                  | 0.995        |
# |    value_loss           | 0.162        |
# ------------------------------------------
#
#
#
#
# Eval num_timesteps=50000, episode_reward=-3296.08 +/- 0.00
# Episode length: 15837.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.58e+04     |
# |    mean_reward          | -3.3e+03     |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0054082396 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | -0.0141      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00742     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00299     |
# |    std                  | 0.993        |
# |    value_loss           | 0.062        |
# ------------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.99e+04  |
# |    ep_rew_mean     | -2.67e+03 |
# | time/              |           |
# |    fps             | 316       |
# |    iterations      | 25        |
# |    time_elapsed    | 161       |
# |    total_timesteps | 51200     |
# ----------------------------------
#
#
# Logging to ./ppo15c50s_tensorboard_log/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 219  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0011635041 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | -0.214       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0763       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000101     |
# |    std                  | 0.992        |
# |    value_loss           | 0.79         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0031210138 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0171       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000947    |
# |    std                  | 0.993        |
# |    value_loss           | 0.0518       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003622166 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000718    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00232    |
# |    std                  | 0.993       |
# |    value_loss           | 0.00543     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 5          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00259087 |
# |    clip_fraction        | 0.00215    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.384      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00561    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00127   |
# |    std                  | 0.982      |
# |    value_loss           | 0.0103     |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 6            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0040315078 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.00714      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00481      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00232     |
# |    std                  | 0.979        |
# |    value_loss           | 0.0185       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 7            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0038608778 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00253      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 0.976        |
# |    value_loss           | 0.00597      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 8            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0044096177 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00671     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.98         |
# |    value_loss           | 0.00326      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0030477769 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.0162       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.982        |
# |    value_loss           | 0.0429       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 10           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0047437213 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00568      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00362     |
# |    std                  | 0.98         |
# |    value_loss           | 0.00107      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 11           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0036200327 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.0266       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0186       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.976        |
# |    value_loss           | 0.039        |
# ------------------------------------------
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 12           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0035646348 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.0558       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0139       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00154     |
# |    std                  | 0.978        |
# |    value_loss           | 0.059        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 13           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0044879066 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.195        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0027      |
# |    std                  | 0.974        |
# |    value_loss           | 0.671        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 14           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0058479095 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0268       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00302     |
# |    std                  | 0.972        |
# |    value_loss           | 0.0823       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34e+04    |
# |    ep_rew_mean          | -2.2e+03    |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 15          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.003947479 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.067       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00172    |
# |    std                  | 0.968       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 16           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0035176817 |
# |    clip_fraction        | 0.00239      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0232       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000513    |
# |    std                  | 0.968        |
# |    value_loss           | 0.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.34e+04    |
# |    ep_rew_mean          | -2.2e+03    |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 17          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006428038 |
# |    clip_fraction        | 0.00996     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00148     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0021     |
# |    std                  | 0.97        |
# |    value_loss           | 0.901       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 18           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012089771 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0107       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000333    |
# |    std                  | 0.97         |
# |    value_loss           | 1.11         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.34e+04      |
# |    ep_rew_mean          | -2.2e+03      |
# | time/                   |               |
# |    fps                  | 359           |
# |    iterations           | 19            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00058631727 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.16         |
# |    explained_variance   | -0.000211     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00364       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000199     |
# |    std                  | 0.969         |
# |    value_loss           | 1.47          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.34e+04     |
# |    ep_rew_mean          | -2.2e+03     |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 20           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0015565145 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | -0.00728     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000199     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000218    |
# |    std                  | 0.968        |
# |    value_loss           | 0.825        |
# ------------------------------------------
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.13e+04     |
# |    ep_rew_mean          | -3e+03       |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 21           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0006798589 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | -0.00954     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0112       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000275     |
# |    std                  | 0.968        |
# |    value_loss           | 0.967        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.13e+04     |
# |    ep_rew_mean          | -3e+03       |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 22           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0036831335 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | -0.0153      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00049     |
# |    std                  | 0.966        |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.13e+04      |
# |    ep_rew_mean          | -3e+03        |
# | time/                   |               |
# |    fps                  | 353           |
# |    iterations           | 23            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.7223298e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.15         |
# |    explained_variance   | -0.0249       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.797         |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 6.12e-05      |
# |    std                  | 0.965         |
# |    value_loss           | 5.08          |
# -------------------------------------------
#
#
#
#
# Eval num_timesteps=48800, episode_reward=-3757.10 +/- 0.00
# Episode length: 17503.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.75e+04      |
# |    mean_reward          | -3.76e+03     |
# | time/                   |               |
# |    total_timesteps      | 48800         |
# | train/                  |               |
# |    approx_kl            | 0.00071996317 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.15         |
# |    explained_variance   | -0.00469      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0286        |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000516     |
# |    std                  | 0.965         |
# |    value_loss           | 1.25          |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.13e+04 |
# |    ep_rew_mean     | -3e+03   |
# | time/              |          |
# |    fps             | 274      |
# |    iterations      | 24       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 49152    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.13e+04     |
# |    ep_rew_mean          | -3e+03       |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 25           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0052332142 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | -0.00518     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.204        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000706    |
# |    std                  | 0.962        |
# |    value_loss           | 1.04         |
# ------------------------------------------
#
#
# Logging to ./ppo15c50s_tensorboard_log/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 213  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0050633447 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00533      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00254     |
# |    std                  | 0.96         |
# |    value_loss           | 1.15         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0038473567 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0172       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.958        |
# |    value_loss           | 0.417        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.003617744 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.957       |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 5            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0037527164 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | -0.274       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0258       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 0.957        |
# |    value_loss           | 0.0845       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 6           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005633621 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | -0.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00124    |
# |    std                  | 0.953       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 322          |
# |    iterations           | 7            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0013141625 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.11        |
# |    explained_variance   | 0.264        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000538    |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000209    |
# |    std                  | 0.954        |
# |    value_loss           | 0.322        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 8           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005650022 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | -0.499      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00371     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.000964   |
# |    std                  | 0.956       |
# |    value_loss           | 0.238       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0055749584 |
# |    clip_fraction        | 0.00913      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | -0.336       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00494     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.956        |
# |    value_loss           | 0.202        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 10           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0023559383 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | -1.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000455     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000741    |
# |    std                  | 0.958        |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 11           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0035768016 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | -0.165       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00318     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 0.956        |
# |    value_loss           | 0.0548       |
# ------------------------------------------
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.28e+04     |
# |    ep_rew_mean          | -3.02e+03    |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 12           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0055776155 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 0.00935      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0181       |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.0031      |
# |    std                  | 0.956        |
# |    value_loss           | 0.0376       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.28e+04      |
# |    ep_rew_mean          | -3.02e+03     |
# | time/                   |               |
# |    fps                  | 335           |
# |    iterations           | 13            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00036088124 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.12         |
# |    explained_variance   | 0.137         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.181         |
# |    n_updates            | 620           |
# |    policy_gradient_loss | -9.35e-05     |
# |    std                  | 0.956         |
# |    value_loss           | 1.64          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.28e+04     |
# |    ep_rew_mean          | -3.02e+03    |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 14           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0011037609 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.11        |
# |    explained_variance   | 0.0636       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0364       |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.000627    |
# |    std                  | 0.947        |
# |    value_loss           | 0.148        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.28e+04     |
# |    ep_rew_mean          | -3.02e+03    |
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 15           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0042189383 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.08        |
# |    explained_variance   | 0.0815       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0408       |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00275     |
# |    std                  | 0.942        |
# |    value_loss           | 0.116        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.28e+04     |
# |    ep_rew_mean          | -3.02e+03    |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 16           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0012753613 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.07        |
# |    explained_variance   | 0.00615      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0236       |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.000403    |
# |    std                  | 0.939        |
# |    value_loss           | 0.55         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.28e+04      |
# |    ep_rew_mean          | -3.02e+03     |
# | time/                   |               |
# |    fps                  | 352           |
# |    iterations           | 17            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00065022055 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.06         |
# |    explained_variance   | 0.25          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0139        |
# |    n_updates            | 660           |
# |    policy_gradient_loss | -0.000205     |
# |    std                  | 0.938         |
# |    value_loss           | 0.997         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.28e+04      |
# |    ep_rew_mean          | -3.02e+03     |
# | time/                   |               |
# |    fps                  | 356           |
# |    iterations           | 18            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00049908424 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.06         |
# |    explained_variance   | 0.121         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0132        |
# |    n_updates            | 670           |
# |    policy_gradient_loss | 7.6e-05       |
# |    std                  | 0.936         |
# |    value_loss           | 1.33          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.28e+04      |
# |    ep_rew_mean          | -3.02e+03     |
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 19            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00037714545 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.05         |
# |    explained_variance   | -0.0134       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0449        |
# |    n_updates            | 680           |
# |    policy_gradient_loss | 8.39e-05      |
# |    std                  | 0.935         |
# |    value_loss           | 1.72          |
# -------------------------------------------
#
#
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.98e+04      |
# |    ep_rew_mean          | -3.3e+03      |
# | time/                   |               |
# |    fps                  | 347           |
# |    iterations           | 20            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00021937862 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.05         |
# |    explained_variance   | 0.011         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0631        |
# |    n_updates            | 690           |
# |    policy_gradient_loss | -0.000273     |
# |    std                  | 0.934         |
# |    value_loss           | 1.78          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.98e+04      |
# |    ep_rew_mean          | -3.3e+03      |
# | time/                   |               |
# |    fps                  | 348           |
# |    iterations           | 21            |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00080711907 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.05         |
# |    explained_variance   | 0.01          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.66          |
# |    n_updates            | 700           |
# |    policy_gradient_loss | -0.000569     |
# |    std                  | 0.935         |
# |    value_loss           | 7.38          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.98e+04      |
# |    ep_rew_mean          | -3.3e+03      |
# | time/                   |               |
# |    fps                  | 351           |
# |    iterations           | 22            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00033451585 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.06         |
# |    explained_variance   | 0.472         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0295        |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000234     |
# |    std                  | 0.935         |
# |    value_loss           | 1.84          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+04     |
# |    ep_rew_mean          | -3.3e+03     |
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 23           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0056315977 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.05        |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0225       |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.934        |
# |    value_loss           | 0.47         |
# ------------------------------------------

# %%
results_plotter.plot_results(
    [log_dir], 1e6, results_plotter.X_TIMESTEPS, "PPO - Env: Battery"
)

# %%
plot_results(log_dir)

# %% [markdown]
# # Test 1 episode of the model

# %%
model.save(os.path.join(log_dir, "best_model_ppo_batterysim15c15s"))


def test_trained_model():
    obs = model.get_env().reset()
    episode_reward = 0

    obsArray = []

    while True:
        obsArray.append(obs)
        action, _states = model.predict(obs)
        oldObs = obs
        obs, rewards, done, info = model.get_env().step(action)
        episode_reward += rewards.squeeze()

        if not done:
            print(str(oldObs) + "  ACTION:" + str(get_converted_action(action)[0]) + "  >>>> ")
            print(str(obs) + "  REWARD:  "  + str(rewards) + "   ")
        else:
            info_item = info.pop()
            print("FINAL: ")
            print(str(info_item.get('terminal_observation'))  + "       ACTION:" )
            print(str(str(get_converted_action(action.flatten()))))
            print("REWARD:  " + str(rewards[0]))
            print("EPISODE TOTAL REWARD: " + str(episode_reward))

            # plot final model
            fig = plt.figure(1)

            data_np = np.array(obsArray)

            plt.xlabel('Step')
            plt.ylabel('SOC')
            print("------------------------------------------------------")
            plt.ylim([-0.5, 1])


            i = 0
            for soc in data_np.T:
                plt.plot(np.arange(start=0, stop=len(data_np), step=1), soc.flatten(), label="soc"+str(i))
                i += 1

            plt.legend()
            #plt.pause(3)

            obsArray = []
            episode_reward = 0
            obs = model.get_env().reset()

            #time.sleep(0.5)
            break




test_trained_model()
# Out:
# [[0.8499998 0.8499998 0.8499998]]  ACTION:[0.24874777 0.43901855 0.60400367]  >>>>
# [[0.8496254  0.84957457 0.8495342 ]]  REWARD:  [0.01990883]
# [[0.8496254  0.84957457 0.8495342 ]]  ACTION:[0.3983578  0.91139925 0.45086655]  >>>>
# [[0.84914184 0.8489489  0.8490475 ]]  REWARD:  [0.01980704]
# [[0.84914184 0.8489489  0.8490475 ]]  ACTION:[0.70862 0.      1.     ]  >>>>
# [[0.84942704 0.8494349  0.8492445 ]]  REWARD:  [0.01980956]
# [[0.84942704 0.8494349  0.8492445 ]]  ACTION:[0.77250665 0.01544333 0.        ]  >>>>
# [[0.84839654 0.84863085 0.8484562 ]]  REWARD:  [0.01976573]
# [[0.84839654 0.84863085 0.8484562 ]]  ACTION:[0.37618738 0.         0.68196154]  >>>>
# [[0.84782076 0.8481682  0.8478078 ]]  REWARD:  [0.01963963]
# [[0.84782076 0.8481682  0.8478078 ]]  ACTION:[0.86216027 0.61217964 0.56915855]  >>>>
# [[0.8469583  0.84738547 0.8470484 ]]  REWARD:  [0.01957283]
# [[0.79363894 0.80766463 0.803001  ]]  ACTION:[0.732895 1.       0.      ]  >>>>
# [[0.7934283  0.80737996 0.80300266]]  REWARD:  [-0.00395164]
# [[0.7934283  0.80737996 0.80300266]]  ACTION:[0.38495448 0.02880287 0.14062902]  >>>>
# [[0.7930101  0.80706775 0.80266356]]  REWARD:  [-0.00405764]
# [[0.7930101  0.80706775 0.80266356]]  ACTION:[0.01240611 0.         0.82525325]  >>>>
# [[0.7926095 0.8066746 0.8020432]]  REWARD:  [-0.00406506]
# [[0.7926095 0.8066746 0.8020432]]  ACTION:[0.4616999 0.        1.       ]  >>>>
# [[0.7920987 0.8063008 0.8013927]]  REWARD:  [-0.0042021]
# [[0.7920987 0.8063008 0.8013927]]  ACTION:[0.15659446 0.25780058 0.15413868]  >>>>
# [[0.7916672  0.80584455 0.8009723 ]]  REWARD:  [-0.0041773]
# [[0.7916672  0.80584455 0.8009723 ]]  ACTION:[1.         0.         0.27862582]  >>>>
# [[0.79127413 0.80574155 0.80079234]]  REWARD:  [-0.00446744]
# [[0.79127413 0.80574155 0.80079234]]  ACTION:[0.92601824 0.7803016  0.551429  ]  >>>>
# [[0.7909701  0.8054824  0.80060154]]  REWARD:  [-0.00451227]
# [[0.7909701  0.8054824  0.80060154]]  ACTION:[0.         0.34478226 0.        ]  >>>>
# [[0.79072255 0.8051386  0.8003602 ]]  REWARD:  [-0.00441603]
# [[0.79072255 0.8051386  0.8003602 ]]  ACTION:[0.8705766  0.61887455 0.32255727]  >>>>
# [[0.7907466  0.80523497 0.80053896]]  REWARD:  [-0.00448839]
# [[0.7907466  0.80523497 0.80053896]]  ACTION:[1.         0.8217248  0.39731157]  >>>>
# [[0.7912216  0.8057576  0.80117387]]  REWARD:  [-0.00453593]
# [[0.7912216  0.8057576  0.80117387]]  ACTION:[0.7584328  0.20019203 0.        ]  >>>>
# [[0.790717   0.80541754 0.8008954 ]]  REWARD:  [-0.01470054]
# [[0.790717   0.80541754 0.8008954 ]]  ACTION:[0.9485426 0.6097995 0.463616 ]  >>>>
# [[0.79038364 0.8051846  0.8007071 ]]  REWARD:  [-0.01480098]
# [[0.79038364 0.8051846  0.8007071 ]]  ACTION:[0.33780736 0.         0.        ]  >>>>
# [[0.7902609  0.8051601  0.80068314]]  REWARD:  [-0.01489921]
# [[0.7902609  0.8051601  0.80068314]]  ACTION:[0.22839993 0.         0.        ]  >>>>
# [[0.790106   0.8050724  0.80059683]]  REWARD:  [-0.01496642]
# [[0.790106   0.8050724  0.80059683]]  ACTION:[1.        0.        0.0191915]  >>>>
# [[0.7901094 0.8053625 0.8008776]]  REWARD:  [-0.01525309]
# [[0.7901094 0.8053625 0.8008776]]  ACTION:[0.45815524 0.5145066  0.24737242]  >>>>
# [[0.78900224 0.80424964 0.7998559 ]]  REWARD:  [-0.01524735]
# [[0.78900224 0.80424964 0.7998559 ]]  ACTION:[0.9671897  0.05584189 0.        ]  >>>>
# [[0.78953177 0.80503607 0.80064696]]  REWARD:  [-0.01550428]
# [[0.78953177 0.80503607 0.80064696]]  ACTION:[0.11251694 0.16265878 0.        ]  >>>>
# [[0.78942555 0.8049166  0.8005754 ]]  REWARD:  [-0.01549106]
# [[0.78942555 0.8049166  0.8005754 ]]  ACTION:[0.35121608 0.7219717  1.        ]  >>>>
# [[0.7887218 0.8041135 0.7997052]]  REWARD:  [-0.01539167]
# [[0.7887218 0.8041135 0.7997052]]  ACTION:[0.         0.3369681  0.78305984]  >>>>
# [[0.78921604 0.8045074  0.79996765]]  REWARD:  [-0.01529132]
# [[0.78921604 0.8045074  0.79996765]]  ACTION:[0.7406488  0.01180995 0.35654604]  >>>>
# [[0.7885747 0.8040807 0.7994499]]  REWARD:  [-0.01550603]
# [[0.7885747 0.8040807 0.7994499]]  ACTION:[0.5603365 0.0631251 0.682717 ]  >>>>
# [[0.78757644 0.8032342  0.7984406 ]]  REWARD:  [-0.01565774]
# [[0.78757644 0.8032342  0.7984406 ]]  ACTION:[0.58171767 0.5593957  0.31460077]  >>>>
# [[0.78715414 0.8028224  0.79810387]]  REWARD:  [-0.01566824]
# [[0.78715414 0.8028224  0.79810387]]  ACTION:[1.        1.        0.5350863]  >>>>
# [[0.78628427 0.8019609  0.79738575]]  REWARD:  [-0.01567664]
# [[0.78628427 0.8019609  0.79738575]]  ACTION:[0.7523531 0.3725487 0.       ]  >>>>
# [[0.78680867 0.8025901  0.7981112 ]]  REWARD:  [-0.01578139]
# [[0.78680867 0.8025901  0.7981112 ]]  ACTION:[0.16756481 0.27511448 0.        ]  >>>>
# [[0.7872215  0.8029689  0.79856247]]  REWARD:  [-0.01574739]
# [[0.7872215  0.8029689  0.79856247]]  ACTION:[1.         0.         0.41726655]  >>>>
# [[0.78605986 0.8021044  0.7975925 ]]  REWARD:  [-0.01604452]
# [[0.78605986 0.8021044  0.7975925 ]]  ACTION:[1.         0.         0.73175347]  >>>>
# [[0.78514034 0.80147976 0.7967703 ]]  REWARD:  [-0.01633942]
# [[0.78514034 0.80147976 0.7967703 ]]  ACTION:[0.16683853 0.         0.02273187]  >>>>
# [[0.78500277 0.8013915  0.79667705]]  REWARD:  [-0.01638869]
# [[0.78500277 0.8013915  0.79667705]]  ACTION:[1.        0.6799416 0.       ]  >>>>
# [[0.78438634 0.8008726  0.79635763]]  REWARD:  [-0.01648627]
# [[0.78438634 0.8008726  0.79635763]]  ACTION:[0.40605032 0.5100633  0.4860344 ]  >>>>
# [[0.7838219  0.80028373 0.795784  ]]  REWARD:  [-0.01646186]
# [[0.7838219  0.80028373 0.795784  ]]  ACTION:[0.24305022 0.         0.8678893 ]  >>>>
# [[0.783466   0.8000009  0.79526037]]  REWARD:  [-0.01653496]
# [[0.783466   0.8000009  0.79526037]]  ACTION:[0.5203332  0.         0.48517236]  >>>>
# [[0.7830086  0.7996969  0.79482394]]  REWARD:  [-0.01668832]
# [[0.7830086  0.7996969  0.79482394]]  ACTION:[0.479642   0.03621486 0.93032634]  >>>>
# [[0.78272504 0.79954314 0.7944202 ]]  REWARD:  [-0.01681812]
# [[0.7573144  0.7820256  0.77350885]]  REWARD:  [-0.02471122]
# [[0.7573144  0.7820256  0.77350885]]  ACTION:[0.6021451  0.10944775 0.8228761 ]  >>>>
# [[0.75706017 0.781915   0.77319866]]  REWARD:  [-0.02485484]
# [[0.75706017 0.781915   0.77319866]]  ACTION:[1.         0.30187583 0.2672169 ]  >>>>
# [[0.75593877 0.78100413 0.77231044]]  REWARD:  [-0.02506532]
# [[0.75593877 0.78100413 0.77231044]]  ACTION:[0.94655913 0.         0.        ]  >>>>
# [[0.756421  0.7817537 0.7730495]]  REWARD:  [-0.02533271]
# [[0.756421  0.7817537 0.7730495]]  ACTION:[1.        0.5474402 0.       ]  >>>>
# [[0.7566743  0.7821349  0.77357984]]  REWARD:  [-0.02546059]
# [[0.7566743  0.7821349  0.77357984]]  ACTION:[1.         0.18638813 0.19084573]  >>>>
# [[0.7556185 0.7813219 0.7727772]]  REWARD:  [-0.02570339]
# [[0.7556185 0.7813219 0.7727772]]  ACTION:[0.08349794 0.         0.7420646 ]  >>>>
# [[0.7549455  0.7806792  0.77193433]]  REWARD:  [-0.02573366]
# [[0.7549455  0.7806792  0.77193433]]  ACTION:[0.7268893  0.82144636 0.8493084 ]  >>>>
# [[0.75457746 0.7802877  0.77154064]]  REWARD:  [-0.02571023]
# [[0.75457746 0.7802877  0.77154064]]  ACTION:[0.6855016  0.         0.09542358]  >>>>
# [[0.754115   0.78002596 0.77125585]]  REWARD:  [-0.025911]
# [[0.754115   0.78002596 0.77125585]]  ACTION:[0.34288275 0.         0.5172486 ]  >>>>
# [[0.75355554 0.77957    0.7706605 ]]  REWARD:  [-0.02601447]
# [[0.75355554 0.77957    0.7706605 ]]  ACTION:[0.37033665 1.         1.        ]  >>>>
# [[0.7531447  0.77898294 0.7700819 ]]  REWARD:  [-0.02583826]
# [[0.7531447  0.77898294 0.7700819 ]]  ACTION:[0.72101426 0.6903505  0.60895926]  >>>>
# [[0.7526431  0.77849495 0.76962394]]  REWARD:  [-0.02585185]
# [[0.7526431  0.77849495 0.76962394]]  ACTION:[0.5209565  0.405978   0.94481516]  >>>>
# [[0.7522731  0.77816147 0.7691433 ]]  REWARD:  [-0.0258884]
# [[0.7522731  0.77816147 0.7691433 ]]  ACTION:[1.         0.18925658 0.7807195 ]  >>>>
# [[0.7517696 0.7778949 0.7687137]]  REWARD:  [-0.02612532]
# [[0.7517696 0.7778949 0.7687137]]  ACTION:[0.2984963  0.77741957 0.8965745 ]  >>>>
# [[0.7514395  0.77743095 0.7682229 ]]  REWARD:  [-0.02599144]
# [[0.7514395  0.77743095 0.7682229 ]]  ACTION:[0.        0.8814844 0.       ]  >>>>
# [[0.7508827  0.77662706 0.76767933]]  REWARD:  [-0.02574439]
# [[0.7508827  0.77662706 0.76767933]]  ACTION:[0.4640503 0.        0.       ]  >>>>
# [[0.7502556 0.7761389 0.7671982]]  REWARD:  [-0.02588328]
# [[0.7502556 0.7761389 0.7671982]]  ACTION:[0.6377758 0.1859928 0.       ]  >>>>
# [[0.73826855 0.7674528  0.7573514 ]]  REWARD:  [-0.03918424]
# [[0.73826855 0.7674528  0.7573514 ]]  ACTION:[1.        0.        0.3493755]  >>>>
# [[0.73774123 0.7672168  0.75702035]]  REWARD:  [-0.03947559]
# [[0.73774123 0.7672168  0.75702035]]  ACTION:[0.63941866 0.213521   0.7386526 ]  >>>>
# [[0.7373499 0.7669512 0.7566105]]  REWARD:  [-0.03960131]
# [[0.7373499 0.7669512 0.7566105]]  ACTION:[0.8932514  0.00907469 0.        ]  >>>>
# [[0.7368344 0.7666938 0.7563595]]  REWARD:  [-0.03985934]
# [[0.7368344 0.7666938 0.7563595]]  ACTION:[0.35078618 0.         0.903358  ]  >>>>
# [[0.73618764 0.7661535  0.7555721 ]]  REWARD:  [-0.03996588]
# [[0.73618764 0.7661535  0.7555721 ]]  ACTION:[0.24650443 0.         0.6297075 ]  >>>>
# [[0.7356046  0.7656467  0.75489473]]  REWARD:  [-0.04004209]
# [[0.7356046  0.7656467  0.75489473]]  ACTION:[0.09378642 0.         0.        ]  >>>>
# [[0.7348213  0.76489764 0.7541564 ]]  REWARD:  [-0.04007632]
# [[0.7348213  0.76489764 0.7541564 ]]  ACTION:[1.        0.6307716 0.9137069]  >>>>
# [[0.7341269  0.76431566 0.7535029 ]]  REWARD:  [-0.04018871]
# [[0.7341269  0.76431566 0.7535029 ]]  ACTION:[0.2508461  0.7107136  0.39678365]  >>>>
# [[0.7343275  0.76438326 0.75365824]]  REWARD:  [-0.04005582]
# [[0.7343275  0.76438326 0.75365824]]  ACTION:[1.         1.         0.02300161]  >>>>
# [[0.7337621  0.76382333 0.75338215]]  REWARD:  [-0.04006122]
# [[0.7337621  0.76382333 0.75338215]]  ACTION:[1.       0.       0.792781]  >>>>
# [[0.732983   0.76333785 0.75267994]]  REWARD:  [-0.04035484]
# [[0.732983   0.76333785 0.75267994]]  ACTION:[0.0557307 0.        1.       ]  >>>>
# [[0.73263437 0.76300853 0.7520732 ]]  REWARD:  [-0.04037417]
# [[0.73263437 0.76300853 0.7520732 ]]  ACTION:[0.78907955 0.         0.715765  ]  >>>>
# [[0.7320131 0.762619  0.7514874]]  REWARD:  [-0.04060595]
# [[0.7320131 0.762619  0.7514874]]  ACTION:[0.76364887 0.         0.5005161 ]  >>>>
# [[0.7316126  0.76244116 0.75117093]]  REWARD:  [-0.04082852]
# [[0.7316126  0.76244116 0.75117093]]  ACTION:[0.33842486 0.3749704  0.73268473]  >>>>
# [[0.7313559 0.7621765 0.7508093]]  REWARD:  [-0.04082061]
# [[0.7313559 0.7621765 0.7508093]]  ACTION:[0.25219464 0.8192255  0.        ]  >>>>
# [[0.7311953  0.76185536 0.7507241 ]]  REWARD:  [-0.04066008]
# [[0.7311953  0.76185536 0.7507241 ]]  ACTION:[1.       0.       0.659968]  >>>>
# [[0.7308836  0.76183313 0.75051606]]  REWARD:  [-0.04094953]
# [[0.7308836  0.76183313 0.75051606]]  ACTION:[1.         0.11488914 0.8961073 ]  >>>>
# [[0.20878461 0.7542833  0.424822  ]]  ACTION:[0.66784865 0.         0.        ]  >>>>
# [[0.20829512 0.75398976 0.42453277]]  REWARD:  [-0.5556946]
# [[0.20829512 0.75398976 0.42453277]]  ACTION:[0.75720924 0.56169856 0.6553322 ]  >>>>
# [[0.20789629 0.7536508  0.42417237]]  REWARD:  [-0.5557545]
# [[0.20789629 0.7536508  0.42417237]]  ACTION:[1.         0.10502213 0.06637233]  >>>>
# [[0.20762895 0.7536424  0.42417523]]  REWARD:  [-0.55601346]
# [[0.20762895 0.7536424  0.42417523]]  ACTION:[0.7302275  0.80344915 0.        ]  >>>>
# [[0.20708524 0.7530829  0.4238506 ]]  REWARD:  [-0.5559976]
# [[0.20708524 0.7530829  0.4238506 ]]  ACTION:[0.7957009  0.80989116 0.34875515]  >>>>
# [[0.20745304 0.75344396 0.4243368 ]]  REWARD:  [-0.55599093]
# [[0.20745304 0.75344396 0.4243368 ]]  ACTION:[0.6281762  0.37492865 0.95556986]  >>>>
# [[0.20786321 0.75392354 0.42464572]]  REWARD:  [-0.5560603]
# [[0.20786321 0.75392354 0.42464572]]  ACTION:[0.32501665 0.6511326  0.5763752 ]  >>>>
# [[0.20754755 0.7535176  0.42426687]]  REWARD:  [-0.5559701]
# [[0.20754755 0.7535176  0.42426687]]  ACTION:[0.28740063 0.66185355 0.6484471 ]  >>>>
# [[0.20754752 0.75341094 0.4241655 ]]  REWARD:  [-0.5558634]
# [[0.20754752 0.75341094 0.4241655 ]]  ACTION:[1.         0.41992956 0.7430322 ]  >>>>
# [[0.20712146 0.7531551  0.42382228]]  REWARD:  [-0.5560337]
# [[0.20712146 0.7531551  0.42382228]]  ACTION:[1.         0.28488535 0.14787647]  >>>>
# [[0.20684199 0.7530834  0.42379034]]  REWARD:  [-0.55624145]
# [[0.20684199 0.7530834  0.42379034]]  ACTION:[0.9980111  0.28166533 0.3326472 ]  >>>>
# [[0.20650181 0.7529517  0.4236463 ]]  REWARD:  [-0.5564499]
# [[0.20650181 0.7529517  0.4236463 ]]  ACTION:[0.21063259 0.         0.4883775 ]  >>>>
# [[0.20590597 0.7524221  0.42298636]]  REWARD:  [-0.5565162]
# [[0.20590597 0.7524221  0.42298636]]  ACTION:[1.        0.0924238 0.       ]  >>>>
# [[0.20611794 0.75289255 0.42347634]]  REWARD:  [-0.5567746]
# [[0.20611794 0.75289255 0.42347634]]  ACTION:[0.41127402 0.         0.32598186]  >>>>
# [[0.20567802 0.75257456 0.42307106]]  REWARD:  [-0.55689657]
# [[0.20567802 0.75257456 0.42307106]]  ACTION:[0.79541945 0.3005292  0.        ]  >>>>
# [[0.20505701 0.7521012  0.42268938]]  REWARD:  [-0.5570442]
# [[0.20505701 0.7521012  0.42268938]]  ACTION:[0.7828114  0.2731231  0.76935863]  >>>>
# [[0.20535123 0.7525393  0.42298126]]  REWARD:  [-0.55718803]
# [[0.20535123 0.7525393  0.42298126]]  ACTION:[0.17946619 0.26378727 0.14974776]  >>>>
# [[0.20444192 0.75161433 0.4221017 ]]  REWARD:  [-0.5571724]
# [[0.18564948 0.73467463 0.4048573 ]]  ACTION:[0.77685195 0.21187598 0.6979965 ]  >>>>
# [[0.18515654 0.7343482  0.40439847]]  REWARD:  [-0.55919164]
# [[0.18515654 0.7343482  0.40439847]]  ACTION:[0.4116634  0.         0.28860927]  >>>>
# [[0.18480521 0.7341181  0.4040904 ]]  REWARD:  [-0.55931294]
# [[0.18480521 0.7341181  0.4040904 ]]  ACTION:[0.54576826 0.4832515  0.68490034]  >>>>
# [[0.18435124 0.7336864  0.40360808]]  REWARD:  [-0.5593351]
# [[0.18435124 0.7336864  0.40360808]]  ACTION:[0.49022678 0.57052857 0.56043154]  >>>>
# [[0.18389991 0.73321635 0.40314776]]  REWARD:  [-0.55931646]
# [[0.18389991 0.73321635 0.40314776]]  ACTION:[0.6690037  0.81498164 0.        ]  >>>>
# [[0.18301083 0.73229384 0.40246844]]  REWARD:  [-0.559283]
# [[0.18301083 0.73229384 0.40246844]]  ACTION:[0.8528274  0.47532946 0.26663154]  >>>>
# [[0.18691549 0.7362746  0.4064505 ]]  REWARD:  [-0.5593591]
# [[0.18691549 0.7362746  0.4064505 ]]  ACTION:[0.36549538 0.20822427 0.13171539]  >>>>
# [[0.19096093 0.74033177 0.41047063]]  REWARD:  [-0.5593708]
# [[0.19096093 0.74033177 0.41047063]]  ACTION:[1.         0.13027796 0.7156665 ]  >>>>
# [[0.19482306 0.7444113  0.41432592]]  REWARD:  [-0.55958825]
# [[0.19482306 0.7444113  0.41432592]]  ACTION:[0. 0. 0.]  >>>>
# [[0.19897412 0.7485281  0.41838324]]  REWARD:  [-0.559554]
# [[0.19897412 0.7485281  0.41838324]]  ACTION:[0.        0.        0.4864267]  >>>>
# [[0.20312516 0.7526449  0.42230323]]  REWARD:  [-0.55951977]
# [[0.20312516 0.7526449  0.42230323]]  ACTION:[0.87949157 0.         0.        ]  >>>>
# [[0.2070221  0.7567617  0.42636055]]  REWARD:  [-0.55973965]
# [[0.2070221  0.7567617  0.42636055]]  ACTION:[0.5812231  0.8341292  0.00902843]  >>>>
# [[0.21100523 0.7606397  0.4304153 ]]  REWARD:  [-0.5596345]
# [[0.21100523 0.7606397  0.4304153 ]]  ACTION:[1.        0.8079628 1.       ]  >>>>
# [[0.21486734 0.7645253  0.43419033]]  REWARD:  [-0.55965793]
# [[0.21486734 0.7645253  0.43419033]]  ACTION:[1.         0.         0.96009135]  >>>>
# [[0.21872947 0.76864207 0.43797663]]  REWARD:  [-0.5599126]
# [[0.21872947 0.76864207 0.43797663]]  ACTION:[1. 1. 1.]  >>>>
# [[0.2225916  0.7724726  0.44175166]]  REWARD:  [-0.55988103]
# [[0.2225916  0.7724726  0.44175166]]  ACTION:[1.         0.         0.38467017]  >>>>
# [[0.2264537  0.77658945 0.44570038]]  REWARD:  [-0.5601357]
#
#
# FINAL:
# [0.2264537  0.77658945 0.44570038]       ACTION:
# [0.6099920719861984, 0.0, 0.4997717794030905]
# REWARD:  -0.5601357
# EPISODE TOTAL REWARD: -2998.392349673346
# ------------------------------------------------------
