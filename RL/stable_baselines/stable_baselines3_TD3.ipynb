# %%
# Python 3.9. Anaconda recommended.
# -- Prerequisites install 
# %pip install ipykernel --user
# %pip install stable_baselines3 --user
# %pip install tensorboard --user
# %pip install torch --index-url https://download.pytorch.org/whl/cu117 --upgrade --force-reinstall --trusted-host pypi.org --trusted-host pytorch.org --trusted-host download.pytorch.org --no-cache --user
# Out:
# Requirement already satisfied: stable_baselines3 in c:\users\matei\appdata\roaming\python\python311\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (2.2.0)
# Requirement already satisfied: cloudpickle in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (2.2.0)
# Requirement already satisfied: matplotlib in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (3.8.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matei\appdata\roaming\python\python311\site-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\matei\appdata\roaming\python\python311\site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# ^C
# Requirement already satisfied: ipykernel in c:\users\matei\appdata\roaming\python\python311\site-packages (6.29.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (8.21.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.14.1)
# Requirement already satisfied: decorator in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: colorama in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\matei\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: tensorboard in c:\users\matei\appdata\roaming\python\python311\site-packages (2.16.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.60.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (3.5.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\envs\stable_baselines\lib\site-packages (from tensorboard) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)

# %% [markdown]
# # STABLEBASELINES TESTBED

# %%
# Battery env 
import gymnasium as gym
import numpy as np
from typing import Optional, Union
import itertools



#class BatteryEnv(gym.Env[np.ndarray, Union[int, np.ndarray]]):

class BatteryEnv(gym.Env):

   def __init__(self, nr_batteries, render_mode: Optional[str] = None):
      super().__init__()

      self.env_id = "Battery v0.4"
      self.num_envs = 1
      
      
      self.nr_batteries = nr_batteries


      self.soc_threshold_upper = 0.85
      self.soc_threshold_lower = 0.15


      self.action_space = gym.spaces.Box(-1, 1, (self.nr_batteries,), dtype=np.float32)       # current applied to cell1,cell2,cell3...
      self.observation_space = gym.spaces.Box(0, 1, (self.nr_batteries,), dtype=np.float32)   # SOCs for cell1, cell2, cell3...


      self.episode_time = 0
      self.state = None
      



   def step(self, action):
      err_msg = f"{action!r} ({type(action)}) invalid"
      assert self.action_space.contains(action), err_msg
      assert self.state is not None, "Call reset before using step method."


      battery_current_values = get_converted_action(action)


      self.episode_time += 1
      passed_threshold = False
      terminated = False
      truncated = False

      #Apply action to state
      self.state = np.subtract(self.state, battery_current_values)         

      for soc in self.state:

         if (soc < self.soc_threshold_lower or soc > self.soc_threshold_upper):
            passed_threshold = True
         if (soc < 0 or soc > 100):
            # Sanity check. Should never happen.
            soc = 0.0
            print("//////// EXITED OBSERVATION SPACE BOUNDS ////////  "  + str(soc))



      # Compute reward and termination cases
      reward = 0
      if not passed_threshold and self.episode_time == 128:
         # Apply step reward. Timeout.
         reward = compute_ballancing_reward(self.state, False)

         self.episode_time = 0
         truncated = True

      elif not passed_threshold:
         # Apply step reward. Continue running.
         reward = compute_ballancing_reward(self.state, False)

      
      elif passed_threshold:
         # Batteries drained! Terminated.
         reward = float(-100)
         terminated = True


      # Return modified
      return np.array(self.state, dtype=np.float32), float(reward), terminated, truncated, {}
   

       


   def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,):
        
         super().reset(seed=seed)



         self.episode_time = 0


         # Get random initial state for the episode.
         self.state = self.np_random.uniform(low=0.50, high=0.85, size=(self.nr_batteries,))


         return np.array(self.state, dtype=np.float32), {}



#CONVERT ACTION
   
def get_converted_action(action):
   current_values = []
   for current in action:
      shifted_value = ((current + 1.0) * 5.0)/100.0  #from [-1, 1] to [0, 0.1], to be reduced from SoC
      current_values.append(shifted_value)

   return current_values


# REWARD CALCULATION HELPERS 

def compute_closeness(socs):
   mean = 0
   for soc in socs:
      mean += soc
   mean = mean/len(socs)

   mean_diff = 0
   for  soc in socs:
      mean_diff += abs(mean - soc)

   mean_diff /= len(socs)

   min = np.array(socs).min()
   max = np.array(socs).max()
   abs_diff_min_max = max - min


   # alternative: (mean_diff_from_mean), or (mean_diff_from_mean*05 + abs_diff_min_max*0.5)
   return abs_diff_min_max

# Closeness function debug code
numbers = [0.6, 0.5, 0.8, 0.65, 0.85]
print(compute_closeness(numbers))
print(np.std(numbers, dtype=np.float32))  # standard deviation






# Get reward for a given step
def compute_ballancing_reward(socs, should_print):

   # ---- REWARD ALTERNATIVES ----

   # 1. Cost as distance between 2 numbers. Yang
   #reward = -pow(soc0 - soc1, 2)
      
   # 2. Cost as standard deviation
   # reward = -np.std(normalized_socs, dtype=np.float32)

   # ---- REWARD ALTERNATIVES ----


   

   reward = 0

   # Give 0.2 for each pair of SOCs that are within 0.02 distance of eachother.
   for i in range(len(socs)):
      for j in range(i + 1, len(socs)):
         if (math.isclose(socs[i], socs[j], abs_tol=0.02)):
            reward += 0.2
   
   # Introduce closeness to the reward
   reward = reward - compute_closeness(socs)
             
   return reward
# Out:
# 0.35
# 0.12884098

# %% [markdown]
# # PLOTTING FUNCTIONS:

# %%
import matplotlib.pyplot as plt
from IPython import display



def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    # plt.show()

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
import stable_baselines3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback


import os
import torch
import math
import numpy as np
from typing import Optional, Union




class PlotResultsCallback(BaseCallback):

    def __init__(self, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.log_dir = log_dir
        self.save_path = None

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        plot_results(self.log_dir)

        return True

# %% [markdown]
# # Initialize environment

# %%
# !pip install gymnasium[box2d]
import gymnasium as gym
from stable_baselines3.common.env_checker import check_env


# Create log dir
log_dir = "./tmp/gym/td3test/"
os.makedirs(log_dir, exist_ok=True)


# Create and wrap the environment
env = BatteryEnv(20, False)

for i in range(0, 30):
    check_env(env)


# Logs will be saved in log_dir/monitor.csv 
env = Monitor(env, log_dir) #monitor for raw environments

# %% [markdown]
# # Opt1: Initialize a new model

# %%
from stable_baselines3 import A2C, SAC, PPO, TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise


print("Is CUDA enabled?", torch.cuda.is_available())


n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = TD3('MlpPolicy', env, verbose=0, device="cuda", action_noise=action_noise, tensorboard_log="./td3_tensorboard_log/")
# Out:
# Is CUDA enabled? True

# %% [markdown]
# # Opt 2: Load existing trained model from save file

# %%
from stable_baselines3 import A2C, SAC, PPO, TD3

model = TD3.load(env=env, path=os.path.join(log_dir, "best_model_td3"))

# %% [markdown]
# Train model for X timesteps.
# Can be interrupted and retain training.

# %%
from stable_baselines3.common import results_plotter
from stable_baselines3 import A2C, SAC, PPO, TD3


callback = EvalCallback(env, log_path=log_dir, n_eval_episodes= 50, eval_freq= 25*128,
                            best_model_save_path=os.path.join(log_dir, "best_model_td3-n"),
                            callback_on_new_best=PlotResultsCallback(log_dir=log_dir))
# Eval callback, for plotting and seeing how the training is going, and saving best models. No effect on the results.

model.learn(total_timesteps=int(300000000000000000), callback=callback)


# Plot helper from the library
results_plotter.plot_results(
    [log_dir], 1e7, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
)
# Out:
# Eval num_timesteps=918400, episode_reward=595.52 +/- 132.56
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=921600, episode_reward=536.82 +/- 110.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=924800, episode_reward=619.78 +/- 191.18
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=928000, episode_reward=531.37 +/- 98.05
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=931200, episode_reward=501.92 +/- 100.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=934400, episode_reward=608.86 +/- 141.60
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=937600, episode_reward=573.94 +/- 119.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=940800, episode_reward=587.91 +/- 146.46
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=944000, episode_reward=579.26 +/- 159.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=947200, episode_reward=529.99 +/- 112.84
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=950400, episode_reward=579.00 +/- 132.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=953600, episode_reward=614.09 +/- 135.95
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=956800, episode_reward=608.15 +/- 142.14
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=960000, episode_reward=573.99 +/- 108.29
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=963200, episode_reward=635.59 +/- 176.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=966400, episode_reward=581.34 +/- 152.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=969600, episode_reward=615.53 +/- 135.21
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=972800, episode_reward=641.65 +/- 141.96
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=976000, episode_reward=631.30 +/- 171.95
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=979200, episode_reward=541.56 +/- 127.36
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=982400, episode_reward=524.31 +/- 138.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=985600, episode_reward=559.24 +/- 96.30
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=988800, episode_reward=511.54 +/- 101.59
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=992000, episode_reward=398.92 +/- 76.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=995200, episode_reward=515.62 +/- 131.58
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=998400, episode_reward=546.87 +/- 152.32
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1001600, episode_reward=486.96 +/- 115.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1004800, episode_reward=529.33 +/- 118.62
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1008000, episode_reward=547.73 +/- 135.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1011200, episode_reward=581.58 +/- 112.31
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1014400, episode_reward=535.63 +/- 113.97
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1017600, episode_reward=540.52 +/- 130.52
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1020800, episode_reward=645.15 +/- 175.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1024000, episode_reward=585.92 +/- 178.50
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1027200, episode_reward=552.25 +/- 125.16
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1030400, episode_reward=603.94 +/- 166.15
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1033600, episode_reward=612.22 +/- 150.48
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1036800, episode_reward=597.21 +/- 139.84
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1040000, episode_reward=537.00 +/- 127.50
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1043200, episode_reward=578.36 +/- 125.47
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1046400, episode_reward=442.13 +/- 121.20
# Episode length: 125.88 +/- 14.84
# Eval num_timesteps=1049600, episode_reward=399.84 +/- 132.99
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1052800, episode_reward=498.20 +/- 102.62
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1056000, episode_reward=471.11 +/- 85.95
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1059200, episode_reward=526.62 +/- 123.86
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1062400, episode_reward=438.08 +/- 95.45
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1065600, episode_reward=482.46 +/- 123.09
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1068800, episode_reward=499.36 +/- 105.35
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1072000, episode_reward=474.82 +/- 115.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1075200, episode_reward=311.28 +/- 86.61
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1078400, episode_reward=355.60 +/- 110.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1081600, episode_reward=97.97 +/- 105.02
# Episode length: 87.30 +/- 30.58
# Eval num_timesteps=1084800, episode_reward=356.98 +/- 119.56
# Episode length: 122.48 +/- 14.92
# Eval num_timesteps=1088000, episode_reward=395.91 +/- 96.60
# Episode length: 125.06 +/- 11.59
# Eval num_timesteps=1091200, episode_reward=-90.73 +/- 2.90
# Episode length: 4.80 +/- 0.82
# Eval num_timesteps=1094400, episode_reward=-92.23 +/- 2.76
# Episode length: 4.34 +/- 0.47
# Eval num_timesteps=1097600, episode_reward=-90.47 +/- 3.36
# Episode length: 4.48 +/- 0.64
# Eval num_timesteps=1100800, episode_reward=-91.70 +/- 2.73
# Episode length: 4.44 +/- 0.61
# Eval num_timesteps=1104000, episode_reward=-91.48 +/- 3.01
# Episode length: 4.50 +/- 0.57
# Eval num_timesteps=1107200, episode_reward=-90.08 +/- 3.43
# Episode length: 4.58 +/- 0.67
# Eval num_timesteps=1110400, episode_reward=-86.62 +/- 4.72
# Episode length: 5.26 +/- 0.91
# Eval num_timesteps=1113600, episode_reward=-89.57 +/- 3.38
# Episode length: 4.72 +/- 0.63
# Eval num_timesteps=1116800, episode_reward=-91.25 +/- 2.89
# Episode length: 4.48 +/- 0.50
# Eval num_timesteps=1120000, episode_reward=-92.79 +/- 2.37
# Episode length: 4.20 +/- 0.40
# Eval num_timesteps=1123200, episode_reward=-87.06 +/- 5.26
# Episode length: 5.22 +/- 0.94
# Eval num_timesteps=1126400, episode_reward=-84.98 +/- 4.83
# Episode length: 5.76 +/- 0.93
# Eval num_timesteps=1129600, episode_reward=-83.75 +/- 5.90
# Episode length: 5.74 +/- 1.00
# Eval num_timesteps=1132800, episode_reward=458.62 +/- 116.16
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1136000, episode_reward=417.00 +/- 124.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1139200, episode_reward=427.63 +/- 75.60
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1142400, episode_reward=419.54 +/- 100.27
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1145600, episode_reward=459.27 +/- 111.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1148800, episode_reward=513.36 +/- 106.95
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1152000, episode_reward=353.90 +/- 72.76
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1155200, episode_reward=431.41 +/- 81.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1158400, episode_reward=302.28 +/- 111.58
# Episode length: 123.68 +/- 15.26
# Eval num_timesteps=1161600, episode_reward=202.42 +/- 108.20
# Episode length: 118.60 +/- 18.90
# Eval num_timesteps=1164800, episode_reward=308.04 +/- 135.57
# Episode length: 119.16 +/- 25.31
# Eval num_timesteps=1168000, episode_reward=301.14 +/- 108.15
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1171200, episode_reward=415.98 +/- 115.96
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1174400, episode_reward=331.89 +/- 119.10
# Episode length: 124.42 +/- 14.17
# Eval num_timesteps=1177600, episode_reward=437.30 +/- 105.72
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1180800, episode_reward=416.87 +/- 90.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1184000, episode_reward=490.55 +/- 105.23
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1187200, episode_reward=422.18 +/- 110.37
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1190400, episode_reward=295.77 +/- 150.92
# Episode length: 115.88 +/- 27.05
# Eval num_timesteps=1193600, episode_reward=384.62 +/- 89.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1196800, episode_reward=432.20 +/- 105.65
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1200000, episode_reward=459.19 +/- 105.35
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1203200, episode_reward=508.56 +/- 142.40
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1206400, episode_reward=540.93 +/- 143.28
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1209600, episode_reward=439.40 +/- 135.39
# Episode length: 126.32 +/- 11.76
# Eval num_timesteps=1212800, episode_reward=527.50 +/- 161.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1216000, episode_reward=527.34 +/- 127.40
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1219200, episode_reward=494.50 +/- 133.23
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1222400, episode_reward=510.27 +/- 112.03
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1225600, episode_reward=479.07 +/- 121.26
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1228800, episode_reward=510.83 +/- 115.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1232000, episode_reward=530.07 +/- 174.44
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1235200, episode_reward=523.58 +/- 127.23
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1238400, episode_reward=535.52 +/- 84.91
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1241600, episode_reward=531.96 +/- 106.79
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1244800, episode_reward=528.36 +/- 110.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1248000, episode_reward=520.71 +/- 128.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1251200, episode_reward=549.19 +/- 136.67
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1254400, episode_reward=523.74 +/- 122.01
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1257600, episode_reward=514.88 +/- 148.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1260800, episode_reward=521.32 +/- 140.33
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1264000, episode_reward=512.35 +/- 102.85
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1267200, episode_reward=498.94 +/- 123.03
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1270400, episode_reward=510.70 +/- 119.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1273600, episode_reward=483.09 +/- 113.10
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1276800, episode_reward=536.38 +/- 126.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1280000, episode_reward=516.18 +/- 122.53
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1283200, episode_reward=465.52 +/- 111.88
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1286400, episode_reward=476.90 +/- 134.92
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1289600, episode_reward=466.33 +/- 127.16
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1292800, episode_reward=443.94 +/- 88.99
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1296000, episode_reward=519.34 +/- 108.24
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1299200, episode_reward=502.52 +/- 116.12
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1302400, episode_reward=542.20 +/- 139.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1305600, episode_reward=462.62 +/- 98.54
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1308800, episode_reward=474.39 +/- 116.91
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1312000, episode_reward=481.31 +/- 116.56
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1315200, episode_reward=376.73 +/- 132.66
# Episode length: 123.00 +/- 17.80
# Eval num_timesteps=1318400, episode_reward=464.56 +/- 111.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1321600, episode_reward=379.17 +/- 120.82
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1324800, episode_reward=381.88 +/- 129.59
# Episode length: 124.96 +/- 15.85
# Eval num_timesteps=1328000, episode_reward=371.15 +/- 135.42
# Episode length: 124.84 +/- 13.28
# Eval num_timesteps=1331200, episode_reward=152.72 +/- 222.47
# Episode length: 69.82 +/- 52.01
# Eval num_timesteps=1334400, episode_reward=205.78 +/- 196.58
# Episode length: 86.28 +/- 47.83
# Eval num_timesteps=1337600, episode_reward=296.86 +/- 177.38
# Episode length: 110.50 +/- 34.69
# Eval num_timesteps=1340800, episode_reward=258.44 +/- 200.15
# Episode length: 102.62 +/- 39.86
# Eval num_timesteps=1344000, episode_reward=232.64 +/- 188.18
# Episode length: 98.12 +/- 40.37
# Eval num_timesteps=1347200, episode_reward=90.85 +/- 167.09
# Episode length: 66.38 +/- 50.35
# Eval num_timesteps=1350400, episode_reward=280.37 +/- 232.16
# Episode length: 95.70 +/- 48.66
# Eval num_timesteps=1353600, episode_reward=307.99 +/- 156.08
# Episode length: 116.94 +/- 31.17
# Eval num_timesteps=1356800, episode_reward=415.85 +/- 122.05
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1360000, episode_reward=341.02 +/- 125.30
# Episode length: 126.36 +/- 6.54
# Eval num_timesteps=1363200, episode_reward=363.05 +/- 95.21
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1366400, episode_reward=374.04 +/- 94.93
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1369600, episode_reward=357.36 +/- 75.22
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1372800, episode_reward=359.71 +/- 134.73
# Episode length: 125.62 +/- 16.66
# Eval num_timesteps=1376000, episode_reward=410.96 +/- 118.78
# Episode length: 125.74 +/- 15.82
# Eval num_timesteps=1379200, episode_reward=451.72 +/- 103.14
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1382400, episode_reward=447.94 +/- 99.05
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1385600, episode_reward=469.74 +/- 91.09
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1388800, episode_reward=477.05 +/- 143.81
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1392000, episode_reward=473.19 +/- 107.83
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1395200, episode_reward=498.75 +/- 88.79
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1398400, episode_reward=498.58 +/- 91.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1401600, episode_reward=522.16 +/- 140.73
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1404800, episode_reward=518.23 +/- 141.98
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1408000, episode_reward=540.36 +/- 106.65
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1776000, episode_reward=441.70 +/- 119.94
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1779200, episode_reward=388.29 +/- 111.23
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1782400, episode_reward=351.77 +/- 113.55
# Episode length: 125.16 +/- 16.79
# Eval num_timesteps=1785600, episode_reward=335.54 +/- 102.67
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1788800, episode_reward=315.58 +/- 115.64
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1792000, episode_reward=346.93 +/- 101.59
# Episode length: 127.94 +/- 0.42
# Eval num_timesteps=1795200, episode_reward=423.28 +/- 110.24
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1798400, episode_reward=418.23 +/- 125.65
# Episode length: 127.16 +/- 5.88
# Eval num_timesteps=1801600, episode_reward=445.88 +/- 112.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1804800, episode_reward=360.43 +/- 107.92
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1808000, episode_reward=456.85 +/- 102.65
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1811200, episode_reward=437.98 +/- 111.25
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1814400, episode_reward=437.92 +/- 105.56
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1817600, episode_reward=394.02 +/- 148.79
# Episode length: 127.82 +/- 1.26
# Eval num_timesteps=1820800, episode_reward=395.87 +/- 114.88
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1824000, episode_reward=468.20 +/- 116.51
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1827200, episode_reward=192.70 +/- 229.48
# Episode length: 79.74 +/- 56.54
# Eval num_timesteps=1830400, episode_reward=451.02 +/- 110.04
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1833600, episode_reward=463.24 +/- 98.19
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1836800, episode_reward=395.25 +/- 99.95
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1840000, episode_reward=419.48 +/- 136.54
# Episode length: 125.64 +/- 16.24
# Eval num_timesteps=1843200, episode_reward=443.64 +/- 137.10
# Episode length: 123.98 +/- 20.04
# Eval num_timesteps=1846400, episode_reward=457.89 +/- 119.11
# Episode length: 126.32 +/- 11.76
# Eval num_timesteps=1849600, episode_reward=441.31 +/- 106.05
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1852800, episode_reward=403.74 +/- 144.69
# Episode length: 122.42 +/- 22.57
# Eval num_timesteps=1856000, episode_reward=446.40 +/- 124.81
# Episode length: 125.24 +/- 14.10
# Eval num_timesteps=1859200, episode_reward=468.41 +/- 130.76
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1862400, episode_reward=437.63 +/- 162.22
# Episode length: 125.58 +/- 16.94
# Eval num_timesteps=1865600, episode_reward=500.92 +/- 124.70
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1868800, episode_reward=473.54 +/- 112.28
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1872000, episode_reward=507.38 +/- 145.03
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1875200, episode_reward=458.23 +/- 108.85
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1878400, episode_reward=455.01 +/- 124.93
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1881600, episode_reward=456.29 +/- 132.91
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1884800, episode_reward=476.72 +/- 104.30
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1888000, episode_reward=472.54 +/- 113.52
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1891200, episode_reward=419.29 +/- 156.80
# Episode length: 127.22 +/- 5.46
# Eval num_timesteps=1894400, episode_reward=483.31 +/- 139.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1897600, episode_reward=463.87 +/- 145.33
# Episode length: 125.82 +/- 15.26
# Eval num_timesteps=1900800, episode_reward=358.50 +/- 151.58
# Episode length: 115.92 +/- 31.46
# Eval num_timesteps=1904000, episode_reward=497.40 +/- 157.56
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1907200, episode_reward=308.50 +/- 207.11
# Episode length: 105.08 +/- 40.27
# Eval num_timesteps=1910400, episode_reward=370.60 +/- 153.58
# Episode length: 121.60 +/- 25.53
# Eval num_timesteps=1913600, episode_reward=389.24 +/- 119.97
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1916800, episode_reward=420.26 +/- 83.26
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1920000, episode_reward=479.51 +/- 110.60
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1923200, episode_reward=485.90 +/- 123.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1926400, episode_reward=447.60 +/- 105.33
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1929600, episode_reward=485.37 +/- 121.98
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1932800, episode_reward=322.88 +/- 257.08
# Episode length: 94.50 +/- 48.40
# Eval num_timesteps=1936000, episode_reward=404.09 +/- 137.95
# Episode length: 124.30 +/- 15.68
# Eval num_timesteps=1939200, episode_reward=496.27 +/- 99.13
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1942400, episode_reward=501.72 +/- 104.04
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1945600, episode_reward=514.02 +/- 116.72
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1948800, episode_reward=505.56 +/- 101.88
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1952000, episode_reward=463.62 +/- 99.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1955200, episode_reward=460.88 +/- 106.90
# Episode length: 126.84 +/- 8.12
# Eval num_timesteps=1958400, episode_reward=490.33 +/- 148.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1961600, episode_reward=483.32 +/- 118.91
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1964800, episode_reward=502.93 +/- 106.32
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1968000, episode_reward=528.26 +/- 142.12
# Episode length: 125.72 +/- 15.96
# Eval num_timesteps=1971200, episode_reward=475.22 +/- 118.15
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1974400, episode_reward=427.48 +/- 164.14
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1977600, episode_reward=466.44 +/- 123.31
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1980800, episode_reward=480.57 +/- 135.61
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1984000, episode_reward=424.19 +/- 97.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1987200, episode_reward=488.50 +/- 102.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1990400, episode_reward=525.26 +/- 112.09
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=1993600, episode_reward=510.52 +/- 151.33
# Episode length: 125.20 +/- 15.22
# Eval num_timesteps=1996800, episode_reward=482.54 +/- 138.34
# Episode length: 126.22 +/- 8.46
# Eval num_timesteps=2000000, episode_reward=462.53 +/- 114.77
# Episode length: 126.40 +/- 11.20
# Eval num_timesteps=2003200, episode_reward=14.16 +/- 167.59
# Episode length: 33.72 +/- 40.53
# Eval num_timesteps=2006400, episode_reward=431.09 +/- 108.66
# Episode length: 127.12 +/- 6.16
# Eval num_timesteps=2009600, episode_reward=421.73 +/- 116.77
# Episode length: 124.92 +/- 15.09
# Eval num_timesteps=2012800, episode_reward=423.94 +/- 110.67
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2016000, episode_reward=466.54 +/- 117.42
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2019200, episode_reward=464.11 +/- 123.42
# Episode length: 126.16 +/- 12.88
# Eval num_timesteps=2022400, episode_reward=495.01 +/- 99.68
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2025600, episode_reward=469.97 +/- 192.26
# Episode length: 120.00 +/- 22.50
# Eval num_timesteps=2028800, episode_reward=511.11 +/- 105.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2032000, episode_reward=512.42 +/- 133.51
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2035200, episode_reward=520.23 +/- 112.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2038400, episode_reward=491.05 +/- 92.49
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2041600, episode_reward=501.63 +/- 105.81
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2044800, episode_reward=497.21 +/- 89.42
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2048000, episode_reward=408.53 +/- 152.77
# Episode length: 119.94 +/- 23.35
# Eval num_timesteps=2051200, episode_reward=459.74 +/- 163.88
# Episode length: 127.66 +/- 2.38
# Eval num_timesteps=2054400, episode_reward=513.83 +/- 116.53
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2057600, episode_reward=490.00 +/- 123.88
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2060800, episode_reward=462.74 +/- 128.37
# Episode length: 127.42 +/- 4.06
# Eval num_timesteps=2064000, episode_reward=442.04 +/- 112.74
# Episode length: 127.90 +/- 0.70
# Eval num_timesteps=2067200, episode_reward=455.24 +/- 102.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2070400, episode_reward=326.01 +/- 158.35
# Episode length: 115.42 +/- 31.86
# Eval num_timesteps=2073600, episode_reward=186.99 +/- 191.65
# Episode length: 85.42 +/- 34.29
# Eval num_timesteps=2076800, episode_reward=325.03 +/- 78.38
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2080000, episode_reward=111.84 +/- 160.41
# Episode length: 73.08 +/- 45.64
# Eval num_timesteps=2083200, episode_reward=139.49 +/- 142.85
# Episode length: 86.50 +/- 38.17
# Eval num_timesteps=2086400, episode_reward=401.51 +/- 175.15
# Episode length: 115.90 +/- 26.76
# Eval num_timesteps=2089600, episode_reward=430.28 +/- 121.65
# Episode length: 127.36 +/- 4.48
# Eval num_timesteps=2092800, episode_reward=493.56 +/- 147.87
# Episode length: 126.96 +/- 7.28
# Eval num_timesteps=2096000, episode_reward=400.83 +/- 186.72
# Episode length: 118.80 +/- 28.31
# Eval num_timesteps=2099200, episode_reward=294.92 +/- 119.99
# Episode length: 121.64 +/- 22.85
# Eval num_timesteps=2102400, episode_reward=389.85 +/- 118.68
# Episode length: 127.66 +/- 2.38
# Eval num_timesteps=2105600, episode_reward=299.79 +/- 167.93
# Episode length: 115.70 +/- 29.31
# Eval num_timesteps=2108800, episode_reward=323.14 +/- 149.29
# Episode length: 119.06 +/- 24.88
# Eval num_timesteps=2112000, episode_reward=343.94 +/- 214.11
# Episode length: 109.54 +/- 38.89
# Eval num_timesteps=2115200, episode_reward=332.09 +/- 176.75
# Episode length: 114.84 +/- 27.94
# Eval num_timesteps=2118400, episode_reward=481.24 +/- 116.43
# Episode length: 127.44 +/- 3.65
# Eval num_timesteps=2121600, episode_reward=291.78 +/- 175.40
# Episode length: 110.66 +/- 35.18
# Eval num_timesteps=2124800, episode_reward=423.61 +/- 98.87
# Episode length: 126.74 +/- 8.82
# Eval num_timesteps=2128000, episode_reward=413.10 +/- 140.35
# Episode length: 122.76 +/- 18.21
# Eval num_timesteps=2131200, episode_reward=257.89 +/- 166.58
# Episode length: 108.96 +/- 31.73
# Eval num_timesteps=2134400, episode_reward=482.67 +/- 132.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2137600, episode_reward=488.16 +/- 101.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2140800, episode_reward=448.93 +/- 128.17
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2144000, episode_reward=407.88 +/- 132.17
# Episode length: 127.44 +/- 2.86
# Eval num_timesteps=2147200, episode_reward=425.68 +/- 110.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2150400, episode_reward=328.40 +/- 105.28
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2153600, episode_reward=431.52 +/- 85.15
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2156800, episode_reward=390.56 +/- 109.85
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2160000, episode_reward=424.23 +/- 122.32
# Episode length: 126.08 +/- 13.44
# Eval num_timesteps=2163200, episode_reward=414.96 +/- 95.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2166400, episode_reward=319.14 +/- 161.93
# Episode length: 114.96 +/- 31.94
# Eval num_timesteps=2169600, episode_reward=455.05 +/- 103.93
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2172800, episode_reward=431.76 +/- 114.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2176000, episode_reward=389.07 +/- 102.66
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2179200, episode_reward=483.72 +/- 102.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2182400, episode_reward=500.41 +/- 129.41
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2185600, episode_reward=522.12 +/- 175.10
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2188800, episode_reward=433.59 +/- 158.38
# Episode length: 124.02 +/- 14.93
# Eval num_timesteps=2192000, episode_reward=423.74 +/- 111.73
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2195200, episode_reward=451.14 +/- 104.40
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2198400, episode_reward=304.64 +/- 136.16
# Episode length: 119.34 +/- 21.07
# Eval num_timesteps=2201600, episode_reward=43.76 +/- 62.69
# Episode length: 73.18 +/- 24.45
# Eval num_timesteps=2204800, episode_reward=317.06 +/- 83.51
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2208000, episode_reward=322.03 +/- 108.06
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2211200, episode_reward=111.27 +/- 197.11
# Episode length: 61.58 +/- 48.10
# Eval num_timesteps=2214400, episode_reward=444.31 +/- 117.06
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2217600, episode_reward=447.85 +/- 109.70
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2220800, episode_reward=419.60 +/- 129.68
# Episode length: 125.92 +/- 14.56
# Eval num_timesteps=2224000, episode_reward=455.18 +/- 90.11
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2227200, episode_reward=451.52 +/- 109.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2230400, episode_reward=464.17 +/- 104.18
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2233600, episode_reward=471.78 +/- 118.48
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2236800, episode_reward=502.24 +/- 118.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2240000, episode_reward=475.36 +/- 95.91
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2243200, episode_reward=493.40 +/- 110.79
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2246400, episode_reward=388.98 +/- 167.65
# Episode length: 119.70 +/- 23.65
# Eval num_timesteps=2249600, episode_reward=366.65 +/- 137.15
# Episode length: 124.54 +/- 13.83
# Eval num_timesteps=2252800, episode_reward=305.65 +/- 102.76
# Episode length: 126.26 +/- 8.73
# Eval num_timesteps=2256000, episode_reward=391.95 +/- 88.26
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2259200, episode_reward=334.61 +/- 117.55
# Episode length: 126.12 +/- 6.90
# Eval num_timesteps=2262400, episode_reward=365.73 +/- 82.54
# Episode length: 126.84 +/- 7.44
# Eval num_timesteps=2265600, episode_reward=380.04 +/- 99.90
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2268800, episode_reward=349.68 +/- 79.70
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2272000, episode_reward=430.85 +/- 95.65
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2275200, episode_reward=399.21 +/- 83.76
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2278400, episode_reward=441.69 +/- 101.99
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2281600, episode_reward=283.19 +/- 219.94
# Episode length: 100.30 +/- 41.97
# Eval num_timesteps=2284800, episode_reward=227.67 +/- 187.00
# Episode length: 95.54 +/- 44.62
# Eval num_timesteps=2288000, episode_reward=432.37 +/- 88.43
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2291200, episode_reward=478.30 +/- 120.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2294400, episode_reward=509.58 +/- 105.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2297600, episode_reward=490.77 +/- 134.30
# Episode length: 125.30 +/- 13.50
# Eval num_timesteps=2300800, episode_reward=357.82 +/- 112.18
# Episode length: 124.98 +/- 15.59
# Eval num_timesteps=2304000, episode_reward=342.53 +/- 190.04
# Episode length: 112.62 +/- 33.02
# Eval num_timesteps=2307200, episode_reward=387.28 +/- 86.03
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2310400, episode_reward=303.90 +/- 177.40
# Episode length: 112.80 +/- 35.04
# Eval num_timesteps=2313600, episode_reward=405.08 +/- 119.08
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2316800, episode_reward=494.47 +/- 144.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2320000, episode_reward=467.53 +/- 101.31
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2323200, episode_reward=379.98 +/- 129.22
# Episode length: 126.20 +/- 12.60
# Eval num_timesteps=2326400, episode_reward=439.07 +/- 110.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2329600, episode_reward=424.77 +/- 84.81
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2332800, episode_reward=522.29 +/- 138.55
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2336000, episode_reward=510.96 +/- 123.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2339200, episode_reward=503.95 +/- 102.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2342400, episode_reward=482.12 +/- 101.78
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2345600, episode_reward=466.02 +/- 125.67
# Episode length: 127.88 +/- 0.84
# Eval num_timesteps=2348800, episode_reward=493.26 +/- 94.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2352000, episode_reward=490.60 +/- 100.79
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2355200, episode_reward=477.66 +/- 84.06
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2358400, episode_reward=483.04 +/- 99.94
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2361600, episode_reward=495.94 +/- 126.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2364800, episode_reward=486.24 +/- 111.44
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2368000, episode_reward=489.79 +/- 91.89
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2371200, episode_reward=512.53 +/- 102.36
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2374400, episode_reward=517.20 +/- 131.38
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2377600, episode_reward=537.07 +/- 123.78
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2380800, episode_reward=558.52 +/- 137.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2384000, episode_reward=504.28 +/- 128.83
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2387200, episode_reward=511.97 +/- 116.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2390400, episode_reward=444.19 +/- 119.61
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2393600, episode_reward=472.19 +/- 139.48
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2396800, episode_reward=438.95 +/- 107.71
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2400000, episode_reward=513.39 +/- 129.93
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2403200, episode_reward=501.62 +/- 132.57
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2406400, episode_reward=371.67 +/- 126.33
# Episode length: 124.70 +/- 15.73
# Eval num_timesteps=2409600, episode_reward=513.24 +/- 103.98
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2412800, episode_reward=498.86 +/- 92.45
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2416000, episode_reward=510.39 +/- 131.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2419200, episode_reward=553.72 +/- 149.08
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2422400, episode_reward=534.69 +/- 104.69
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2425600, episode_reward=501.27 +/- 201.19
# Episode length: 120.04 +/- 25.60
# Eval num_timesteps=2428800, episode_reward=335.90 +/- 209.06
# Episode length: 105.20 +/- 40.33
# Eval num_timesteps=2432000, episode_reward=421.60 +/- 150.97
# Episode length: 121.10 +/- 25.10
# Eval num_timesteps=2435200, episode_reward=377.18 +/- 223.54
# Episode length: 108.86 +/- 40.37
# Eval num_timesteps=2438400, episode_reward=468.77 +/- 144.49
# Episode length: 125.40 +/- 13.48
# Eval num_timesteps=2441600, episode_reward=445.59 +/- 111.06
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2444800, episode_reward=344.73 +/- 170.28
# Episode length: 116.22 +/- 31.19
# Eval num_timesteps=2448000, episode_reward=265.32 +/- 170.87
# Episode length: 112.68 +/- 33.63
# Eval num_timesteps=2451200, episode_reward=274.71 +/- 156.68
# Episode length: 115.44 +/- 33.04
# Eval num_timesteps=2454400, episode_reward=79.17 +/- 153.23
# Episode length: 72.28 +/- 49.34
# Eval num_timesteps=2457600, episode_reward=203.88 +/- 136.90
# Episode length: 113.90 +/- 25.30
# Eval num_timesteps=2460800, episode_reward=129.93 +/- 152.25
# Episode length: 91.78 +/- 40.10
# Eval num_timesteps=2464000, episode_reward=343.41 +/- 94.24
# Episode length: 127.32 +/- 4.48
# Eval num_timesteps=2467200, episode_reward=346.01 +/- 106.30
# Episode length: 127.60 +/- 2.12
# Eval num_timesteps=2470400, episode_reward=260.34 +/- 178.80
# Episode length: 107.02 +/- 39.19
# Eval num_timesteps=2473600, episode_reward=333.90 +/- 121.00
# Episode length: 121.28 +/- 21.92
# Eval num_timesteps=2476800, episode_reward=296.06 +/- 176.43
# Episode length: 110.36 +/- 38.36
# Eval num_timesteps=2480000, episode_reward=372.25 +/- 133.80
# Episode length: 122.98 +/- 21.92
# Eval num_timesteps=2483200, episode_reward=361.88 +/- 85.58
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2486400, episode_reward=482.84 +/- 114.31
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2489600, episode_reward=381.45 +/- 103.82
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2492800, episode_reward=439.33 +/- 158.67
# Episode length: 124.26 +/- 18.87
# Eval num_timesteps=2496000, episode_reward=418.08 +/- 101.94
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2499200, episode_reward=500.83 +/- 85.34
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2502400, episode_reward=422.73 +/- 150.09
# Episode length: 123.00 +/- 20.45
# Eval num_timesteps=2505600, episode_reward=424.78 +/- 117.96
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2508800, episode_reward=436.21 +/- 88.64
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2512000, episode_reward=468.24 +/- 114.37
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2515200, episode_reward=444.23 +/- 89.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2518400, episode_reward=412.70 +/- 115.15
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2521600, episode_reward=516.59 +/- 124.33
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2524800, episode_reward=506.28 +/- 140.58
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2528000, episode_reward=439.46 +/- 102.67
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2531200, episode_reward=397.21 +/- 94.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2534400, episode_reward=374.47 +/- 181.47
# Episode length: 113.34 +/- 32.84
# Eval num_timesteps=2537600, episode_reward=496.94 +/- 113.26
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2540800, episode_reward=492.29 +/- 152.48
# Episode length: 125.88 +/- 14.84
# Eval num_timesteps=2544000, episode_reward=491.08 +/- 147.45
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2547200, episode_reward=471.43 +/- 120.48
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2550400, episode_reward=431.34 +/- 115.24
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2553600, episode_reward=478.84 +/- 124.06
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2556800, episode_reward=442.10 +/- 98.90
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2560000, episode_reward=426.21 +/- 101.68
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2563200, episode_reward=393.22 +/- 93.21
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2566400, episode_reward=330.76 +/- 76.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=2569600, episode_reward=126.02 +/- 113.68
# ...
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3792000, episode_reward=461.34 +/- 109.57
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3795200, episode_reward=522.32 +/- 132.49
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3798400, episode_reward=504.11 +/- 106.40
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3801600, episode_reward=468.22 +/- 129.10
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3804800, episode_reward=420.39 +/- 90.56
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3808000, episode_reward=481.33 +/- 123.33
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3811200, episode_reward=481.26 +/- 190.69
# Episode length: 126.62 +/- 9.66
# Eval num_timesteps=3814400, episode_reward=458.86 +/- 101.81
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3817600, episode_reward=28.35 +/- 189.39
# Episode length: 37.74 +/- 47.81
# Eval num_timesteps=3820800, episode_reward=525.64 +/- 104.81
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3824000, episode_reward=488.38 +/- 113.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3827200, episode_reward=518.65 +/- 123.53
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3830400, episode_reward=451.90 +/- 118.27
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3833600, episode_reward=199.60 +/- 186.17
# Episode length: 96.16 +/- 50.25
# Eval num_timesteps=3836800, episode_reward=-86.66 +/- 4.35
# Episode length: 5.24 +/- 0.91
# Eval num_timesteps=3840000, episode_reward=397.01 +/- 132.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3843200, episode_reward=-92.40 +/- 2.19
# Episode length: 4.18 +/- 0.38
# Eval num_timesteps=3846400, episode_reward=-90.13 +/- 2.91
# Episode length: 4.58 +/- 0.67
# Eval num_timesteps=3849600, episode_reward=-90.36 +/- 3.53
# Episode length: 4.44 +/- 0.57
# Eval num_timesteps=3852800, episode_reward=-91.71 +/- 2.74
# Episode length: 4.42 +/- 0.53
# Eval num_timesteps=3856000, episode_reward=-90.68 +/- 3.28
# Episode length: 4.66 +/- 0.59
# Eval num_timesteps=3859200, episode_reward=-90.74 +/- 3.00
# Episode length: 4.68 +/- 0.68
# Eval num_timesteps=3862400, episode_reward=-91.18 +/- 2.82
# Episode length: 4.52 +/- 0.61
# Eval num_timesteps=3865600, episode_reward=-87.05 +/- 5.17
# Episode length: 5.62 +/- 1.13
# Eval num_timesteps=3868800, episode_reward=458.35 +/- 164.81
# Episode length: 125.56 +/- 17.08
# Eval num_timesteps=3872000, episode_reward=498.30 +/- 134.43
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3875200, episode_reward=488.76 +/- 110.96
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3878400, episode_reward=482.80 +/- 93.32
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3881600, episode_reward=503.73 +/- 105.72
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3884800, episode_reward=531.58 +/- 156.22
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3888000, episode_reward=170.55 +/- 131.81
# Episode length: 99.56 +/- 26.99
# Eval num_timesteps=3891200, episode_reward=260.05 +/- 127.32
# Episode length: 119.54 +/- 18.57
# Eval num_timesteps=3894400, episode_reward=306.04 +/- 109.37
# Episode length: 123.14 +/- 23.81
# Eval num_timesteps=3897600, episode_reward=374.90 +/- 113.41
# Episode length: 125.88 +/- 14.84
# Eval num_timesteps=3900800, episode_reward=306.54 +/- 104.50
# Episode length: 126.20 +/- 12.60
# Eval num_timesteps=3904000, episode_reward=-11.00 +/- 109.99
# Episode length: 38.06 +/- 41.72
# Eval num_timesteps=3907200, episode_reward=16.97 +/- 132.98
# Episode length: 42.50 +/- 33.38
# Eval num_timesteps=3910400, episode_reward=30.36 +/- 107.61
# Episode length: 51.50 +/- 35.51
# Eval num_timesteps=3913600, episode_reward=53.26 +/- 150.57
# Episode length: 48.20 +/- 41.40
# Eval num_timesteps=3916800, episode_reward=416.87 +/- 144.22
# Episode length: 122.92 +/- 15.28
# Eval num_timesteps=3920000, episode_reward=128.99 +/- 230.87
# Episode length: 63.58 +/- 59.13
# Eval num_timesteps=3923200, episode_reward=421.57 +/- 151.36
# Episode length: 124.12 +/- 19.01
# Eval num_timesteps=3926400, episode_reward=440.92 +/- 100.46
# Episode length: 127.94 +/- 0.42
# Eval num_timesteps=3929600, episode_reward=442.51 +/- 108.25
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3932800, episode_reward=349.25 +/- 113.02
# Episode length: 126.38 +/- 6.69
# Eval num_timesteps=3936000, episode_reward=369.15 +/- 128.57
# Episode length: 123.22 +/- 20.41
# Eval num_timesteps=3939200, episode_reward=350.18 +/- 116.90
# Episode length: 125.58 +/- 16.94
# Eval num_timesteps=3942400, episode_reward=322.49 +/- 110.04
# Episode length: 125.38 +/- 17.23
# Eval num_timesteps=3945600, episode_reward=338.98 +/- 83.90
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3948800, episode_reward=405.58 +/- 110.09
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3952000, episode_reward=385.75 +/- 110.03
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3955200, episode_reward=393.60 +/- 100.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3958400, episode_reward=430.58 +/- 98.55
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3961600, episode_reward=409.81 +/- 107.00
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3964800, episode_reward=432.27 +/- 119.68
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3968000, episode_reward=-75.05 +/- 65.66
# Episode length: 10.54 +/- 23.99
# Eval num_timesteps=3971200, episode_reward=356.71 +/- 97.93
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3974400, episode_reward=346.10 +/- 106.34
# Episode length: 126.08 +/- 12.35
# Eval num_timesteps=3977600, episode_reward=420.38 +/- 110.75
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=3980800, episode_reward=317.12 +/- 97.89
# Episode length: 126.18 +/- 12.74
# Eval num_timesteps=3984000, episode_reward=232.39 +/- 105.02
# Episode length: 121.80 +/- 18.56
# Eval num_timesteps=3987200, episode_reward=302.33 +/- 110.13
# Episode length: 123.84 +/- 14.85
# Eval num_timesteps=3990400, episode_reward=274.94 +/- 127.99
# Episode length: 118.22 +/- 28.41
# Eval num_timesteps=3993600, episode_reward=113.70 +/- 180.89
# Episode length: 65.92 +/- 47.52
# Eval num_timesteps=3996800, episode_reward=183.11 +/- 195.78
# Episode length: 86.10 +/- 48.03
# Eval num_timesteps=4000000, episode_reward=88.00 +/- 160.07
# Episode length: 65.74 +/- 48.28
# Eval num_timesteps=4003200, episode_reward=171.52 +/- 172.52
# Episode length: 88.70 +/- 43.92
# Eval num_timesteps=4006400, episode_reward=127.42 +/- 188.97
# Episode length: 73.92 +/- 47.03
# Eval num_timesteps=4009600, episode_reward=182.10 +/- 228.19
# Episode length: 76.16 +/- 48.37
# Eval num_timesteps=4012800, episode_reward=128.15 +/- 194.15
# Episode length: 69.64 +/- 48.13
# Eval num_timesteps=4016000, episode_reward=168.65 +/- 180.73
# Episode length: 82.00 +/- 45.90
# Eval num_timesteps=4019200, episode_reward=304.93 +/- 162.85
# Episode length: 114.08 +/- 31.68
# Eval num_timesteps=4022400, episode_reward=414.96 +/- 158.09
# Episode length: 123.22 +/- 23.42
# Eval num_timesteps=4025600, episode_reward=459.71 +/- 96.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4028800, episode_reward=457.37 +/- 118.55
# Episode length: 127.78 +/- 1.54
# Eval num_timesteps=4032000, episode_reward=194.44 +/- 196.65
# Episode length: 91.60 +/- 51.51
# Eval num_timesteps=4035200, episode_reward=500.48 +/- 153.70
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4038400, episode_reward=431.21 +/- 117.84
# Episode length: 126.88 +/- 7.84
# Eval num_timesteps=4041600, episode_reward=415.05 +/- 114.58
# Episode length: 126.72 +/- 8.96
# Eval num_timesteps=4044800, episode_reward=-59.40 +/- 59.59
# Episode length: 19.36 +/- 21.67
# Eval num_timesteps=4048000, episode_reward=327.39 +/- 176.48
# Episode length: 112.10 +/- 38.11
# Eval num_timesteps=4051200, episode_reward=424.37 +/- 126.02
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4054400, episode_reward=428.17 +/- 78.76
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4057600, episode_reward=440.18 +/- 112.83
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4060800, episode_reward=391.85 +/- 92.08
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4064000, episode_reward=400.71 +/- 108.18
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4067200, episode_reward=393.45 +/- 114.07
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4070400, episode_reward=395.38 +/- 125.42
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4073600, episode_reward=408.41 +/- 99.96
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4076800, episode_reward=409.97 +/- 140.95
# Episode length: 125.70 +/- 16.10
# Eval num_timesteps=4080000, episode_reward=375.12 +/- 156.13
# Episode length: 120.00 +/- 27.13
# Eval num_timesteps=4083200, episode_reward=469.57 +/- 164.22
# Episode length: 122.84 +/- 19.00
# Eval num_timesteps=4086400, episode_reward=353.99 +/- 171.98
# Episode length: 115.84 +/- 32.37
# Eval num_timesteps=4089600, episode_reward=340.87 +/- 135.00
# Episode length: 119.80 +/- 24.44
# Eval num_timesteps=4092800, episode_reward=241.34 +/- 146.82
# Episode length: 107.70 +/- 29.97
# Eval num_timesteps=4096000, episode_reward=320.23 +/- 133.80
# Episode length: 124.02 +/- 13.07
# Eval num_timesteps=4099200, episode_reward=399.63 +/- 115.02
# Episode length: 126.94 +/- 6.38
# Eval num_timesteps=4102400, episode_reward=413.94 +/- 107.68
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4105600, episode_reward=372.15 +/- 125.87
# Episode length: 124.28 +/- 17.21
# Eval num_timesteps=4108800, episode_reward=459.17 +/- 131.05
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4112000, episode_reward=379.57 +/- 102.28
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4115200, episode_reward=428.97 +/- 111.86
# Episode length: 127.44 +/- 3.92
# Eval num_timesteps=4118400, episode_reward=338.54 +/- 170.99
# Episode length: 113.90 +/- 26.82
# Eval num_timesteps=4121600, episode_reward=462.81 +/- 145.45
# Episode length: 126.14 +/- 9.40
# Eval num_timesteps=4124800, episode_reward=328.20 +/- 152.93
# Episode length: 114.86 +/- 22.57
# Eval num_timesteps=4128000, episode_reward=454.24 +/- 124.13
# Episode length: 126.06 +/- 6.83
# Eval num_timesteps=4131200, episode_reward=281.02 +/- 151.92
# Episode length: 106.16 +/- 27.07
# Eval num_timesteps=4134400, episode_reward=392.01 +/- 87.49
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4137600, episode_reward=346.18 +/- 128.83
# Episode length: 119.80 +/- 18.74
# Eval num_timesteps=4140800, episode_reward=66.49 +/- 119.02
# Episode length: 59.64 +/- 39.65
# Eval num_timesteps=4144000, episode_reward=357.72 +/- 109.95
# Episode length: 126.12 +/- 7.75
# Eval num_timesteps=4147200, episode_reward=373.91 +/- 132.95
# Episode length: 119.78 +/- 19.41
# Eval num_timesteps=4150400, episode_reward=449.06 +/- 110.23
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4153600, episode_reward=454.87 +/- 120.63
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4156800, episode_reward=430.27 +/- 123.25
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4160000, episode_reward=262.52 +/- 118.22
# Episode length: 116.54 +/- 18.82
# Eval num_timesteps=4163200, episode_reward=396.36 +/- 154.03
# Episode length: 121.48 +/- 18.26
# Eval num_timesteps=4166400, episode_reward=444.57 +/- 174.11
# Episode length: 119.62 +/- 26.73
# Eval num_timesteps=4169600, episode_reward=281.38 +/- 164.18
# Episode length: 104.62 +/- 31.34
# Eval num_timesteps=4172800, episode_reward=101.94 +/- 141.72
# Episode length: 64.14 +/- 36.32
# Eval num_timesteps=4176000, episode_reward=78.45 +/- 196.81
# Episode length: 50.56 +/- 47.27
# Eval num_timesteps=4179200, episode_reward=280.70 +/- 257.25
# Episode length: 91.10 +/- 54.02
# Eval num_timesteps=4182400, episode_reward=491.35 +/- 95.20
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4185600, episode_reward=487.18 +/- 117.80
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4188800, episode_reward=496.02 +/- 101.10
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4192000, episode_reward=506.03 +/- 116.77
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4195200, episode_reward=413.44 +/- 98.51
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4198400, episode_reward=388.88 +/- 113.78
# Episode length: 126.10 +/- 7.57
# Eval num_timesteps=4201600, episode_reward=440.19 +/- 110.13
# Episode length: 128.00 +/- 0.00
# Eval num_timesteps=4204800, episode_reward=310.29 +/- 178.43
# Episode length: 108.94 +/- 28.72
# Eval num_timesteps=4208000, episode_reward=393.87 +/- 153.26
# Episode length: 123.64 +/- 15.31
# Eval num_timesteps=4211200, episode_reward=391.47 +/- 112.24
# Episode length: 126.96 +/- 5.01
# Eval num_timesteps=4214400, episode_reward=385.41 +/- 123.55
# Episode length: 124.58 +/- 13.18
# Eval num_timesteps=4217600, episode_reward=121.37 +/- 138.68
# Episode length: 82.16 +/- 40.46
# Eval num_timesteps=4220800, episode_reward=334.04 +/- 90.00
# Episode length: 126.98 +/- 5.78
# Eval num_timesteps=4224000, episode_reward=281.84 +/- 92.53
# Episode length: 124.80 +/- 15.83
# Eval num_timesteps=4227200, episode_reward=12.67 +/- 97.06
# Episode length: 50.04 +/- 29.77
# Eval num_timesteps=4230400, episode_reward=89.58 +/- 127.31
# Episode length: 60.82 +/- 31.85
# Eval num_timesteps=4233600, episode_reward=58.37 +/- 125.08
# Episode length: 51.00 +/- 33.60
# Eval num_timesteps=4236800, episode_reward=343.92 +/- 215.48
# Episode length: 106.04 +/- 43.43
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 10
#       5 callback = EvalCallback(env, log_path=log_dir, n_eval_episodes= 50, eval_freq= 25*128,
#       6                             best_model_save_path=os.path.join(log_dir, "best_model_td3-n"),
#       7                             callback_on_new_best=PlotResultsCallback(log_dir=log_dir))
#       8 # Eval callback, for plotting and seeing how the training is going, and saving best models. No effect on the results.
# ---> 10 model.learn(total_timesteps=int(300000000000000000), callback=callback)
#      13 # Plot helper from the library
#      14 results_plotter.plot_results(
#      15     [log_dir], 1e7, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
#      16 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\td3\td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\td3\td3.py:167, in TD3.train(self, gradient_steps, batch_size)
#     164 # Sample replay buffer
#     165 replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)  # type: ignore[union-attr]
# --> 167 with th.no_grad():
#     168     # Select action according to policy and add clipped noise
#     169     noise = replay_data.actions.clone().data.normal_(0, self.target_policy_noise)
#     170     noise = noise.clamp(-self.target_noise_clip, self.target_noise_clip)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\autograd\grad_mode.py:57, in no_grad.__exit__(self, exc_type, exc_value, traceback)
#      54     self.prev = torch.is_grad_enabled()
#      55     torch.set_grad_enabled(False)
# ---> 57 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#      58     torch.set_grad_enabled(self.prev)
#
# KeyboardInterrupt:

# %%
results_plotter.plot_results(
    [log_dir], 1e7, results_plotter.X_TIMESTEPS, "PPO - Env: Battery"
)

# %%
plot_results(log_dir)

# %% [markdown]
# # Test 1 episode of the model

# %%
model.save(os.path.join(log_dir, "best_model_td3-n"))


def test_trained_model():
    obs = model.get_env().reset()
    episode_reward = 0

    obsArray = []

    while True:
        obsArray.append(obs)
        action, _states = model.predict(obs)
        oldObs = obs
        obs, rewards, done, info = model.get_env().step(action)
        episode_reward += rewards.squeeze()

        if not done:
            print(str(oldObs) + "  ACTION:" + str(get_converted_action(action)[0]) + "  >>>> ")
            print(str(obs) + "  REWARD:  "  + str(rewards) + "   ")
        else:
            info_item = info.pop()
            print("FINAL: ")
            print(str(info_item.get('terminal_observation'))  + "       ACTION:" )
            print(str(str(get_converted_action(action.flatten()))))
            print("REWARD:  " + str(rewards[0]))
            print("EPISODE TOTAL REWARD: " + str(episode_reward))

            # plot final model
            fig = plt.figure(1)

            data_np = np.array(obsArray)

            plt.xlabel('Step')
            plt.ylabel('SOC')
            print("------------------------------------------------------")
            plt.ylim([-0.5, 1])


            i = 0
            for soc in data_np.T:
                plt.plot(np.arange(start=0, stop=len(data_np), step=1), soc.flatten(), label="soc"+str(i))
                i += 1

            # plt.legend()
            #plt.pause(3)

            obsArray = []
            episode_reward = 0
            obs = model.get_env().reset()

            #time.sleep(0.5)
            break




test_trained_model()
# Out:
# [[0.848315   0.8283833  0.8438647  0.5019383  0.5862813  0.74151963
#   0.6692434  0.5579345  0.61106235 0.8272093  0.8339091  0.8305707
#   0.7430092  0.6182788  0.8156489  0.5260398  0.5903565  0.6674359
#   0.70592266 0.5710495 ]]  ACTION:[7.8260900e-06 2.7113661e-02 0.0000000e+00 1.1920929e-08 0.0000000e+00
#  0.0000000e+00 7.9154775e-02 0.0000000e+00 4.4703484e-08 1.5884638e-06
#  0.0000000e+00 0.0000000e+00 3.5676359e-05 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 2.7692318e-05 0.0000000e+00]  >>>>
# [[0.8483072  0.8012697  0.8438647  0.5019383  0.5862813  0.74151963
#   0.5900886  0.5579345  0.6110623  0.8272077  0.8339091  0.8305707
#   0.74297357 0.6182788  0.8156489  0.5260398  0.5903565  0.6674359
#   0.70589495 0.5710495 ]]  REWARD:  [4.0536313]
# [[0.8483072  0.8012697  0.8438647  0.5019383  0.5862813  0.74151963
#   0.5900886  0.5579345  0.6110623  0.8272077  0.8339091  0.8305707
#   0.74297357 0.6182788  0.8156489  0.5260398  0.5903565  0.6674359
#   0.70589495 0.5710495 ]]  ACTION:[4.3383239e-05 2.0148268e-02 0.0000000e+00 2.3543835e-07 0.0000000e+00
#  0.0000000e+00 3.4311723e-02 0.0000000e+00 1.2338162e-06 1.6924740e-05
#  1.0401011e-06 0.0000000e+00 2.0844936e-04 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 9.7008117e-02 0.0000000e+00]  >>>>
# [[0.8482638  0.78112143 0.8438647  0.50193805 0.5862813  0.74151963
#   0.5557769  0.5579345  0.6110611  0.82719076 0.833908   0.8305707
#   0.74276507 0.6182788  0.8156489  0.5260398  0.5903565  0.6674359
#   0.60888684 0.5710495 ]]  REWARD:  [4.253674]
# [[0.8482638  0.78112143 0.8438647  0.50193805 0.5862813  0.74151963
#   0.5557769  0.5579345  0.6110611  0.82719076 0.833908   0.8305707
#   0.74276507 0.6182788  0.8156489  0.5260398  0.5903565  0.6674359
#   0.60888684 0.5710495 ]]  ACTION:[2.54240644e-04 1.72210522e-02 0.00000000e+00 3.47793093e-06
#  0.00000000e+00 0.00000000e+00 1.40730385e-02 0.00000000e+00
#  8.50856304e-06 7.12722540e-05 1.51994827e-04 0.00000000e+00
#  5.49623393e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7