# %%
# !pip3 install stable_baselines3 --user
#!pip3 install torch --index-url https://download.pytorch.org/whl/cu117 --upgrade --force-reinstall --trusted-host pypi.org --trusted-host pytorch.org --trusted-host download.pytorch.org
#!pip3 install tensorflow-io
#!pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.2 in c:\users\matei\appdata\roaming\python\python310\site-packages (from hyperopt) (3.2.1)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from hyperopt) (1.24.2)
# Collecting scipy
#   Downloading scipy-1.12.0-cp310-cp310-win_amd64.whl (46.2 MB)
#      --------------------------------------- 46.2/46.2 MB 50.4 MB/s eta 0:00:00
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ------------------------------------- 840.9/840.9 KB 51.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ------------------------------------- 200.5/200.5 KB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in c:\users\matei\appdata\roaming\python\python310\site-packages (from hyperopt) (3.0.0)
# Requirement already satisfied: six in c:\users\matei\appdata\roaming\python\python310\site-packages (from hyperopt) (1.16.0)
# Collecting tqdm
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 KB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\matei\appdata\roaming\python\python310\site-packages (from tqdm->hyperopt) (0.4.6)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492071 sha256=196cc483f825efb50410374520eacea1e6dc915a5ee9d1252a83282d2a4da82f
#   Stored in directory: c:\users\matei\appdata\local\pip\cache\wheels\5e\a9\47\f118e66afd12240e4662752cc22cefae5d97275623aa8ef57d
# Successfully built future
# Installing collected packages: py4j, tqdm, scipy, future, hyperopt
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python310\\share'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#!pip3 uninstall tensorflow-tensorboard
#!pip3 install tensorboard==2.13.0
# Out:
# WARNING: Skipping tensorflow-tensorboard as it is not installed.
# Collecting tensorboard==2.13.0
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (4.25.2)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (49.2.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (2.27.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (2.1.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (0.42.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (1.60.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (1.26.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (3.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (0.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from tensorboard==2.13.0) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (5.3.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard==2.13.0) (2.1.3)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\a493191\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard==2.13.0) (7.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (2.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard==2.13.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\a493191\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0) (3.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\a493191\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard==2.13.0) (3.17.0)
# Installing collected packages: google-auth-oauthlib, tensorboard
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
# Successfully installed google-auth-oauthlib-1.0.0 tensorboard-2.13.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# tensorflow-intel 2.15.0 requires tensorboard<2.16,>=2.15, but you'll have tensorboard 2.13.0 which is incompatible.
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\a493191\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip3 install --upgrade --force-reinstall tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.15.0-cp39-cp39-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.15.0; platform_system == "Windows"
#   Using cached tensorflow_intel-2.15.0-cp39-cp39-win_amd64.whl (300.8 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-win_amd64.whl (35 kB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.25.2-cp39-cp39-win_amd64.whl (413 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting setuptools
#   Downloading setuptools-69.1.0-py3-none-any.whl (819 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.10.0-cp39-cp39-win_amd64.whl (2.7 MB)
# Collecting tensorflow-estimator<2.16,>=2.15.0
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting keras<2.16,>=2.15.0
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Collecting packaging
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Collecting flatbuffers>=23.5.26
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.60.1-cp39-cp39-win_amd64.whl (3.7 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting ml-dtypes~=0.2.0
#   Using cached ml_dtypes-0.2.0-cp39-cp39-win_amd64.whl (938 kB)
# Collecting tensorboard<2.16,>=2.15
#   Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Collecting six>=1.12.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting numpy<2.0.0,>=1.23.5
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Collecting google-auth-oauthlib<2,>=0.5
#   Using cached google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.5.2-py3-none-any.whl (103 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.27.0-py2.py3-none-any.whl (186 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4; python_version < "3.10"
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.0-py3-none-any.whl (120 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl (17 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: libclang, termcolor, wrapt, typing-extensions, protobuf, numpy, opt-einsum, setuptools, wheel, six, astunparse, absl-py, h5py, tensorflow-estimator, google-pasta, gast, keras, packaging, flatbuffers, grpcio, tensorflow-io-gcs-filesystem, ml-dtypes, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, oauthlib, idna, charset-normalizer, certifi, urllib3, requests, requests-oauthlib, google-auth-oauthlib, tensorboard-data-server, zipp, importlib-metadata, markdown, MarkupSafe, werkzeug, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: libclang
#     Found existing installation: libclang 16.0.6
#     Uninstalling libclang-16.0.6:
#       Successfully uninstalled libclang-16.0.6
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.8.0
#     Uninstalling typing-extensions-4.8.0:
#       Successfully uninstalled typing-extensions-4.8.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.2
#     Uninstalling protobuf-4.25.2:
#       Successfully uninstalled protobuf-4.25.2
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\A493191\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\google\\~upb\\_message.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\a493191\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip3 install stable_baselines3 --upgrade --force-reinstall
# Out:
# Collecting stable_baselines3
#   Using cached stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.8.2-cp39-cp39-win_amd64.whl (7.6 MB)
# Collecting numpy>=1.20
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Collecting torch>=1.13
#   Using cached torch-2.2.0-cp39-cp39-win_amd64.whl (198.5 MB)
# Collecting cloudpickle
#   Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting pandas
#   Using cached pandas-2.2.0-cp39-cp39-win_amd64.whl (11.6 MB)
# Collecting gymnasium<0.30,>=0.28.1
#   Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.0-cp39-cp39-win_amd64.whl (181 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Using cached pillow-10.2.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.48.1-cp39-cp39-win_amd64.whl (2.2 MB)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting packaging>=20.0
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Collecting typing-extensions>=4.8.0
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting filelock
#   Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting fsspec
#   Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Collecting jinja2
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting farama-notifications>=0.0.1
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting importlib-metadata>=4.8.0; python_version < "3.10"
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting zipp>=3.1.0; python_version < "3.10"
#   Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp39-cp39-win_amd64.whl (17 kB)
# Installing collected packages: numpy, contourpy, cycler, pillow, kiwisolver, fonttools, six, python-dateutil, pyparsing, zipp, importlib-resources, packaging, matplotlib, typing-extensions, mpmath, sympy, filelock, fsspec, MarkupSafe, jinja2, networkx, torch, cloudpickle, tzdata, pytz, pandas, farama-notifications, importlib-metadata, gymnasium, stable-baselines3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\A493191\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\~-mpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\a493191\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip3 uninstall tensorflow
# Out:
# ^C

# %%
#!pip install stable-baselines3[extra]

# -- Prerequisites install 
# !pip3 install stable_baselines3 --user
# !pip3 install stable_baselines3 --user
# !pip3 install ipykernel --user
# !pip3 install tensorboard --user
# Out:
# Requirement already satisfied: stable_baselines3 in c:\users\matei\appdata\roaming\python\python311\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (2.2.0)
# Requirement already satisfied: cloudpickle in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (2.2.0)
# Requirement already satisfied: matplotlib in c:\users\matei\appdata\roaming\python\python311\site-packages (from stable_baselines3) (3.8.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.13.1)
# Requirement already satisfied: sympy in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (1.12)
# Requirement already satisfied: networkx in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\matei\appdata\roaming\python\python311\site-packages (from torch>=1.13->stable_baselines3) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matei\appdata\roaming\python\python311\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matei\appdata\roaming\python\python311\site-packages (from pandas->stable_baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\matei\appdata\roaming\python\python311\site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# ^C
# Requirement already satisfied: ipykernel in c:\users\matei\appdata\roaming\python\python311\site-packages (6.29.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (8.21.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipykernel) (5.14.1)
# Requirement already satisfied: decorator in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: colorama in c:\users\matei\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\matei\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\matei\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\matei\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\matei\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: tensorboard in c:\users\matei\appdata\roaming\python\python311\site-packages (2.16.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.60.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (3.5.2)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\envs\stable_baselines\lib\site-packages (from tensorboard) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matei\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)

# %%
import stable_baselines3

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env


#from stable_baselines3 import DQN,PPO,A2C
from stable_baselines3 import PPO
import os


from hyperopt import hp,fmin,tpe
import torch as th
import math



def set_up_model(params, env):
    log_path = os.path.join('Training', 'Logs')
    hidden_layers_policy_network = params['hidden_layers_policy_network']
    size_hidden_layers_policy_network = params['size_hidden_layers_policy_network']
    hidden_layers_value_network = params['hidden_layers_value_network']
    size_hidden_layers_value_network = params['size_hidden_layers_value_network']

    net_arch = [dict(pi=([size_hidden_layers_policy_network] * hidden_layers_policy_network),vf=([size_hidden_layers_value_network] * hidden_layers_value_network))]

    activation_fn = {"tanh": th.nn.Tanh, "relu": th.nn.ReLU, "elu": th.nn.ELU, "leaky_relu": th.nn.LeakyReLU}[params['activation_fn']]

    policy_kwargs = dict(net_arch=net_arch,
                    ortho_init=params['ortho_init'],
                    activation_fn=activation_fn)

    batch_size = math.gcd(params['batch_size'],params['n_steps'])

    model = PPO("MlpPolicy",
                env, 
                learning_rate=params['learning_rate'], 
                n_steps=params['n_steps'], 
                batch_size=batch_size, 
                n_epochs=params['n_epochs'], 
                gamma=params['gamma'], 
                gae_lambda=params['gae_lambda'], 
                clip_range=params['clip_range'], 
                ent_coef=params['ent_coef'], 
                vf_coef=params['vf_coef'], 
                max_grad_norm=params['max_grad_norm'],
                policy_kwargs=policy_kwargs,
                verbose=0, 
                tensorboard_log=log_path,
                device='cuda')
    return model




space = {
        'learning_rate': 5e-6,
        'n_steps': 128,
        'batch_size': 128,
        'n_epochs': 10,
        'gamma': 0.99,
        'gae_lambda': 0.9,
        'clip_range': 0.2,
        'ent_coef': 0,
        'vf_coef': 0.5,
        'max_grad_norm': 0.5,
        'lr_schedule': 'linear',
        'hidden_layers_policy_network': 2,
        'size_hidden_layers_policy_network': 128,
        'hidden_layers_value_network': 2,
        'size_hidden_layers_value_network': 128,
        'ortho_init': False,
        'activation_fn': "relu"
    }


log_dir = "./tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

env = BatteryEnv()
env = Monitor(env, log_dir)


check_env(env, warn=True)

print(hp.choice('hidden_layers_policy_network', [1,2,3,4]))

model = set_up_model(space,env)

model.learn(total_timesteps=1000)
# Out:
# 0 switch
# 1   hyperopt_param
# 2     Literal{hidden_layers_policy_network}
# 3     randint
# 4       Literal{4}
# 5   Literal{1}
# 6   Literal{2}
# 7   Literal{3}
# 8   Literal{4}
# C:\Users\A493191\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\policies.py:484: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results(
    [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 LunarLander"
)

# %%
import matplotlib.pyplot as plt

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()


plot_results(log_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 34
#      30     plt.title(title + " Smoothed")
#      31     plt.show()
# ---> 34 plot_results(log_dir)
#
# Cell In[4], line 27, in plot_results(log_folder, title)
#      24 x = x[len(x) - len(y) :]
#      26 fig = plt.figure(title)
# ---> 27 plt.plot(x, y)
#      28 plt.xlabel("Number of Timesteps")
#      29 plt.ylabel("Rewards")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (50,)

# %% [markdown]
# # STABLEBASELINES TESTBED

# %%
# Battery env 
import gymnasium as gym
import numpy as np
from typing import Optional, Union
from math import isclose


#class BatteryEnv(gym.Env[np.ndarray, Union[int, np.ndarray]]):

class BatteryEnv(gym.Env):

   def __init__(self, render_mode: Optional[str] = None):
      #self.zk = 9.8  # = SOC
      #self.hk = 1.0  # = hysteresis state
      #self.t = 1.0   # = temperature
      #self.vk = 1.0
      #self.rck = 1.0 # = Current through paralel resistor
      
      #...


      self.ik = 0.1   # current

      self.env_id = "Battery v0.2"


      self.vk_threshold_upper = 4.2
      self.vk_threshold_lower = 3.2

      self.soc_threshold_upper = 85
      self.soc_threshold_lower = 15


      action_high = np.array(
            [
               20,        
               20,        
         ],
         dtype=np.float32,
      )

      action_low = np.array(
            [
               0,
               0,
         ],
         dtype=np.float32,
      )


      high = np.array(
            [
            #   10,         #min= 0, max= 10       Voltage (v) - vk
               100,        #min= 0, max= 100      SOC - zk
               100,        #min= 0, max= 100      SOC - zk
            #   150,        #min= -30, max= 150    Temperature  - t
            #   1,          #min= -1, max= 1       Hysteresis state - hk
            #   100,        #min= -100, max= 100   Current through paralel resistor - rck
            #   33459,      # time 
            #   np.finfo(np.float32).max,   #min= Inf, max= Inf
         ],
         dtype=np.float32,
      )

      low = np.array(
            [
            #   0,        
               0,
               0,
            #   -30,
            #   -1,      
            #   -100,  
            #    0,       # time
            #   np.finfo(np.float32).max,
         ],
         dtype=np.float32,
      )


      # self.action_space = gym.spaces.Discrete(2)
      # self.action_space = gym.spaces.MultiDiscrete([2, 2]) #actions: charge/discharge AND cell1/cell2
      # self.action_space = gym.spaces.Box(action_low, action_high, (2,), dtype=np.float32) # cell1,cell2,cell3... and voltage
      self.action_space = gym.spaces.Box(action_low, action_high, (2,), dtype=np.float32) # New idea: shapes = voltages for each cell
      self.observation_space = gym.spaces.Box(low, high, dtype=np.float32)

      self.state = None
      self.steps_beyond_terminated = None

      self.episode_steps = 0

      



   def step(self, action):
      err_msg = f"{action!r} ({type(action)}) invalid"
      assert self.action_space.contains(action), err_msg
      assert self.state is not None, "Call reset before using step method."


      #vk, zk, t, hk, rck, time = self.state


      # discharge until 15, and 85 limilits
      #print(action)

      self.episode_steps += 1

      soc0, soc1 = self.state

      # if action[0] == 1:
      #    ik = self.ik 
      # else:
      ik = action[1]

      if action[0] <= 0.5:
         soc0 = soc0 - ik
      else:
         soc1 = soc1 - ik
      
      # NO! Respect the markov property!
      # oldSoc0 = soc0
      # oldSoc1 = soc1

      self.state = [soc0, soc1]

      terminated = False

      # right now the reward in only based on if the variables fall out of bounds 
      exceeded_soc_threshold = bool(
         # isclose(soc0, soc1, abs_tol=1e-2)
         soc0 < self.soc_threshold_lower
         or soc0 > self.soc_threshold_upper
         or soc1 < self.soc_threshold_lower
         or soc1 > self.soc_threshold_upper
         # time doesnt really make sense here for now
         #or time < 0
         #or time > 33458
      )

      if self.episode_steps == 10:
         reward = 100
         self.episode_steps = 0
         terminated = True

      elif not exceeded_soc_threshold:
         reward = compute_ballancing_reward(soc0, soc1, False)

      elif self.steps_beyond_terminated is None:
         # Batteries drained! Terminated.
         # print('TERMINATED')
         terminated = True
         self.steps_beyond_terminated = 0


         soc0, soc1 = self.state

         # if isclose(soc0, soc1, abs_tol=1e-2):
         reward = -10000.0
         # else:
         #    reward = compute_ballancing_reward(soc0, soc1, False)

         #reward = compute_ballancing_reward(soc0, soc1, False) * (500 - self.episode_steps) # apply cost of of remaining steps in the episode¨

         self.episode_steps = 0



      else:
         if self.steps_beyond_terminated == 0:
              print(
                  "You are calling 'step()' even though this "
                  "environment has already returned terminated = True. You "
                  "should always call 'reset()' once you receive 'terminated = "
                  "True' -- any further steps are undefined behavior."
               )
         self.steps_beyond_terminated += 1
         reward = 0.0


      if self.render_mode == "human":
         self.render()
      return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
   

       


   def reset(
        self,
        *,
        seed: Optional[int] = None,
        options: Optional[dict] = None,):
        

         super().reset(seed=seed)
         # Note that if you use custom reset bounds, it may lead to out-of-bound
         # state/observations.
         #high = utils.maybe_parse_reset_bounds(
         #    options, -0.05, 0.05  # default low
         #)  # default high

         high = np.array(
               [
               #   self.vk_threshold_upper,         #min= 0, max= 10       Voltage (v) - vk
                  85,        #min= 0, max= 100      SOC - zk
                  85,        #min= 0, max= 100      SOC - zk
               #   150,        #min= -30, max= 150    Temperature  - t
               #   1,          #min= -1, max= 1       Hysteresis state - hk
               #   100,        #min= -100, max= 100   Current through paralel resistor - rck
               #   33459,      # time 
               #   np.finfo(np.float32).max,   #min= Inf, max= Inf
            ],
            dtype=np.float32,
         )

         low = np.array(
               [
               #   self.vk_threshold_lower,        
                  15,
                  15,
               #   -30,
               #   -1,      
               #   -100,  
               #   0,       # time
               #   np.finfo(np.float32).max,
            ],
            dtype=np.float32,
         )

         #definition of an episode: 1 whole run of the matlab script
         #                               OR
         #                          1 segment of it     

         self.state = self.np_random.uniform(low=low, high=high, size=(2,))
         #initialize voltage between self.vk_threshold_upper and self.vk_threshold_lower
         #self.state[0] = 4.0

         self.steps_beyond_terminated = None
         self.episode_steps = 0

         if self.render_mode == "human":
               self.render()
         return np.array(self.state, dtype=np.float32), {}



def compute_ballancing_reward(soc0, soc1, should_print):
   reward = 0
   
   reward = -pow(soc0 - soc1, 2)


   # if(should_print):
   #    print( "SOC Mean: " + str(mean) +  "    ---- SOC1 Difference    "  + str(difference1)  +  "    ----   SOC2 Difference    "  + str(difference2))
      
      
   

   return reward

# %%
import torch

def plot_step(episode_number, state, action, reward, show_result=False):
    
    fig = plt.figure(1)

    actions_t = torch.tensor(action, dtype=torch.float)
    rewards_t = torch.tensor(reward, dtype=torch.float)

    plt.title('Episode ' + str(episode_number))
    plt.xlabel('Step')
    plt.ylabel('SOC & Actions')



    # Plot SOCs
    soc0 = []
    soc1 = []
    for st in state:
        # states_t = torch.tensor(st, dtype=torch.float)
        # plt.plot(states_t.cpu().squeeze().numpy(), label='State ' + str(st))

        soc0.append(st[0][0].item())
        soc1.append(st[0][1].item())
    
    plt.plot(soc0, label='soc0')
    plt.plot(soc1, label='soc1')



    # Plot actions as indvidual points
    action_array = np.multiply(actions_t.numpy(), 10)   # multiply action values by 10 for better display on graph
    plt.plot(action_array, 'bo', markersize=0.4, label='Action')
    line_nr = 0

    # Plot action value as text above point
    # for line in action_array:
    #     plt.text(line_nr, line+1.8, str(int(line)), horizontalalignment='center', size='small', color='black')
    #     line_nr = line_nr + 1 


    # Plot actions as single point average
    # Take 100 steps average and plot the average action for that period
    # if len(actions_t) >= 10:
    #     means = actions_t.unfold(0, 10, 1).mean(1).view(-1)
    #     means = torch.cat((torch.zeros(9), means))
    #     plt.plot(means.numpy(), 'go', markersize=1, label='Action')

    plt.legend()



    # Plot rewards
    # Reduces displayed rewards by an order of 10 to fit within the graph
    fig2 = plt.figure(2)
    plt.title('Episode ' + str(episode_number))
    plt.xlabel('Step')
    plt.ylabel('Reward')
    #plt.plot(np.divide(rewards_t.numpy(), 10), label='Reward')
    plt.plot(rewards_t.numpy(), label='Reward')

    # add legend with labels
    plt.legend()




    plt.pause(0.0001)  # pause a bit so that plots are updated
    #if is_ipython:
    if not show_result:
        display.display(plt.gcf())
        display.clear_output(wait=True)
    else:
        display.display(plt.gcf())

# %%
# NOT FUNCTIONAL

class TimeLimitWrapper(gym.Wrapper):
    """
    :param env: (gym.Env) Gym environment that will be wrapped
    :param max_steps: (int) Max number of steps per episode
    """

    def __init__(self, env, max_steps=100):
        # Call the parent constructor, so we can access self.env later
        super(TimeLimitWrapper, self).__init__(env)
        self.max_steps = max_steps
        # Counter of steps per episode
        self.current_step = 0

        # PLOT CODE
        # self.episode_durations = []
        self.current_episode_states = []
        self.current_episode_actions = []
        self.current_episode_rewards = []


    def reset(self, **kwargs):
        """
        Reset the environment
        """
        # Reset the counter
        self.current_step = 0
        print("dsdsdsdsds")
        return self.env.reset(**kwargs)

    def step(self, action):
        """
        :param action: ([float] or int) Action taken by the agent
        :return: (np.ndarray, float, bool, bool, dict) observation, reward, is the episode over?, additional informations
        """
        self.current_step += 1
        obs, reward, terminated, truncated, info = self.env.step(action)

        print("dsdsdsdsds")

        # PLOT CODE
        self.current_episode_states.append(self.env.state)
        self.current_episode_actions.append(action[0].item())
        self.current_episode_rewards.append(reward)

        plot_step(1, self.current_episode_states,  self.current_episode_actions,  self.current_episode_rewards)

        # Overwrite the truncation signal when when the number of steps reaches the maximum
        if self.current_step >= self.max_steps:
            truncated = True
        return obs, reward, terminated, truncated, info

# %%
import stable_baselines3

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env


#from stable_baselines3 import DQN,PPO,A2C
from stable_baselines3 import PPO
import os


from hyperopt import hp,fmin,tpe
import torch as th
import math


import numpy as np
from typing import Optional, Union



class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            #print(x[-100:])

            results_plotter.plot_results(
                [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
            )

            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)
            
            # RESET ENV
            #self.model.env.reset()

        return True
# Out:
# WARNING:tensorflow:From c:\Users\A493191\AppData\Local\anaconda3\envs\stable_baselines\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# !pip install gymnasium[box2d]
import gymnasium as gym



# Create log dir
log_dir = "./tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
#env = gym.make("LunarLanderContinuous-v2")
env = BatteryEnv(False)
#env = gym.wrappers.TimeLimit(env, max_episode_steps = 500)
#env = gym.wrappers.AutoResetWrapper(env)  --- call reset manually when 'done' is true if not using this wrapper

# OrderEnforcing wraper -- throw error if step is caled before reset

#end = TimeLimitWrapper(env, max_steps=50)   -- NOT FUNCTIONAL ON THIS IMPL. use TimeLimit instead
# Logs will be saved in log_dir/monitor.csv 
env = Monitor(env, log_dir)
#env = gym.wrappers.RecordEpisodeStatistics(env, 500)

# %%
from stable_baselines3 import A2C, SAC, PPO, TD3
import torch

#print("Is CUDA enabled?", torch.cuda.is_available())


# Create action noise because TD3 and DDPG use a deterministic policy
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=100, log_dir=log_dir)
# Create RL model
model = PPO('MlpPolicy', env, verbose=0, device="cuda", tensorboard_log="./ppo_tensorboard_log/", n_steps=100, n_epochs=100, batch_size=100, gamma=0.4)
# model = TD3('MlpPolicy', env, verbose=0, device="cuda", tensorboard_log="./ppo_tensorboard_log/", action_noise=action_noise, learning_rate=0.01)

#TD3: ''The primary issue I was having was that I wasn't normalizing the input data before sending it through the system.'' - normalize
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from stable_baselines3.common import results_plotter

# Train the agent
# model.learn(total_timesteps=int(100000), log_interval=10, callback=callback)

model.learn(total_timesteps=int(1o00000), log_interval=100, reset_num_timesteps=True, callback=callback)



# Helper from the library
results_plotter.plot_results(
    [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
)
# Out:
# Num timesteps: 100
# Best mean reward: -2413.31 - Last mean reward per episode: -3287.90
# Num timesteps: 200
# Best mean reward: -2413.31 - Last mean reward per episode: -3209.88
# Num timesteps: 300
# Best mean reward: -2413.31 - Last mean reward per episode: -3238.73
# Num timesteps: 400
# Best mean reward: -2413.31 - Last mean reward per episode: -3296.60
# Num timesteps: 500
# Best mean reward: -2413.31 - Last mean reward per episode: -3001.46
# Num timesteps: 600
# Best mean reward: -2413.31 - Last mean reward per episode: -3014.88
# Num timesteps: 700
# Best mean reward: -2413.31 - Last mean reward per episode: -3215.51
# Num timesteps: 800
# Best mean reward: -2413.31 - Last mean reward per episode: -3425.13
# Num timesteps: 900
# Best mean reward: -2413.31 - Last mean reward per episode: -2983.16
# Num timesteps: 1000
# Best mean reward: -2413.31 - Last mean reward per episode: -2799.04
# Num timesteps: 1100
# Best mean reward: -2413.31 - Last mean reward per episode: -3365.71
# Num timesteps: 1200
# Best mean reward: -2413.31 - Last mean reward per episode: -3627.32
# Num timesteps: 1300
# Best mean reward: -2413.31 - Last mean reward per episode: -3657.36
# Num timesteps: 1400
# Best mean reward: -2413.31 - Last mean reward per episode: -3868.29
# Num timesteps: 1500
# Best mean reward: -2413.31 - Last mean reward per episode: -3612.06
# Num timesteps: 1600
# Best mean reward: -2413.31 - Last mean reward per episode: -3813.04
# Num timesteps: 1700
# Best mean reward: -2413.31 - Last mean reward per episode: -3662.57
# Num timesteps: 1800
# Best mean reward: -2413.31 - Last mean reward per episode: -3773.10
# Num timesteps: 1900
# Best mean reward: -2413.31 - Last mean reward per episode: -4255.24
# Num timesteps: 2000
# Best mean reward: -2413.31 - Last mean reward per episode: -4109.32
# Num timesteps: 2100
# Best mean reward: -2413.31 - Last mean reward per episode: -4029.70
# Num timesteps: 2200
# Best mean reward: -2413.31 - Last mean reward per episode: -4150.90
# Num timesteps: 2300
# Best mean reward: -2413.31 - Last mean reward per episode: -4403.56
# Num timesteps: 2400
# Best mean reward: -2413.31 - Last mean reward per episode: -4468.86
# Num timesteps: 2500
# Best mean reward: -2413.31 - Last mean reward per episode: -4740.84
# Num timesteps: 2600
# Best mean reward: -2413.31 - Last mean reward per episode: -4289.04
# Num timesteps: 2700
# Best mean reward: -2413.31 - Last mean reward per episode: -4582.62
# Num timesteps: 2800
# Best mean reward: -2413.31 - Last mean reward per episode: -4346.47
# Num timesteps: 2900
# Best mean reward: -2413.31 - Last mean reward per episode: -3986.66
# Num timesteps: 3000
# Best mean reward: -2413.31 - Last mean reward per episode: -4603.77
# Num timesteps: 3100
# Best mean reward: -2413.31 - Last mean reward per episode: -4064.05
# Num timesteps: 3200
# Best mean reward: -2413.31 - Last mean reward per episode: -3782.18
# Num timesteps: 3300
# Best mean reward: -2413.31 - Last mean reward per episode: -3683.83
# Num timesteps: 3400
# Best mean reward: -2413.31 - Last mean reward per episode: -3297.05
# Num timesteps: 3500
# Best mean reward: -2413.31 - Last mean reward per episode: -3456.13
# Num timesteps: 3600
# Best mean reward: -2413.31 - Last mean reward per episode: -4072.93
# Num timesteps: 3700
# Best mean reward: -2413.31 - Last mean reward per episode: -3772.79
# Num timesteps: 3800
# Best mean reward: -2413.31 - Last mean reward per episode: -3775.46
# Num timesteps: 3900
# Best mean reward: -2413.31 - Last mean reward per episode: -3971.37
# Num timesteps: 4000
# Best mean reward: -2413.31 - Last mean reward per episode: -3697.96
# Num timesteps: 4100
# Best mean reward: -2413.31 - Last mean reward per episode: -3859.47
# Num timesteps: 4200
# Best mean reward: -2413.31 - Last mean reward per episode: -3984.29
# Num timesteps: 4300
# Best mean reward: -2413.31 - Last mean reward per episode: -4230.40
# Num timesteps: 4400
# Best mean reward: -2413.31 - Last mean reward per episode: -4250.56
# Num timesteps: 4500
# Best mean reward: -2413.31 - Last mean reward per episode: -4143.77
# Num timesteps: 4600
# Best mean reward: -2413.31 - Last mean reward per episode: -4147.73
# Num timesteps: 4700
# Best mean reward: -2413.31 - Last mean reward per episode: -4377.46
# Num timesteps: 4800
# Best mean reward: -2413.31 - Last mean reward per episode: -4720.95
# Num timesteps: 4900
# Best mean reward: -2413.31 - Last mean reward per episode: -4586.57
# Num timesteps: 5000
# Best mean reward: -2413.31 - Last mean reward per episode: -4573.21
# Num timesteps: 5100
# Best mean reward: -2413.31 - Last mean reward per episode: -4614.25
# Num timesteps: 5200
# Best mean reward: -2413.31 - Last mean reward per episode: -5060.50
# Num timesteps: 5300
# Best mean reward: -2413.31 - Last mean reward per episode: -4904.02
# Num timesteps: 5400
# Best mean reward: -2413.31 - Last mean reward per episode: -6016.33
# Num timesteps: 5500
# Best mean reward: -2413.31 - Last mean reward per episode: -5845.17
# Num timesteps: 5600
# Best mean reward: -2413.31 - Last mean reward per episode: -5508.18
# Num timesteps: 5700
# Best mean reward: -2413.31 - Last mean reward per episode: -5197.77
# Num timesteps: 5800
# Best mean reward: -2413.31 - Last mean reward per episode: -5101.45
# Num timesteps: 5900
# Best mean reward: -2413.31 - Last mean reward per episode: -5299.02
# Num timesteps: 6000
# Best mean reward: -2413.31 - Last mean reward per episode: -5305.15
# Num timesteps: 6100
# Best mean reward: -2413.31 - Last mean reward per episode: -5149.37
# Num timesteps: 6200
# Best mean reward: -2413.31 - Last mean reward per episode: -5031.33
# Num timesteps: 6300
# Best mean reward: -2413.31 - Last mean reward per episode: -4978.92
# Num timesteps: 6400
# Best mean reward: -2413.31 - Last mean reward per episode: -4086.70
# Num timesteps: 6500
# Best mean reward: -2413.31 - Last mean reward per episode: -4327.25
# Num timesteps: 6600
# Best mean reward: -2413.31 - Last mean reward per episode: -4154.89
# Num timesteps: 6700
# Best mean reward: -2413.31 - Last mean reward per episode: -4157.63
# Num timesteps: 6800
# Best mean reward: -2413.31 - Last mean reward per episode: -4045.24
# Num timesteps: 6900
# Best mean reward: -2413.31 - Last mean reward per episode: -3950.55
# Num timesteps: 7000
# Best mean reward: -2413.31 - Last mean reward per episode: -3972.77
# Num timesteps: 7100
# Best mean reward: -2413.31 - Last mean reward per episode: -4117.85
# Num timesteps: 7200
# Best mean reward: -2413.31 - Last mean reward per episode: -3630.32
# Num timesteps: 7300
# Best mean reward: -2413.31 - Last mean reward per episode: -3744.70
# Num timesteps: 7400
# Best mean reward: -2413.31 - Last mean reward per episode: -4091.70
# Num timesteps: 7500
# Best mean reward: -2413.31 - Last mean reward per episode: -3796.44
# Num timesteps: 7600
# Best mean reward: -2413.31 - Last mean reward per episode: -4067.80
# Num timesteps: 7700
# Best mean reward: -2413.31 - Last mean reward per episode: -3868.17
# Num timesteps: 7800
# Best mean reward: -2413.31 - Last mean reward per episode: -3688.51
# Num timesteps: 7900
# Best mean reward: -2413.31 - Last mean reward per episode: -3364.98
# Num timesteps: 8000
# Best mean reward: -2413.31 - Last mean reward per episode: -2958.77
# Num timesteps: 8100
# Best mean reward: -2413.31 - Last mean reward per episode: -3465.69
# Num timesteps: 8200
# Best mean reward: -2413.31 - Last mean reward per episode: -3531.71
# Num timesteps: 8300
# Best mean reward: -2413.31 - Last mean reward per episode: -3236.95
# Num timesteps: 8400
# Best mean reward: -2413.31 - Last mean reward per episode: -2915.38
# Num timesteps: 8500
# Best mean reward: -2413.31 - Last mean reward per episode: -3384.38
# Num timesteps: 8600
# Best mean reward: -2413.31 - Last mean reward per episode: -3070.30
# Num timesteps: 8700
# Best mean reward: -2413.31 - Last mean reward per episode: -3419.48
# Num timesteps: 8800
# Best mean reward: -2413.31 - Last mean reward per episode: -3523.62
# Num timesteps: 8900
# Best mean reward: -2413.31 - Last mean reward per episode: -4133.23
# Num timesteps: 9000
# Best mean reward: -2413.31 - Last mean reward per episode: -4551.31
# Num timesteps: 9100
# Best mean reward: -2413.31 - Last mean reward per episode: -4140.30
# Num timesteps: 9200
# Best mean reward: -2413.31 - Last mean reward per episode: -4128.12
# Num timesteps: 9300
# Best mean reward: -2413.31 - Last mean reward per episode: -4441.60
# Num timesteps: 9400
# Best mean reward: -2413.31 - Last mean reward per episode: -4035.99
# Num timesteps: 9500
# Best mean reward: -2413.31 - Last mean reward per episode: -4235.05
# Num timesteps: 9600
# Best mean reward: -2413.31 - Last mean reward per episode: -4219.43
# Num timesteps: 9700
# Best mean reward: -2413.31 - Last mean reward per episode: -3731.66
# Num timesteps: 9800
# Best mean reward: -2413.31 - Last mean reward per episode: -3810.27
# Num timesteps: 9900
# Best mean reward: -2413.31 - Last mean reward per episode: -3500.12
# Num timesteps: 10000
# Best mean reward: -2413.31 - Last mean reward per episode: -3020.42
# Num timesteps: 10100
# Best mean reward: -2413.31 - Last mean reward per episode: -3179.00
# Num timesteps: 10200
# Best mean reward: -2413.31 - Last mean reward per episode: -3349.20
# Num timesteps: 10300
# Best mean reward: -2413.31 - Last mean reward per episode: -3323.52
# Num timesteps: 10400
# Best mean reward: -2413.31 - Last mean reward per episode: -3753.07
# Num timesteps: 10500
# Best mean reward: -2413.31 - Last mean reward per episode: -3360.17
# Num timesteps: 10600
# Best mean reward: -2413.31 - Last mean reward per episode: -3523.91
# Num timesteps: 10700
# Best mean reward: -2413.31 - Last mean reward per episode: -4373.91
# Num timesteps: 10800
# Best mean reward: -2413.31 - Last mean reward per episode: -4499.44
# Num timesteps: 10900
# Best mean reward: -2413.31 - Last mean reward per episode: -4857.70
# Num timesteps: 11000
# Best mean reward: -2413.31 - Last mean reward per episode: -5060.74
# Num timesteps: 11100
# Best mean reward: -2413.31 - Last mean reward per episode: -4732.49
# Num timesteps: 11200
# Best mean reward: -2413.31 - Last mean reward per episode: -4815.51
# Num timesteps: 11300
# Best mean reward: -2413.31 - Last mean reward per episode: -4388.08
# Num timesteps: 11400
# Best mean reward: -2413.31 - Last mean reward per episode: -4467.19
# Num timesteps: 11500
# Best mean reward: -2413.31 - Last mean reward per episode: -4529.86
# Num timesteps: 11600
# Best mean reward: -2413.31 - Last mean reward per episode: -4416.23
# Num timesteps: 11700
# Best mean reward: -2413.31 - Last mean reward per episode: -3839.36
# Num timesteps: 11800
# Best mean reward: -2413.31 - Last mean reward per episode: -3503.60
# Num timesteps: 11900
# Best mean reward: -2413.31 - Last mean reward per episode: -2961.98
# Num timesteps: 12000
# Best mean reward: -2413.31 - Last mean reward per episode: -2713.27
# Num timesteps: 12100
# Best mean reward: -2413.31 - Last mean reward per episode: -2928.41
# Num timesteps: 12200
# Best mean reward: -2413.31 - Last mean reward per episode: -2582.70
# Num timesteps: 12300
# Best mean reward: -2413.31 - Last mean reward per episode: -3231.57
# Num timesteps: 12400
# Best mean reward: -2413.31 - Last mean reward per episode: -3077.73
# Num timesteps: 12500
# Best mean reward: -2413.31 - Last mean reward per episode: -3348.82
# Num timesteps: 12600
# Best mean reward: -2413.31 - Last mean reward per episode: -3711.70
# Num timesteps: 12700
# Best mean reward: -2413.31 - Last mean reward per episode: -3464.85
# Num timesteps: 12800
# Best mean reward: -2413.31 - Last mean reward per episode: -3554.33
# Num timesteps: 12900
# Best mean reward: -2413.31 - Last mean reward per episode: -3559.60
# Num timesteps: 13000
# Best mean reward: -2413.31 - Last mean reward per episode: -3879.04
# Num timesteps: 13100
# Best mean reward: -2413.31 - Last mean reward per episode: -4444.81
# Num timesteps: 13200
# Best mean reward: -2413.31 - Last mean reward per episode: -4582.69
# Num timesteps: 13300
# Best mean reward: -2413.31 - Last mean reward per episode: -4136.33
# Num timesteps: 13400
# Best mean reward: -2413.31 - Last mean reward per episode: -4022.71
# Num timesteps: 13500
# Best mean reward: -2413.31 - Last mean reward per episode: -3705.51
# Num timesteps: 13600
# Best mean reward: -2413.31 - Last mean reward per episode: -3757.58
# Num timesteps: 13700
# Best mean reward: -2413.31 - Last mean reward per episode: -4155.97
# Num timesteps: 13800
# Best mean reward: -2413.31 - Last mean reward per episode: -4299.31
# Num timesteps: 13900
# Best mean reward: -2413.31 - Last mean reward per episode: -4220.17
# Num timesteps: 14000
# Best mean reward: -2413.31 - Last mean reward per episode: -4191.82
# Num timesteps: 14100
# Best mean reward: -2413.31 - Last mean reward per episode: -3715.60
# Num timesteps: 14200
# Best mean reward: -2413.31 - Last mean reward per episode: -3806.55
# Num timesteps: 14300
# Best mean reward: -2413.31 - Last mean reward per episode: -4618.81
# Num timesteps: 14400
# Best mean reward: -2413.31 - Last mean reward per episode: -4630.28
# Num timesteps: 14500
# Best mean reward: -2413.31 - Last mean reward per episode: -4717.23
# Num timesteps: 14600
# Best mean reward: -2413.31 - Last mean reward per episode: -4087.66
# Num timesteps: 14700
# Best mean reward: -2413.31 - Last mean reward per episode: -4169.15
# Num timesteps: 14800
# Best mean reward: -2413.31 - Last mean reward per episode: -4324.39
# Num timesteps: 14900
# Best mean reward: -2413.31 - Last mean reward per episode: -4435.69
# Num timesteps: 15000
# Best mean reward: -2413.31 - Last mean reward per episode: -5018.09
# Num timesteps: 15100
# Best mean reward: -2413.31 - Last mean reward per episode: -5222.02
# Num timesteps: 15200
# Best mean reward: -2413.31 - Last mean reward per episode: -5466.81
# Num timesteps: 15300
# Best mean reward: -2413.31 - Last mean reward per episode: -4553.95
# Num timesteps: 15400
# Best mean reward: -2413.31 - Last mean reward per episode: -4399.70
# Num timesteps: 15500
# Best mean reward: -2413.31 - Last mean reward per episode: -4390.31
# Num timesteps: 15600
# Best mean reward: -2413.31 - Last mean reward per episode: -4583.54
# Num timesteps: 15700
# Best mean reward: -2413.31 - Last mean reward per episode: -4296.53
# Num timesteps: 15800
# Best mean reward: -2413.31 - Last mean reward per episode: -4050.12
# Num timesteps: 15900
# Best mean reward: -2413.31 - Last mean reward per episode: -4033.32
# Num timesteps: 16000
# Best mean reward: -2413.31 - Last mean reward per episode: -4356.39
# Num timesteps: 16100
# Best mean reward: -2413.31 - Last mean reward per episode: -4600.84
# Num timesteps: 16200
# Best mean reward: -2413.31 - Last mean reward per episode: -4440.69
# Num timesteps: 16300
# Best mean reward: -2413.31 - Last mean reward per episode: -4610.12
# Num timesteps: 16400
# Best mean reward: -2413.31 - Last mean reward per episode: -4518.92
# Num timesteps: 16500
# Best mean reward: -2413.31 - Last mean reward per episode: -4620.99
# Num timesteps: 16600
# Best mean reward: -2413.31 - Last mean reward per episode: -4515.87
# Num timesteps: 16700
# Best mean reward: -2413.31 - Last mean reward per episode: -4656.96
# Num timesteps: 16800
# Best mean reward: -2413.31 - Last mean reward per episode: -4799.40
# Num timesteps: 16900
# Best mean reward: -2413.31 - Last mean reward per episode: -5008.17
# Num timesteps: 17000
# Best mean reward: -2413.31 - Last mean reward per episode: -4421.93
# Num timesteps: 17100
# Best mean reward: -2413.31 - Last mean reward per episode: -4060.71
# Num timesteps: 17200
# Best mean reward: -2413.31 - Last mean reward per episode: -3878.09
# Num timesteps: 17300
# Best mean reward: -2413.31 - Last mean reward per episode: -4181.43
# Num timesteps: 17400
# Best mean reward: -2413.31 - Last mean reward per episode: -4020.39
# Num timesteps: 17500
# Best mean reward: -2413.31 - Last mean reward per episode: -3936.65
# Num timesteps: 17600
# Best mean reward: -2413.31 - Last mean reward per episode: -4034.61
# Num timesteps: 17700
# Best mean reward: -2413.31 - Last mean reward per episode: -4375.13
# Num timesteps: 17800
# Best mean reward: -2413.31 - Last mean reward per episode: -4196.87
# Num timesteps: 17900
# Best mean reward: -2413.31 - Last mean reward per episode: -3943.23
# Num timesteps: 18000
# Best mean reward: -2413.31 - Last mean reward per episode: -3997.03
# Num timesteps: 18100
# Best mean reward: -2413.31 - Last mean reward per episode: -4270.09
# Num timesteps: 18200
# Best mean reward: -2413.31 - Last mean reward per episode: -4461.39
# Num timesteps: 18300
# Best mean reward: -2413.31 - Last mean reward per episode: -5210.34
# Num timesteps: 18400
# Best mean reward: -2413.31 - Last mean reward per episode: -5445.25
# Num timesteps: 18500
# Best mean reward: -2413.31 - Last mean reward per episode: -5449.66
# Num timesteps: 18600
# Best mean reward: -2413.31 - Last mean reward per episode: -5522.59
# Num timesteps: 18700
# Best mean reward: -2413.31 - Last mean reward per episode: -5042.12
# Num timesteps: 18800
# Best mean reward: -2413.31 - Last mean reward per episode: -4915.66
# Num timesteps: 18900
# Best mean reward: -2413.31 - Last mean reward per episode: -4669.48
# Num timesteps: 19000
# Best mean reward: -2413.31 - Last mean reward per episode: -4791.32
# Num timesteps: 19100
# Best mean reward: -2413.31 - Last mean reward per episode: -4535.05
# Num timesteps: 19200
# Best mean reward: -2413.31 - Last mean reward per episode: -4407.27
# Num timesteps: 19300
# Best mean reward: -2413.31 - Last mean reward per episode: -3370.02
# Num timesteps: 19400
# Best mean reward: -2413.31 - Last mean reward per episode: -3317.80
# Num timesteps: 19500
# Best mean reward: -2413.31 - Last mean reward per episode: -3500.85
# Num timesteps: 19600
# Best mean reward: -2413.31 - Last mean reward per episode: -4511.71
# Num timesteps: 19700
# Best mean reward: -2413.31 - Last mean reward per episode: -4903.92
# Num timesteps: 19800
# Best mean reward: -2413.31 - Last mean reward per episode: -4664.63
# Num timesteps: 19900
# Best mean reward: -2413.31 - Last mean reward per episode: -4967.26
# Num timesteps: 20000
# Best mean reward: -2413.31 - Last mean reward per episode: -4498.41
# Num timesteps: 20100
# Best mean reward: -2413.31 - Last mean reward per episode: -4662.88
# Num timesteps: 20200
# Best mean reward: -2413.31 - Last mean reward per episode: -4907.34
# Num timesteps: 20300
# Best mean reward: -2413.31 - Last mean reward per episode: -5035.79
# Num timesteps: 20400
# Best mean reward: -2413.31 - Last mean reward per episode: -5186.08
# Num timesteps: 20500
# Best mean reward: -2413.31 - Last mean reward per episode: -5902.32
# Num timesteps: 20600
# Best mean reward: -2413.31 - Last mean reward per episode: -4931.38
# Num timesteps: 20700
# Best mean reward: -2413.31 - Last mean reward per episode: -4673.26
# Num timesteps: 20800
# Best mean reward: -2413.31 - Last mean reward per episode: -4917.00
# Num timesteps: 20900
# Best mean reward: -2413.31 - Last mean reward per episode: -4670.47
# Num timesteps: 21000
# Best mean reward: -2413.31 - Last mean reward per episode: -4837.82
# Num timesteps: 21100
# Best mean reward: -2413.31 - Last mean reward per episode: -5066.44
# Num timesteps: 21200
# Best mean reward: -2413.31 - Last mean reward per episode: -5194.57
# Num timesteps: 21300
# Best mean reward: -2413.31 - Last mean reward per episode: -5125.63
# Num timesteps: 21400
# Best mean reward: -2413.31 - Last mean reward per episode: -4673.34
# Num timesteps: 21500
# Best mean reward: -2413.31 - Last mean reward per episode: -3808.95
# Num timesteps: 21600
# Best mean reward: -2413.31 - Last mean reward per episode: -4169.34
# Num timesteps: 21700
# Best mean reward: -2413.31 - Last mean reward per episode: -4182.53
# Num timesteps: 21800
# Best mean reward: -2413.31 - Last mean reward per episode: -4197.88
# Num timesteps: 21900
# Best mean reward: -2413.31 - Last mean reward per episode: -4566.37
# Num timesteps: 22000
# Best mean reward: -2413.31 - Last mean reward per episode: -3989.60
# Num timesteps: 22100
# Best mean reward: -2413.31 - Last mean reward per episode: -4194.59
# Num timesteps: 22200
# Best mean reward: -2413.31 - Last mean reward per episode: -4193.62
# Num timesteps: 22300
# Best mean reward: -2413.31 - Last mean reward per episode: -3666.04
# Num timesteps: 22400
# Best mean reward: -2413.31 - Last mean reward per episode: -3625.45
# Num timesteps: 22500
# Best mean reward: -2413.31 - Last mean reward per episode: -3858.39
# Num timesteps: 22600
# Best mean reward: -2413.31 - Last mean reward per episode: -3655.29
# Num timesteps: 22700
# Best mean reward: -2413.31 - Last mean reward per episode: -3775.48
# Num timesteps: 22800
# Best mean reward: -2413.31 - Last mean reward per episode: -4046.16
# Num timesteps: 22900
# Best mean reward: -2413.31 - Last mean reward per episode: -4003.57
# Num timesteps: 23000
# Best mean reward: -2413.31 - Last mean reward per episode: -4094.42
# Num timesteps: 23100
# Best mean reward: -2413.31 - Last mean reward per episode: -3714.51
# Num timesteps: 23200
# Best mean reward: -2413.31 - Last mean reward per episode: -3371.52
# Num timesteps: 23300
# Best mean reward: -2413.31 - Last mean reward per episode: -3576.22
# Num timesteps: 23400
# Best mean reward: -2413.31 - Last mean reward per episode: -3511.02
# Num timesteps: 23500
# Best mean reward: -2413.31 - Last mean reward per episode: -3503.87
# Num timesteps: 23600
# Best mean reward: -2413.31 - Last mean reward per episode: -3852.43
# Num timesteps: 23700
# Best mean reward: -2413.31 - Last mean reward per episode: -3415.13
# Num timesteps: 23800
# Best mean reward: -2413.31 - Last mean reward per episode: -3319.61
# Num timesteps: 23900
# Best mean reward: -2413.31 - Last mean reward per episode: -3264.18
# Num timesteps: 24000
# Best mean reward: -2413.31 - Last mean reward per episode: -3189.90
# Num timesteps: 24100
# Best mean reward: -2413.31 - Last mean reward per episode: -3140.32
# Num timesteps: 24200
# Best mean reward: -2413.31 - Last mean reward per episode: -3199.99
# Num timesteps: 24300
# Best mean reward: -2413.31 - Last mean reward per episode: -3279.07
# Num timesteps: 24400
# Best mean reward: -2413.31 - Last mean reward per episode: -3372.17
# Num timesteps: 24500
# Best mean reward: -2413.31 - Last mean reward per episode: -3346.58
# Num timesteps: 24600
# Best mean reward: -2413.31 - Last mean reward per episode: -3329.88
# Num timesteps: 24700
# Best mean reward: -2413.31 - Last mean reward per episode: -3458.97
# Num timesteps: 24800
# Best mean reward: -2413.31 - Last mean reward per episode: -3723.03
# Num timesteps: 24900
# Best mean reward: -2413.31 - Last mean reward per episode: -3515.78
# Num timesteps: 25000
# Best mean reward: -2413.31 - Last mean reward per episode: -3878.65
# Num timesteps: 25100
# Best mean reward: -2413.31 - Last mean reward per episode: -3595.41
# Num timesteps: 25200
# Best mean reward: -2413.31 - Last mean reward per episode: -4086.13
# Num timesteps: 25300
# Best mean reward: -2413.31 - Last mean reward per episode: -4528.97
# Num timesteps: 25400
# Best mean reward: -2413.31 - Last mean reward per episode: -4657.47
# Num timesteps: 25500
# Best mean reward: -2413.31 - Last mean reward per episode: -4947.12
# Num timesteps: 25600
# Best mean reward: -2413.31 - Last mean reward per episode: -4528.10
# Num timesteps: 25700
# Best mean reward: -2413.31 - Last mean reward per episode: -4509.18
# Num timesteps: 25800
# Best mean reward: -2413.31 - Last mean reward per episode: -4442.43
# Num timesteps: 25900
# Best mean reward: -2413.31 - Last mean reward per episode: -4649.64
# Num timesteps: 26000
# Best mean reward: -2413.31 - Last mean reward per episode: -4553.18
# Num timesteps: 26100
# Best mean reward: -2413.31 - Last mean reward per episode: -5100.09
# Num timesteps: 26200
# Best mean reward: -2413.31 - Last mean reward per episode: -4781.42
# Num timesteps: 26300
# Best mean reward: -2413.31 - Last mean reward per episode: -4403.07
# Num timesteps: 26400
# Best mean reward: -2413.31 - Last mean reward per episode: -4530.90
# Num timesteps: 26500
# Best mean reward: -2413.31 - Last mean reward per episode: -4306.77
# Num timesteps: 26600
# Best mean reward: -2413.31 - Last mean reward per episode: -4293.45
# Num timesteps: 26700
# Best mean reward: -2413.31 - Last mean reward per episode: -4104.61
# Num timesteps: 26800
# Best mean reward: -2413.31 - Last mean reward per episode: -4249.30
# Num timesteps: 26900
# Best mean reward: -2413.31 - Last mean reward per episode: -4498.78
# Num timesteps: 27000
# Best mean reward: -2413.31 - Last mean reward per episode: -4428.36
# Num timesteps: 27100
# Best mean reward: -2413.31 - Last mean reward per episode: -3924.84
# Num timesteps: 27200
# Best mean reward: -2413.31 - Last mean reward per episode: -3505.30
# Num timesteps: 27300
# Best mean reward: -2413.31 - Last mean reward per episode: -3865.74
# Num timesteps: 27400
# Best mean reward: -2413.31 - Last mean reward per episode: -3673.23
# Num timesteps: 27500
# Best mean reward: -2413.31 - Last mean reward per episode: -3564.80
# Num timesteps: 27600
# Best mean reward: -2413.31 - Last mean reward per episode: -3771.93
# Num timesteps: 27700
# Best mean reward: -2413.31 - Last mean reward per episode: -3827.06
# Num timesteps: 27800
# Best mean reward: -2413.31 - Last mean reward per episode: -4206.37
# Num timesteps: 27900
# Best mean reward: -2413.31 - Last mean reward per episode: -3969.06
# Num timesteps: 28000
# Best mean reward: -2413.31 - Last mean reward per episode: -3610.62
# Num timesteps: 28100
# Best mean reward: -2413.31 - Last mean reward per episode: -4051.35
# Num timesteps: 28200
# Best mean reward: -2413.31 - Last mean reward per episode: -4046.53
# Num timesteps: 28300
# Best mean reward: -2413.31 - Last mean reward per episode: -4456.33
# Num timesteps: 28400
# Best mean reward: -2413.31 - Last mean reward per episode: -4579.96
# Num timesteps: 28500
# Best mean reward: -2413.31 - Last mean reward per episode: -5247.79
# Num timesteps: 28600
# Best mean reward: -2413.31 - Last mean reward per episode: -5343.97
# Num timesteps: 28700
# Best mean reward: -2413.31 - Last mean reward per episode: -4883.88
# Num timesteps: 28800
# Best mean reward: -2413.31 - Last mean reward per episode: -4987.97
# Num timesteps: 28900
# Best mean reward: -2413.31 - Last mean reward per episode: -5015.86
# Num timesteps: 29000
# Best mean reward: -2413.31 - Last mean reward per episode: -4772.32
# Num timesteps: 29100
# Best mean reward: -2413.31 - Last mean reward per episode: -4577.45
# Num timesteps: 29200
# Best mean reward: -2413.31 - Last mean reward per episode: -4217.33
# Num timesteps: 29300
# Best mean reward: -2413.31 - Last mean reward per episode: -3554.15
# Num timesteps: 29400
# Best mean reward: -2413.31 - Last mean reward per episode: -3697.25
# Num timesteps: 29500
# Best mean reward: -2413.31 - Last mean reward per episode: -2676.00
# Num timesteps: 29600
# Best mean reward: -2413.31 - Last mean reward per episode: -2651.10
# Num timesteps: 29700
# Best mean reward: -2413.31 - Last mean reward per episode: -2963.91
# Num timesteps: 29800
# Best mean reward: -2413.31 - Last mean reward per episode: -2376.54
# Saving new best model to ./tmp/gym/best_model.zip
# Num timesteps: 29900
# Best mean reward: -2376.54 - Last mean reward per episode: -2287.50
# Saving new best model to ./tmp/gym/best_model.zip
# Num timesteps: 30000
# Best mean reward: -2287.50 - Last mean reward per episode: -2316.70
# Num timesteps: 30100
# Best mean reward: -2287.50 - Last mean reward per episode: -2520.15
# Num timesteps: 30200
# Best mean reward: -2287.50 - Last mean reward per episode: -2839.03
# Num timesteps: 30300
# Best mean reward: -2287.50 - Last mean reward per episode: -3041.77
# Num timesteps: 30400
# Best mean reward: -2287.50 - Last mean reward per episode: -2751.93
# Num timesteps: 30500
# Best mean reward: -2287.50 - Last mean reward per episode: -2637.83
# Num timesteps: 30600
# Best mean reward: -2287.50 - Last mean reward per episode: -2894.91
# Num timesteps: 30700
# Best mean reward: -2287.50 - Last mean reward per episode: -2772.50
# Num timesteps: 30800
# Best mean reward: -2287.50 - Last mean reward per episode: -3366.67
# Num timesteps: 30900
# Best mean reward: -2287.50 - Last mean reward per episode: -3406.19
# Num timesteps: 31000
# Best mean reward: -2287.50 - Last mean reward per episode: -3365.01
# Num timesteps: 31100
# Best mean reward: -2287.50 - Last mean reward per episode: -3467.39
# Num timesteps: 31200
# Best mean reward: -2287.50 - Last mean reward per episode: -3266.28
# Num timesteps: 31300
# Best mean reward: -2287.50 - Last mean reward per episode: -3610.67
# Num timesteps: 31400
# Best mean reward: -2287.50 - Last mean reward per episode: -3633.78
# Num timesteps: 31500
# Best mean reward: -2287.50 - Last mean reward per episode: -3772.85
# Num timesteps: 31600
# Best mean reward: -2287.50 - Last mean reward per episode: -3543.44
# Num timesteps: 31700
# Best mean reward: -2287.50 - Last mean reward per episode: -4089.78
# Num timesteps: 31800
# Best mean reward: -2287.50 - Last mean reward per episode: -3866.49
# Num timesteps: 31900
# Best mean reward: -2287.50 - Last mean reward per episode: -3829.84
# Num timesteps: 32000
# Best mean reward: -2287.50 - Last mean reward per episode: -3919.05
# Num timesteps: 32100
# Best mean reward: -2287.50 - Last mean reward per episode: -3713.91
# Num timesteps: 32200
# Best mean reward: -2287.50 - Last mean reward per episode: -3980.13
# Num timesteps: 32300
# Best mean reward: -2287.50 - Last mean reward per episode: -4154.33
# Num timesteps: 32400
# Best mean reward: -2287.50 - Last mean reward per episode: -4272.87
# Num timesteps: 32500
# Best mean reward: -2287.50 - Last mean reward per episode: -4083.70
# Num timesteps: 32600
# Best mean reward: -2287.50 - Last mean reward per episode: -4079.90
# Num timesteps: 32700
# Best mean reward: -2287.50 - Last mean reward per episode: -3441.43
# Num timesteps: 32800
# Best mean reward: -2287.50 - Last mean reward per episode: -3418.14
# Num timesteps: 32900
# Best mean reward: -2287.50 - Last mean reward per episode: -3789.16
# Num timesteps: 33000
# Best mean reward: -2287.50 - Last mean reward per episode: -3737.22
# Num timesteps: 33100
# Best mean reward: -2287.50 - Last mean reward per episode: -3829.38
# Num timesteps: 33200
# Best mean reward: -2287.50 - Last mean reward per episode: -3559.56
# Num timesteps: 33300
# Best mean reward: -2287.50 - Last mean reward per episode: -3783.57
# Num timesteps: 33400
# Best mean reward: -2287.50 - Last mean reward per episode: -4094.36
# Num timesteps: 33500
# Best mean reward: -2287.50 - Last mean reward per episode: -4708.84
# Num timesteps: 33600
# Best mean reward: -2287.50 - Last mean reward per episode: -4629.50
# Num timesteps: 33700
# Best mean reward: -2287.50 - Last mean reward per episode: -5205.48
# Num timesteps: 33800
# Best mean reward: -2287.50 - Last mean reward per episode: -5283.10
# Num timesteps: 33900
# Best mean reward: -2287.50 - Last mean reward per episode: -5282.33
# Num timesteps: 34000
# Best mean reward: -2287.50 - Last mean reward per episode: -5221.23
# Num timesteps: 34100
# Best mean reward: -2287.50 - Last mean reward per episode: -5340.10
# Num timesteps: 34200
# Best mean reward: -2287.50 - Last mean reward per episode: -5136.55
# Num timesteps: 34300
# Best mean reward: -2287.50 - Last mean reward per episode: -5249.55
# Num timesteps: 34400
# Best mean reward: -2287.50 - Last mean reward per episode: -5165.01
# Num timesteps: 34500
# Best mean reward: -2287.50 - Last mean reward per episode: -4885.23
# Num timesteps: 34600
# Best mean reward: -2287.50 - Last mean reward per episode: -4962.13
# Num timesteps: 34700
# Best mean reward: -2287.50 - Last mean reward per episode: -4257.04
# Num timesteps: 34800
# Best mean reward: -2287.50 - Last mean reward per episode: -3826.90
# Num timesteps: 34900
# Best mean reward: -2287.50 - Last mean reward per episode: -4015.76
# Num timesteps: 35000
# Best mean reward: -2287.50 - Last mean reward per episode: -4142.24
# Num timesteps: 35100
# Best mean reward: -2287.50 - Last mean reward per episode: -3825.81
# Num timesteps: 35200
# Best mean reward: -2287.50 - Last mean reward per episode: -3926.41
# Num timesteps: 35300
# Best mean reward: -2287.50 - Last mean reward per episode: -3703.47
# Num timesteps: 35400
# Best mean reward: -2287.50 - Last mean reward per episode: -3558.14
# Num timesteps: 35500
# Best mean reward: -2287.50 - Last mean reward per episode: -3534.53
# Num timesteps: 35600
# Best mean reward: -2287.50 - Last mean reward per episode: -3883.92
# Num timesteps: 35700
# Best mean reward: -2287.50 - Last mean reward per episode: -4133.28
# Num timesteps: 35800
# Best mean reward: -2287.50 - Last mean reward per episode: -4437.92
# Num timesteps: 35900
# Best mean reward: -2287.50 - Last mean reward per episode: -4166.23
# Num timesteps: 36000
# Best mean reward: -2287.50 - Last mean reward per episode: -4069.97
# Num timesteps: 36100
# Best mean reward: -2287.50 - Last mean reward per episode: -4772.79
# Num timesteps: 36200
# Best mean reward: -2287.50 - Last mean reward per episode: -4639.49
# Num timesteps: 36300
# Best mean reward: -2287.50 - Last mean reward per episode: -4573.62
# Num timesteps: 36400
# Best mean reward: -2287.50 - Last mean reward per episode: -4844.81
# Num timesteps: 36500
# Best mean reward: -2287.50 - Last mean reward per episode: -4998.69
# Num timesteps: 36600
# Best mean reward: -2287.50 - Last mean reward per episode: -4835.80
# Num timesteps: 36700
# Best mean reward: -2287.50 - Last mean reward per episode: -4752.68
# Num timesteps: 36800
# Best mean reward: -2287.50 - Last mean reward per episode: -4646.79
# Num timesteps: 36900
# Best mean reward: -2287.50 - Last mean reward per episode: -4712.70
# Num timesteps: 37000
# Best mean reward: -2287.50 - Last mean reward per episode: -4629.19
# Num timesteps: 37100
# Best mean reward: -2287.50 - Last mean reward per episode: -3936.43
# Num timesteps: 37200
# Best mean reward: -2287.50 - Last mean reward per episode: -4011.63
# Num timesteps: 37300
# Best mean reward: -2287.50 - Last mean reward per episode: -4666.25
# Num timesteps: 37400
# Best mean reward: -2287.50 - Last mean reward per episode: -4628.66
# Num timesteps: 37500
# Best mean reward: -2287.50 - Last mean reward per episode: -4958.67
# Num timesteps: 37600
# Best mean reward: -2287.50 - Last mean reward per episode: -5348.38
# Num timesteps: 37700
# Best mean reward: -2287.50 - Last mean reward per episode: -5162.18
# Num timesteps: 37800
# Best mean reward: -2287.50 - Last mean reward per episode: -5209.87
# Num timesteps: 37900
# Best mean reward: -2287.50 - Last mean reward per episode: -5528.47
# Num timesteps: 38000
# Best mean reward: -2287.50 - Last mean reward per episode: -5461.13
# Num timesteps: 38100
# Best mean reward: -2287.50 - Last mean reward per episode: -5628.63
# Num timesteps: 38200
# Best mean reward: -2287.50 - Last mean reward per episode: -4967.76
# Num timesteps: 38300
# Best mean reward: -2287.50 - Last mean reward per episode: -4707.35
# Num timesteps: 38400
# Best mean reward: -2287.50 - Last mean reward per episode: -4531.91
# Num timesteps: 38500
# Best mean reward: -2287.50 - Last mean reward per episode: -4476.10
# Num timesteps: 38600
# Best mean reward: -2287.50 - Last mean reward per episode: -4138.99
# Num timesteps: 38700
# Best mean reward: -2287.50 - Last mean reward per episode: -4277.68
# Num timesteps: 38800
# Best mean reward: -2287.50 - Last mean reward per episode: -3949.63
# Num timesteps: 38900
# Best mean reward: -2287.50 - Last mean reward per episode: -3982.61
# Num timesteps: 39000
# Best mean reward: -2287.50 - Last mean reward per episode: -3827.28
# Num timesteps: 39100
# Best mean reward: -2287.50 - Last mean reward per episode: -3979.69
# Num timesteps: 39200
# Best mean reward: -2287.50 - Last mean reward per episode: -3924.05
# Num timesteps: 39300
# Best mean reward: -2287.50 - Last mean reward per episode: -4137.40
# Num timesteps: 39400
# Best mean reward: -2287.50 - Last mean reward per episode: -3784.85
# Num timesteps: 39500
# Best mean reward: -2287.50 - Last mean reward per episode: -3602.66
# Num timesteps: 39600
# Best mean reward: -2287.50 - Last mean reward per episode: -3934.33
# Num timesteps: 39700
# Best mean reward: -2287.50 - Last mean reward per episode: -4059.15
# Num timesteps: 39800
# Best mean reward: -2287.50 - Last mean reward per episode: -3896.41
# Num timesteps: 39900
# Best mean reward: -2287.50 - Last mean reward per episode: -3657.22
# Num timesteps: 40000
# Best mean reward: -2287.50 - Last mean reward per episode: -4234.38
# Num timesteps: 40100
# Best mean reward: -2287.50 - Last mean reward per episode: -4004.89
# Num timesteps: 40200
# Best mean reward: -2287.50 - Last mean reward per episode: -4034.63
# Num timesteps: 40300
# Best mean reward: -2287.50 - Last mean reward per episode: -4312.39
# Num timesteps: 40400
# Best mean reward: -2287.50 - Last mean reward per episode: -4563.17
# Num timesteps: 40500
# Best mean reward: -2287.50 - Last mean reward per episode: -4488.92
# Num timesteps: 40600
# Best mean reward: -2287.50 - Last mean reward per episode: -4051.55
# Num timesteps: 40700
# Best mean reward: -2287.50 - Last mean reward per episode: -3748.28
# Num timesteps: 40800
# Best mean reward: -2287.50 - Last mean reward per episode: -4030.26
# Num timesteps: 40900
# Best mean reward: -2287.50 - Last mean reward per episode: -4808.72
# Num timesteps: 41000
# Best mean reward: -2287.50 - Last mean reward per episode: -4369.13
# Num timesteps: 41100
# Best mean reward: -2287.50 - Last mean reward per episode: -4649.47
# Num timesteps: 41200
# Best mean reward: -2287.50 - Last mean reward per episode: -4679.58
# Num timesteps: 41300
# Best mean reward: -2287.50 - Last mean reward per episode: -4272.29
# Num timesteps: 41400
# Best mean reward: -2287.50 - Last mean reward per episode: -3947.11
# Num timesteps: 41500
# Best mean reward: -2287.50 - Last mean reward per episode: -4224.34
# Num timesteps: 41600
# Best mean reward: -2287.50 - Last mean reward per episode: -4541.20
# Num timesteps: 41700
# Best mean reward: -2287.50 - Last mean reward per episode: -4581.54
# Num timesteps: 41800
# Best mean reward: -2287.50 - Last mean reward per episode: -4722.23
# Num timesteps: 41900
# Best mean reward: -2287.50 - Last mean reward per episode: -4753.54
# Num timesteps: 42000
# Best mean reward: -2287.50 - Last mean reward per episode: -4875.01
# Num timesteps: 42100
# Best mean reward: -2287.50 - Last mean reward per episode: -5040.39
# Num timesteps: 42200
# Best mean reward: -2287.50 - Last mean reward per episode: -4642.06
# Num timesteps: 42300
# Best mean reward: -2287.50 - Last mean reward per episode: -4756.07
# Num timesteps: 42400
# Best mean reward: -2287.50 - Last mean reward per episode: -4897.68
# Num timesteps: 42500
# Best mean reward: -2287.50 - Last mean reward per episode: -4981.51
# Num timesteps: 42600
# Best mean reward: -2287.50 - Last mean reward per episode: -5212.29
# Num timesteps: 42700
# Best mean reward: -2287.50 - Last mean reward per episode: -4932.59
# Num timesteps: 42800
# Best mean reward: -2287.50 - Last mean reward per episode: -4377.47
# Num timesteps: 42900
# Best mean reward: -2287.50 - Last mean reward per episode: -4841.99
# Num timesteps: 43000
# Best mean reward: -2287.50 - Last mean reward per episode: -4772.01
# Num timesteps: 43100
# Best mean reward: -2287.50 - Last mean reward per episode: -4378.67
# Num timesteps: 43200
# Best mean reward: -2287.50 - Last mean reward per episode: -4683.56
# Num timesteps: 43300
# Best mean reward: -2287.50 - Last mean reward per episode: -4670.64
# Num timesteps: 43400
# Best mean reward: -2287.50 - Last mean reward per episode: -4736.64
# Num timesteps: 43500
# Best mean reward: -2287.50 - Last mean reward per episode: -4291.93
# Num timesteps: 43600
# Best mean reward: -2287.50 - Last mean reward per episode: -3720.36
# Num timesteps: 43700
# Best mean reward: -2287.50 - Last mean reward per episode: -3336.34
# Num timesteps: 43800
# Best mean reward: -2287.50 - Last mean reward per episode: -3810.46
# Num timesteps: 43900
# Best mean reward: -2287.50 - Last mean reward per episode: -3592.91
# Num timesteps: 44000
# Best mean reward: -2287.50 - Last mean reward per episode: -3464.90
# Num timesteps: 44100
# Best mean reward: -2287.50 - Last mean reward per episode: -4011.02
# Num timesteps: 44200
# Best mean reward: -2287.50 - Last mean reward per episode: -4187.13
# Num timesteps: 44300
# Best mean reward: -2287.50 - Last mean reward per episode: -4134.30
# Num timesteps: 44400
# Best mean reward: -2287.50 - Last mean reward per episode: -4395.28
# Num timesteps: 44500
# Best mean reward: -2287.50 - Last mean reward per episode: -4609.64
# Num timesteps: 44600
# Best mean reward: -2287.50 - Last mean reward per episode: -4599.17
# Num timesteps: 44700
# Best mean reward: -2287.50 - Last mean reward per episode: -5157.66
# Num timesteps: 44800
# Best mean reward: -2287.50 - Last mean reward per episode: -4501.95
# Num timesteps: 44900
# Best mean reward: -2287.50 - Last mean reward per episode: -5504.84
# Num timesteps: 45000
# Best mean reward: -2287.50 - Last mean reward per episode: -5114.96
# Num timesteps: 45100
# Best mean reward: -2287.50 - Last mean reward per episode: -5346.42
# Num timesteps: 45200
# Best mean reward: -2287.50 - Last mean reward per episode: -5286.22
# Num timesteps: 45300
# Best mean reward: -2287.50 - Last mean reward per episode: -4691.34
# Num timesteps: 45400
# Best mean reward: -2287.50 - Last mean reward per episode: -4699.62
# Num timesteps: 45500
# Best mean reward: -2287.50 - Last mean reward per episode: -4528.71
# Num timesteps: 45600
# Best mean reward: -2287.50 - Last mean reward per episode: -4875.63
# Num timesteps: 45700
# Best mean reward: -2287.50 - Last mean reward per episode: -4671.14
# Num timesteps: 45800
# Best mean reward: -2287.50 - Last mean reward per episode: -4534.93
# Num timesteps: 45900
# Best mean reward: -2287.50 - Last mean reward per episode: -3873.78
# Num timesteps: 46000
# Best mean reward: -2287.50 - Last mean reward per episode: -4032.22
# Num timesteps: 46100
# Best mean reward: -2287.50 - Last mean reward per episode: -3515.07
# Num timesteps: 46200
# Best mean reward: -2287.50 - Last mean reward per episode: -3461.74
# Num timesteps: 46300
# Best mean reward: -2287.50 - Last mean reward per episode: -3817.17
# Num timesteps: 46400
# Best mean reward: -2287.50 - Last mean reward per episode: -4169.19
# Num timesteps: 46500
# Best mean reward: -2287.50 - Last mean reward per episode: -4640.01
# Num timesteps: 46600
# Best mean reward: -2287.50 - Last mean reward per episode: -4528.25
# Num timesteps: 46700
# Best mean reward: -2287.50 - Last mean reward per episode: -4072.18
# Num timesteps: 46800
# Best mean reward: -2287.50 - Last mean reward per episode: -3861.72
# Num timesteps: 46900
# Best mean reward: -2287.50 - Last mean reward per episode: -3852.34
# Num timesteps: 47000
# Best mean reward: -2287.50 - Last mean reward per episode: -3542.46
# Num timesteps: 47100
# Best mean reward: -2287.50 - Last mean reward per episode: -3560.49
# Num timesteps: 47200
# Best mean reward: -2287.50 - Last mean reward per episode: -3744.04
# Num timesteps: 47300
# Best mean reward: -2287.50 - Last mean reward per episode: -3198.95
# Num timesteps: 47400
# Best mean reward: -2287.50 - Last mean reward per episode: -2780.64
# Num timesteps: 47500
# Best mean reward: -2287.50 - Last mean reward per episode: -2609.69
# Num timesteps: 47600
# Best mean reward: -2287.50 - Last mean reward per episode: -2143.52
# Saving new best model to ./tmp/gym/best_model.zip
# Num timesteps: 47700
# Best mean reward: -2143.52 - Last mean reward per episode: -2347.89
# Num timesteps: 47800
# Best mean reward: -2143.52 - Last mean reward per episode: -2573.69
# Num timesteps: 47900
# Best mean reward: -2143.52 - Last mean reward per episode: -2829.53
# Num timesteps: 48000
# Best mean reward: -2143.52 - Last mean reward per episode: -2936.05
# Num timesteps: 48100
# Best mean reward: -2143.52 - Last mean reward per episode: -3207.69
# Num timesteps: 48200
# Best mean reward: -2143.52 - Last mean reward per episode: -3091.76
# Num timesteps: 48300
# Best mean reward: -2143.52 - Last mean reward per episode: -3811.99
# Num timesteps: 48400
# Best mean reward: -2143.52 - Last mean reward per episode: -3872.97
# Num timesteps: 48500
# Best mean reward: -2143.52 - Last mean reward per episode: -3933.55
# Num timesteps: 48600
# Best mean reward: -2143.52 - Last mean reward per episode: -4233.38
# Num timesteps: 48700
# Best mean reward: -2143.52 - Last mean reward per episode: -3927.72
# Num timesteps: 48800
# Best mean reward: -2143.52 - Last mean reward per episode: -4050.10
# Num timesteps: 48900
# Best mean reward: -2143.52 - Last mean reward per episode: -3586.64
# Num timesteps: 49000
# Best mean reward: -2143.52 - Last mean reward per episode: -4150.82
# Num timesteps: 49100
# Best mean reward: -2143.52 - Last mean reward per episode: -3790.91
# Num timesteps: 49200
# Best mean reward: -2143.52 - Last mean reward per episode: -3859.37
# Num timesteps: 49300
# Best mean reward: -2143.52 - Last mean reward per episode: -3681.70
# Num timesteps: 49400
# Best mean reward: -2143.52 - Last mean reward per episode: -3663.01
# Num timesteps: 49500
# Best mean reward: -2143.52 - Last mean reward per episode: -3751.40
# Num timesteps: 49600
# Best mean reward: -2143.52 - Last mean reward per episode: -3647.07
# Num timesteps: 49700
# Best mean reward: -2143.52 - Last mean reward per episode: -3187.92
# Num timesteps: 49800
# Best mean reward: -2143.52 - Last mean reward per episode: -3259.45
# Num timesteps: 49900
# Best mean reward: -2143.52 - Last mean reward per episode: -3361.83
# Num timesteps: 50000
# Best mean reward: -2143.52 - Last mean reward per episode: -3461.50
# Num timesteps: 50100
# Best mean reward: -2143.52 - Last mean reward per episode: -3551.79
# Num timesteps: 50200
# Best mean reward: -2143.52 - Last mean reward per episode: -3725.00
# Num timesteps: 50300
# Best mean reward: -2143.52 - Last mean reward per episode: -3701.21
# Num timesteps: 50400
# Best mean reward: -2143.52 - Last mean reward per episode: -3628.36
# Num timesteps: 50500
# Best mean reward: -2143.52 - Last mean reward per episode: -3648.58
# Num timesteps: 50600
# Best mean reward: -2143.52 - Last mean reward per episode: -3596.14
# Num timesteps: 50700
# Best mean reward: -2143.52 - Last mean reward per episode: -3866.66
# Num timesteps: 50800
# Best mean reward: -2143.52 - Last mean reward per episode: -4154.35
# Num timesteps: 50900
# Best mean reward: -2143.52 - Last mean reward per episode: -4050.74
# Num timesteps: 51000
# Best mean reward: -2143.52 - Last mean reward per episode: -4033.16
# Num timesteps: 51100
# Best mean reward: -2143.52 - Last mean reward per episode: -4232.57
# Num timesteps: 51200
# Best mean reward: -2143.52 - Last mean reward per episode: -4280.35
# Num timesteps: 51300
# Best mean reward: -2143.52 - Last mean reward per episode: -3824.28
# Num timesteps: 51400
# Best mean reward: -2143.52 - Last mean reward per episode: -4369.58
# Num timesteps: 51500
# Best mean reward: -2143.52 - Last mean reward per episode: -4866.06
# Num timesteps: 51600
# Best mean reward: -2143.52 - Last mean reward per episode: -4893.06
# Num timesteps: 51700
# Best mean reward: -2143.52 - Last mean reward per episode: -5251.34
# Num timesteps: 51800
# Best mean reward: -2143.52 - Last mean reward per episode: -5050.18
# Num timesteps: 51900
# Best mean reward: -2143.52 - Last mean reward per episode: -4989.99
# Num timesteps: 52000
# Best mean reward: -2143.52 - Last mean reward per episode: -4752.05
# Num timesteps: 52100
# Best mean reward: -2143.52 - Last mean reward per episode: -4255.65
# Num timesteps: 52200
# Best mean reward: -2143.52 - Last mean reward per episode: -4436.42
# Num timesteps: 52300
# Best mean reward: -2143.52 - Last mean reward per episode: -4242.35
# Num timesteps: 52400
# Best mean reward: -2143.52 - Last mean reward per episode: -3968.34
# Num timesteps: 52500
# Best mean reward: -2143.52 - Last mean reward per episode: -4108.63
# Num timesteps: 52600
# Best mean reward: -2143.52 - Last mean reward per episode: -3946.16
# Num timesteps: 52700
# Best mean reward: -2143.52 - Last mean reward per episode: -4030.31
# Num timesteps: 52800
# Best mean reward: -2143.52 - Last mean reward per episode: -3975.56
# Num timesteps: 52900
# Best mean reward: -2143.52 - Last mean reward per episode: -4183.61
# Num timesteps: 53000
# Best mean reward: -2143.52 - Last mean reward per episode: -3814.74
# Num timesteps: 53100
# Best mean reward: -2143.52 - Last mean reward per episode: -4080.85
# Num timesteps: 53200
# Best mean reward: -2143.52 - Last mean reward per episode: -4560.65
# Num timesteps: 53300
# Best mean reward: -2143.52 - Last mean reward per episode: -4713.60
# Num timesteps: 53400
# Best mean reward: -2143.52 - Last mean reward per episode: -4780.21
# Num timesteps: 53500
# Best mean reward: -2143.52 - Last mean reward per episode: -4385.94
# Num timesteps: 53600
# Best mean reward: -2143.52 - Last mean reward per episode: -4194.37
# Num timesteps: 53700
# Best mean reward: -2143.52 - Last mean reward per episode: -4044.15
# Num timesteps: 53800
# Best mean reward: -2143.52 - Last mean reward per episode: -4327.70
# Num timesteps: 53900
# ...
# Num timesteps: 87900
# Best mean reward: -2014.68 - Last mean reward per episode: -3685.37
# Num timesteps: 88000
# Best mean reward: -2014.68 - Last mean reward per episode: -3194.18
# Num timesteps: 88100
# Best mean reward: -2014.68 - Last mean reward per episode: -3066.10
# Num timesteps: 88200
# Best mean reward: -2014.68 - Last mean reward per episode: -2891.59
# Num timesteps: 88300
# Best mean reward: -2014.68 - Last mean reward per episode: -3023.15
# Num timesteps: 88400
# Best mean reward: -2014.68 - Last mean reward per episode: -2831.75
# Num timesteps: 88500
# Best mean reward: -2014.68 - Last mean reward per episode: -2941.65
# Num timesteps: 88600
# Best mean reward: -2014.68 - Last mean reward per episode: -2893.95
# Num timesteps: 88700
# Best mean reward: -2014.68 - Last mean reward per episode: -2939.09
# Num timesteps: 88800
# Best mean reward: -2014.68 - Last mean reward per episode: -3463.58
# Num timesteps: 88900
# Best mean reward: -2014.68 - Last mean reward per episode: -4373.72
# Num timesteps: 89000
# Best mean reward: -2014.68 - Last mean reward per episode: -4873.55
# Num timesteps: 89100
# Best mean reward: -2014.68 - Last mean reward per episode: -5539.45
# Num timesteps: 89200
# Best mean reward: -2014.68 - Last mean reward per episode: -5467.62
# Num timesteps: 89300
# Best mean reward: -2014.68 - Last mean reward per episode: -5799.51
# Num timesteps: 89400
# Best mean reward: -2014.68 - Last mean reward per episode: -5994.55
# Num timesteps: 89500
# Best mean reward: -2014.68 - Last mean reward per episode: -5631.09
# Num timesteps: 89600
# Best mean reward: -2014.68 - Last mean reward per episode: -6012.65
# Num timesteps: 89700
# Best mean reward: -2014.68 - Last mean reward per episode: -5547.74
# Num timesteps: 89800
# Best mean reward: -2014.68 - Last mean reward per episode: -4676.12
# Num timesteps: 89900
# Best mean reward: -2014.68 - Last mean reward per episode: -4540.96
# Num timesteps: 90000
# Best mean reward: -2014.68 - Last mean reward per episode: -4104.03
# Num timesteps: 90100
# Best mean reward: -2014.68 - Last mean reward per episode: -3925.14
# Num timesteps: 90200
# Best mean reward: -2014.68 - Last mean reward per episode: -3613.08
# Num timesteps: 90300
# Best mean reward: -2014.68 - Last mean reward per episode: -3044.28
# Num timesteps: 90400
# Best mean reward: -2014.68 - Last mean reward per episode: -3009.66
# Num timesteps: 90500
# Best mean reward: -2014.68 - Last mean reward per episode: -3262.48
# Num timesteps: 90600
# Best mean reward: -2014.68 - Last mean reward per episode: -3293.92
# Num timesteps: 90700
# Best mean reward: -2014.68 - Last mean reward per episode: -3262.33
# Num timesteps: 90800
# Best mean reward: -2014.68 - Last mean reward per episode: -3243.12
# Num timesteps: 90900
# Best mean reward: -2014.68 - Last mean reward per episode: -3546.49
# Num timesteps: 91000
# Best mean reward: -2014.68 - Last mean reward per episode: -3763.56
# Num timesteps: 91100
# Best mean reward: -2014.68 - Last mean reward per episode: -3796.96
# Num timesteps: 91200
# Best mean reward: -2014.68 - Last mean reward per episode: -4387.32
# Num timesteps: 91300
# Best mean reward: -2014.68 - Last mean reward per episode: -4459.31
# Num timesteps: 91400
# Best mean reward: -2014.68 - Last mean reward per episode: -4520.48
# Num timesteps: 91500
# Best mean reward: -2014.68 - Last mean reward per episode: -4099.00
# Num timesteps: 91600
# Best mean reward: -2014.68 - Last mean reward per episode: -4388.78
# Num timesteps: 91700
# Best mean reward: -2014.68 - Last mean reward per episode: -4483.57
# Num timesteps: 91800
# Best mean reward: -2014.68 - Last mean reward per episode: -4602.99
# Num timesteps: 91900
# Best mean reward: -2014.68 - Last mean reward per episode: -4173.29
# Num timesteps: 92000
# Best mean reward: -2014.68 - Last mean reward per episode: -4416.62
# Num timesteps: 92100
# Best mean reward: -2014.68 - Last mean reward per episode: -4442.50
# Num timesteps: 92200
# Best mean reward: -2014.68 - Last mean reward per episode: -4111.47
# Num timesteps: 92300
# Best mean reward: -2014.68 - Last mean reward per episode: -4502.81
# Num timesteps: 92400
# Best mean reward: -2014.68 - Last mean reward per episode: -4733.13
# Num timesteps: 92500
# Best mean reward: -2014.68 - Last mean reward per episode: -5580.65
# Num timesteps: 92600
# Best mean reward: -2014.68 - Last mean reward per episode: -5688.39
# Num timesteps: 92700
# Best mean reward: -2014.68 - Last mean reward per episode: -5766.10
# Num timesteps: 92800
# Best mean reward: -2014.68 - Last mean reward per episode: -5330.46
# Num timesteps: 92900
# Best mean reward: -2014.68 - Last mean reward per episode: -4934.04
# Num timesteps: 93000
# Best mean reward: -2014.68 - Last mean reward per episode: -5033.33
# Num timesteps: 93100
# Best mean reward: -2014.68 - Last mean reward per episode: -5066.00
# Num timesteps: 93200
# Best mean reward: -2014.68 - Last mean reward per episode: -4611.14
# Num timesteps: 93300
# Best mean reward: -2014.68 - Last mean reward per episode: -4771.71
# Num timesteps: 93400
# Best mean reward: -2014.68 - Last mean reward per episode: -3849.58
# Num timesteps: 93500
# Best mean reward: -2014.68 - Last mean reward per episode: -4157.56
# Num timesteps: 93600
# Best mean reward: -2014.68 - Last mean reward per episode: -3871.59
# Num timesteps: 93700
# Best mean reward: -2014.68 - Last mean reward per episode: -3673.42
# Num timesteps: 93800
# Best mean reward: -2014.68 - Last mean reward per episode: -3890.04
# Num timesteps: 93900
# Best mean reward: -2014.68 - Last mean reward per episode: -3919.12
# Num timesteps: 94000
# Best mean reward: -2014.68 - Last mean reward per episode: -3548.21
# Num timesteps: 94100
# Best mean reward: -2014.68 - Last mean reward per episode: -3857.51
# Num timesteps: 94200
# Best mean reward: -2014.68 - Last mean reward per episode: -4147.17
# Num timesteps: 94300
# Best mean reward: -2014.68 - Last mean reward per episode: -3483.59
# Num timesteps: 94400
# Best mean reward: -2014.68 - Last mean reward per episode: -3654.64
# Num timesteps: 94500
# Best mean reward: -2014.68 - Last mean reward per episode: -3287.80
# Num timesteps: 94600
# Best mean reward: -2014.68 - Last mean reward per episode: -3092.08
# Num timesteps: 94700
# Best mean reward: -2014.68 - Last mean reward per episode: -3248.91
# Num timesteps: 94800
# Best mean reward: -2014.68 - Last mean reward per episode: -3322.40
# Num timesteps: 94900
# Best mean reward: -2014.68 - Last mean reward per episode: -3381.03
# Num timesteps: 95000
# Best mean reward: -2014.68 - Last mean reward per episode: -4042.11
# Num timesteps: 95100
# Best mean reward: -2014.68 - Last mean reward per episode: -3772.63
# Num timesteps: 95200
# Best mean reward: -2014.68 - Last mean reward per episode: -3484.82
# Num timesteps: 95300
# Best mean reward: -2014.68 - Last mean reward per episode: -3911.98
# Num timesteps: 95400
# Best mean reward: -2014.68 - Last mean reward per episode: -3983.16
# Num timesteps: 95500
# Best mean reward: -2014.68 - Last mean reward per episode: -3691.31
# Num timesteps: 95600
# Best mean reward: -2014.68 - Last mean reward per episode: -3607.73
# Num timesteps: 95700
# Best mean reward: -2014.68 - Last mean reward per episode: -3598.59
# Num timesteps: 95800
# Best mean reward: -2014.68 - Last mean reward per episode: -3462.21
# Num timesteps: 95900
# Best mean reward: -2014.68 - Last mean reward per episode: -3752.65
# Num timesteps: 96000
# Best mean reward: -2014.68 - Last mean reward per episode: -3740.80
# Num timesteps: 96100
# Best mean reward: -2014.68 - Last mean reward per episode: -4264.84
# Num timesteps: 96200
# Best mean reward: -2014.68 - Last mean reward per episode: -4250.49
# Num timesteps: 96300
# Best mean reward: -2014.68 - Last mean reward per episode: -4071.80
# Num timesteps: 96400
# Best mean reward: -2014.68 - Last mean reward per episode: -4131.03
# Num timesteps: 96500
# Best mean reward: -2014.68 - Last mean reward per episode: -4902.71
# Num timesteps: 96600
# Best mean reward: -2014.68 - Last mean reward per episode: -5421.17
# Num timesteps: 96700
# Best mean reward: -2014.68 - Last mean reward per episode: -5298.47
# Num timesteps: 96800
# Best mean reward: -2014.68 - Last mean reward per episode: -5256.19
# Num timesteps: 96900
# Best mean reward: -2014.68 - Last mean reward per episode: -5120.49
# Num timesteps: 97000
# Best mean reward: -2014.68 - Last mean reward per episode: -5345.56
# Num timesteps: 97100
# Best mean reward: -2014.68 - Last mean reward per episode: -5017.33
# Num timesteps: 97200
# Best mean reward: -2014.68 - Last mean reward per episode: -4621.28
# Num timesteps: 97300
# Best mean reward: -2014.68 - Last mean reward per episode: -5453.04
# Num timesteps: 97400
# Best mean reward: -2014.68 - Last mean reward per episode: -4757.13
# Num timesteps: 97500
# Best mean reward: -2014.68 - Last mean reward per episode: -4293.83
# Num timesteps: 97600
# Best mean reward: -2014.68 - Last mean reward per episode: -4535.31
# Num timesteps: 97700
# Best mean reward: -2014.68 - Last mean reward per episode: -4582.99
# Num timesteps: 97800
# Best mean reward: -2014.68 - Last mean reward per episode: -4487.68
# Num timesteps: 97900
# Best mean reward: -2014.68 - Last mean reward per episode: -4341.44
# Num timesteps: 98000
# Best mean reward: -2014.68 - Last mean reward per episode: -4381.80
# Num timesteps: 98100
# Best mean reward: -2014.68 - Last mean reward per episode: -4665.53
# Num timesteps: 98200
# Best mean reward: -2014.68 - Last mean reward per episode: -4482.11
# Num timesteps: 98300
# Best mean reward: -2014.68 - Last mean reward per episode: -3896.79
# Num timesteps: 98400
# Best mean reward: -2014.68 - Last mean reward per episode: -3943.76
# Num timesteps: 98500
# Best mean reward: -2014.68 - Last mean reward per episode: -3867.04
# Num timesteps: 98600
# Best mean reward: -2014.68 - Last mean reward per episode: -3731.19
# Num timesteps: 98700
# Best mean reward: -2014.68 - Last mean reward per episode: -3920.07
# Num timesteps: 98800
# Best mean reward: -2014.68 - Last mean reward per episode: -4065.18
# Num timesteps: 98900
# Best mean reward: -2014.68 - Last mean reward per episode: -4144.30
# Num timesteps: 99000
# Best mean reward: -2014.68 - Last mean reward per episode: -3829.60
# Num timesteps: 99100
# Best mean reward: -2014.68 - Last mean reward per episode: -4793.98
# Num timesteps: 99200
# Best mean reward: -2014.68 - Last mean reward per episode: -4873.88
# Num timesteps: 99300
# Best mean reward: -2014.68 - Last mean reward per episode: -5391.73
# Num timesteps: 99400
# Best mean reward: -2014.68 - Last mean reward per episode: -5693.01
# Num timesteps: 99500
# Best mean reward: -2014.68 - Last mean reward per episode: -6157.67
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 6
#       1 from stable_baselines3.common import results_plotter
#       3 # Train the agent
#       4 # model.learn(total_timesteps=int(100000), log_interval=10, callback=callback)
# ----> 6 model.learn(total_timesteps=int(100000), log_interval=100, reset_num_timesteps=True, callback=callback)
#      10 # Helper from the library
#      11 results_plotter.plot_results(
#      12     [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
#      13 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\on_policy_algorithm.py:200, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     198 # Give access to local variables
#     199 callback.update_locals(locals())
# --> 200 if not callback.on_step():
#     201     return False
#     203 self._update_info_buffer(infos)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\callbacks.py:114, in BaseCallback.on_step(self)
#     111 self.n_calls += 1
#     112 self.num_timesteps = self.model.num_timesteps
# --> 114 return self._on_step()
#
# Cell In[20], line 52, in SaveOnBestTrainingRewardCallback._on_step(self)
#      48 def _on_step(self) -> bool:
#      49     if self.n_calls % self.check_freq == 0:
#      50
#      51         # Retrieve training reward
# ---> 52         x, y = ts2xy(load_results(self.log_dir), "timesteps")
#      53         #print(x[-100:])
#      55         results_plotter.plot_results(
#      56             [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
#      57         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\monitor.py:246, in load_results(path)
#     244 assert first_line[0] == "#"
#     245 header = json.loads(first_line[1:])
# --> 246 data_frame = pandas.read_csv(file_handler, index_col=None)
#     247 headers.append(header)
#     248 data_frame["t"] += header["t_start"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1896, in TextFileReader._make_engine(self, f, engine)
#    1893     raise ValueError(msg)
#    1895 try:
# -> 1896     return mapping[engine](f, **self.options)
#    1897 except Exception:
#    1898     if self.handles is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results(
    [log_dir], 1e5, results_plotter.X_TIMESTEPS, "TD3 - Env: Battery"
)

# %%
import matplotlib.pyplot as plt


def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %%
plot_results(log_dir)

# study value and policy more
# view episides during training

# %%
# from stable_baselines3.common.monitor import Monitor
# from stable_baselines3.common.vec_env import DummyVecEnv
# from stable_baselines3 import A2C, SAC, PPO, TD3

# env = Monitor(gym.make("Pendulum-v1"))
# env = DummyVecEnv([lambda: env])

# model = A2C("MlpPolicy", env, verbose=1).learn(int(5000))


iteration_length = 30000
iterations = 100
episode_length = 500


# for _ in range(iterations):
#     #print('training')
#     #model.learn(iteration_length, log_interval=10)
#     #print('saving')
#     #model.save('/content/drive/My Drive/Colab Notebooks/sac_training')
#     #print('evaluating')
#     vec_env = model.get_env()
#     obs = vec_env.reset()
#     episode_reward = 0.0
#     rewards = []
#     for _ in range(episode_length*10):
#         action, _ = model.predict(obs)
#         obs, reward, done, info = vec_env.step(action)
#         episode_reward = reward.sum()
#         if done:
#             rewards += [episode_reward]
#             print("Reward =", round(episode_reward, 2), "Info:", info)
#             episode_reward = 0.0
#             obs = vec_env.reset()
#     print("Mean Reward = ", round(np.mean(rewards), 2))
#     model.set_env(env)


#model.load('./tmp/gym/')
obs = model.get_env().reset()

episode_reward = 0

while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = model.get_env().step(action)
    episode_reward += rewards.squeeze()
    if not done:
        print(str(obs) +  "   ACTION: " +  str(action)  +  "  REWARD: "  + str(rewards))
    else:
        info_item = info.pop()
        print("FINAL: ")
        print(str(info_item.get('terminal_observation')) +  "   ACTION: " +  str(action) +  "  REWARD: "  + str(rewards) )
        print("EPISODE LENGTH: "  + str(info_item.get('episode').get('l')))
        print("EPISODE TOTAL REWARD: "  + str(episode_reward))
        obs = model.get_env().reset()
        break
        
    # env.render()
# Out:
# [[24.505276 42.449627]]   ACTION: [[ 1.3246312 13.446556 ]]  REWARD: [-321.9997]
# [[24.505276 29.162298]]   ACTION: [[ 1.2095076 13.287328 ]]  REWARD: [-21.687857]
# [[19.708279 29.162298]]   ACTION: [[0.       4.796997]]  REWARD: [-89.37849]
# [[19.708279 16.628   ]]   ACTION: [[ 0.9468908 12.534298 ]]  REWARD: [-9.488115]
# [[19.708279 16.628   ]]   ACTION: [[0. 0.]]  REWARD: [-9.488115]
# [[19.708279 16.628   ]]   ACTION: [[0. 0.]]  REWARD: [-9.488115]
# [[19.708279 16.628   ]]   ACTION: [[0. 0.]]  REWARD: [-9.488115]
# [[19.708279 16.628   ]]   ACTION: [[0. 0.]]  REWARD: [-9.488115]
# [[19.708279 16.628   ]]   ACTION: [[0. 0.]]  REWARD: [-9.488115]
# FINAL:
# [19.708279 16.628   ]   ACTION: [[0. 0.]]  REWARD: [100.]
# EPISODE LENGTH: 10
# EPISODE TOTAL REWARD: -389.99472999572754

# %% [markdown]
# DDPG is known to be very brittle. You should use TD3 instead. It solves some of the issues plaguing DDPG.
#
#
#
# -  generally don't use PPO because of its lack of sample efficiency. If you can quickly sample transitions from your environment, you probably want to run a vectorized environment.
# I generally don't use PPO because of its lack of sample efficiency. If you can quickly sample transitions from your environment, you probably want to run a vectorized environment.
#
# If this is the case, you would be better off using a more advanced approach such as IMPALA, or you could use APPO, an asynchronous version of PPO based on IMPALA.
#
#
# See if the hyperparameters in rl-zoo help you out by taking parameters from a closest-matching environment, or you could try using Optuna to optimize them (see this part of rl-zoo README).

# %%
import gym
import numpy as np

from stable_baselines3 import TD3
from stable_baselines3.td3.policies import MlpPolicy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.noise import NormalActionNoise

env = gym.make('Pendulum-v1')

# The noise objects for TD3
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = TD3(MlpPolicy, env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=50000, log_interval=10)
model.save("td3_pendulum")

del model # remove to demonstrate saving and loading

model = TD3.load("td3_pendulum")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 15
#      12 n_actions = env.action_space.shape[-1]
#      13 action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# ---> 15 model = TD3(MlpPolicy, env, action_noise=action_noise, verbose=1)
#      16 model.learn(total_timesteps=50000, log_interval=10)
#      17 model.save("td3_pendulum")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\td3\td3.py:106, in TD3.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_delay, target_policy_noise, target_noise_clip, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      79 def __init__(
#      80     self,
#      81     policy: Union[str, Type[TD3Policy]],
#    (...)
#     104     _init_setup_model: bool = True,
#     105 ):
# --> 106     super().__init__(
#     107         policy,
#     108         env,
#     109         learning_rate,
#     110         buffer_size,
#     111         learning_starts,
#     112         batch_size,
#     113         tau,
#     114         gamma,
#     115         train_freq,
#     116         gradient_steps,
#     117         action_noise=action_noise,
#     118         replay_buffer_class=replay_buffer_class,
#     119         replay_buffer_kwargs=replay_buffer_kwargs,
#     120         policy_kwargs=policy_kwargs,
#     121         stats_window_size=stats_window_size,
#     122         tensorboard_log=tensorboard_log,
#     123         verbose=verbose,
#     124         device=device,
#     125         seed=seed,
#     126         sde_support=False,
#     127         optimize_memory_usage=optimize_memory_usage,
#     128         supported_action_spaces=(spaces.Box,),
#     129         support_multi_env=True,
#     130     )
#     132     self.policy_delay = policy_delay
#     133     self.target_noise_clip = target_noise_clip
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\off_policy_algorithm.py:110, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      80 def __init__(
#      81     self,
#      82     policy: Union[str, Type[BasePolicy]],
#    (...)
#     108     supported_action_spaces: Optional[Tuple[Type[spaces.Space], ...]] = None,
#     109 ):
# --> 110     super().__init__(
#     111         policy=policy,
#     112         env=env,
#     113         learning_rate=learning_rate,
#     114         policy_kwargs=policy_kwargs,
#     115         stats_window_size=stats_window_size,
#     116         tensorboard_log=tensorboard_log,
#     117         verbose=verbose,
#     118         device=device,
#     119         support_multi_env=support_multi_env,
#     120         monitor_wrapper=monitor_wrapper,
#     121         seed=seed,
#     122         use_sde=use_sde,
#     123         sde_sample_freq=sde_sample_freq,
#     124         supported_action_spaces=supported_action_spaces,
#     125     )
#     126     self.buffer_size = buffer_size
#     127     self.batch_size = batch_size
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\base_class.py:169, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     167 if env is not None:
#     168     env = maybe_make_env(env, self.verbose)
# --> 169     env = self._wrap_env(env, self.verbose, monitor_wrapper)
#     171     self.observation_space = env.observation_space
#     172     self.action_space = env.action_space
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\base_class.py:216, in BaseAlgorithm._wrap_env(env, verbose, monitor_wrapper)
#     204 """ "
#     205 Wrap environment with the appropriate wrappers if needed.
#     206 For instance, to have a vectorized environment
#    (...)
#     212 :return: The wrapped environment.
#     213 """
#     214 if not isinstance(env, VecEnv):
#     215     # Patch to support gym 0.21/0.26 and gymnasium
# --> 216     env = _patch_env(env)
#     217     if not is_wrapped(env, Monitor) and monitor_wrapper:
#     218         if verbose >= 1:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\vec_env\patch_gym.py:33, in _patch_env(env)
#      30     return env
#      32 if not gym_installed or not isinstance(env, gym.Env):
# ---> 33     raise ValueError(
#      34         f"The environment is of type {type(env)}, not a Gymnasium "
#      35         f"environment. In this case, we expect OpenAI Gym to be "
#      36         f"installed and the environment to be an OpenAI Gym environment."
#      37     )
#      39 try:
#      40     import shimmy
#
# ValueError: The environment is of type <class 'gym.wrappers.time_limit.TimeLimit'>, not a Gymnasium environment. In this case, we expect OpenAI Gym to be installed and the environment to be an OpenAI Gym environment.
